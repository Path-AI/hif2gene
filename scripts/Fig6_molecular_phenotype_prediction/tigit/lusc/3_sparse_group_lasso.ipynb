# %%
# Clear workspace
# %reset

# standard packages
from math import e
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pickle as pkl
import os
from sklearn import preprocessing
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import classification_report, roc_curve, auc, roc_auc_score, precision_recall_curve, plot_precision_recall_curve
from scipy.stats import sem
pd.options.display.max_colwidth = 100

# SGL packages
from group_lasso import LogisticGroupLasso
LogisticGroupLasso.LOG_LOSSES = True

# %reload_ext autoreload
# %autoreload 2

working_dir = "~/Desktop/hif2gene"
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
seed = 360
np.random.seed(seed)

# %% [markdown]
# ## Load in HIFs + Clusters

# %%
# Load in HIF dataset with labels
# NAs removed, already converted to patient-level
df = pd.read_csv("{0}/data/genetic_data/TIGIT/datasets/lusc.TIGIT.joined.USE.csv".format(working_dir))
df = df.iloc[:,1:]
df
# Out:
#      AREA..MM2..OF..EPITHELIAL..IN..TISSUE._FFPE  \
# 0                                      27.225548
# 1                                      26.648888
# 2                                      52.244148
# 3                                      14.304372
# 4                                     108.472596
# ..                                           ...
# 295                                    68.523012
# 296                                    63.597184
# 297                                    77.987908
# 298                                    39.603288
# 299                                    17.451352
#
#      AREA..MM2..OF..ESI_0080..IN..TISSUE._FFPE  \
# 0                                    20.799096
# 1                                    50.661880
# 2                                    48.311188
# 3                                    13.492176
# 4                                   139.476556
# ..                                         ...
# 295                                  85.173192
# 296                                  70.101124
# 297                                 106.847656
# 298                                  65.279932
# 299                                  20.754456
#
#      AREA..MM2..OF..NECROSIS..IN..TISSUE._FFPE  \
# 0                                    39.167736
# 1                                    21.445668
# 2                                     6.086560
# 3                                     1.043028
# 4                                    40.770468
# ..                                         ...
# 295                                 111.656488
# 296                                  15.685304
# 297                                  57.923272
# 298                                  70.423856
# 299                                   7.431092
#
#      AREA..MM2..OF..STROMA..IN..TISSUE._FFPE  \
# 0                                  85.021760
# 1                                  68.787860
# 2                                  32.802492
# 3                                  17.688216
# 4                                 102.949824
# ..                                       ...
# 295                                59.804684
# 296                                37.812436
# 297                                95.313388
# 298                                49.194160
# 299                                53.174212
#
#      AREA..MM2..OF..TUMOR..IN..TISSUE._FFPE  \
# 0                                112.247308
# 1                                 95.436748
# 2                                 85.046640
# 3                                 31.992588
# 4                                211.422420
# ..                                      ...
# 295                              128.327696
# 296                              101.409620
# 297                              173.301296
# 298                               88.797448
# 299                               70.625564
#
#      CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.CANCER.IN.EPITHELIAL_FFPE  \
# 0                                                                 5110.147301
# 1                                                                 5902.693712
# 2                                                                 6767.115806
# 3                                                                 6700.259693
# 4                                                                 6523.976300
# ..                                                                        ...
# 295                                                               6257.862859
# 296                                                               6795.170377
# 297                                                               6331.815097
# 298                                                               6153.814813
# 299                                                               6045.268247
#
#      CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.CANCER.IN.ESI_0080_FFPE  \
# 0                                                               5460.162356
# 1                                                               6204.851490
# 2                                                               6598.832293
# 3                                                               6490.025315
# 4                                                               6178.594212
# ..                                                                      ...
# 295                                                             6306.755071
# 296                                                             6840.896120
# 297                                                             5924.450521
# 298                                                             5975.715902
# 299                                                             5516.059207
#
#      CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.CANCER.IN.STROMA_FFPE  \
# 0                                                             4177.408629
# 1                                                             5660.053414
# 2                                                             5307.369333
# 3                                                             4799.295929
# 4                                                             5890.749941
# ..                                                                    ...
# 295                                                           5587.013131
# 296                                                           5641.014115
# 297                                                           5927.116040
# 298                                                           5641.371296
# 299                                                           4807.185347
#
#      CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.CANCER.IN.TUMOR_FFPE  \
# 0                                                            4758.447487
# 1                                                            5775.615807
# 2                                                            6009.020668
# 3                                                            6114.604178
# 4                                                            6504.132661
# ..                                                                   ...
# 295                                                          6284.619255
# 296                                                          6738.660953
# 297                                                          6345.516412
# 298                                                          6316.010061
# 299                                                          5803.153841
#
#      CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.FIBROBLAST.IN.EPITHELIAL_FFPE  \
# 0                                                                     4499.157584
# 1                                                                     4904.934479
# 2                                                                     5909.048722
# 3                                                                     6224.053279
# 4                                                                     5345.874892
# ..                                                                            ...
# 295                                                                   3767.663380
# 296                                                                   5923.293362
# 297                                                                   5205.901012
# 298                                                                   5052.757209
# 299                                                                   4366.118374
#
#      ...  DENSITY..LYMPHOCYTE.CELLS..IN..TUMOR._FFPE  \
# 0    ...                                  886.586964
# 1    ...                                  510.547572
# 2    ...                                  468.825106
# 3    ...                                  367.928972
# 4    ...                                  574.111298
# ..   ...                                         ...
# 295  ...                                  859.385802
# 296  ...                                  725.404552
# 297  ...                                  679.498669
# 298  ...                                  897.334347
# 299  ...                                 1226.708788
#
#      DENSITY..MACROPHAGE.CELLS..IN..EPITHELIAL._FFPE  \
# 0                                          98.620604
# 1                                         134.939964
# 2                                         188.499581
# 3                                         328.291239
# 4                                         600.824562
# ..                                               ...
# 295                                        34.309642
# 296                                        13.758471
# 297                                        25.324439
# 298                                        91.760058
# 299                                       105.206748
#
#      DENSITY..MACROPHAGE.CELLS..IN..ESI_0080._FFPE  \
# 0                                       447.423292
# 1                                       619.617748
# 2                                       351.140196
# 3                                       515.632171
# 4                                       794.534961
# ..                                             ...
# 295                                     140.995068
# 296                                      50.270235
# 297                                      84.278873
# 298                                     255.331148
# 299                                     671.614809
#
#      DENSITY..MACROPHAGE.CELLS..IN..STROMA._FFPE  \
# 0                                    1028.560218
# 1                                    1140.259342
# 2                                    1166.801595
# 3                                    1341.288460
# 4                                     880.788295
# ..                                           ...
# 295                                   310.092768
# 296                                   167.167225
# 297                                   148.866810
# 298                                   498.778717
# 299                                  1171.658171
#
#      DENSITY..MACROPHAGE.CELLS..IN..TUMOR._FFPE  \
# 0                                    803.003668
# 1                                    859.543119
# 2                                    565.830702
# 3                                    888.362017
# 4                                    737.149825
# ..                                          ...
# 295                                  162.833127
# 296                                   70.959737
# 297                                   93.271086
# 298                                  317.250108
# 299                                  908.141420
#
#      DENSITY..PLASMA.CELLS..IN..EPITHELIAL._FFPE  \
# 0                                      17.153006
# 1                                      33.847566
# 2                                      86.593431
# 3                                      61.869196
# 4                                      72.267101
# ..                                           ...
# 295                                    17.760457
# 296                                     8.113567
# 297                                    56.188198
# 298                                    56.030701
# 299                                    43.320426
#
#      DENSITY..PLASMA.CELLS..IN..ESI_0080._FFPE  \
# 0                                   914.318584
# 1                                   562.138634
# 2                                   288.483901
# 3                                    97.019191
# 4                                   307.463858
# ..                                         ...
# 295                                  73.403378
# 296                                 206.301970
# 297                                 252.537126
# 298                                 437.025578
# 299                                 437.881870
#
#      DENSITY..PLASMA.CELLS..IN..STROMA._FFPE  \
# 0                                1656.599440
# 1                                1058.835091
# 2                                 642.451189
# 3                                 183.285867
# 4                                 546.839206
# ..                                       ...
# 295                               167.913269
# 296                               707.359875
# 297                               635.230803
# 298                               953.629455
# 299                              1230.032332
#
#      DENSITY..PLASMA.CELLS..IN..TUMOR._FFPE  joined.TIGIT_label
# 0                               1258.952241                   1
# 1                                772.626913                   0
# 2                                300.987787                   0
# 3                                128.998629                   0
# 4                                303.354772                   1
# ..                                      ...                 ...
# 295                               87.736322                   0
# 296                              268.840372                   1
# 297                              374.653863                   0
# 298                              553.304190                   0
# 299                              936.799599                   1
#
# [300 rows x 608 columns]

# %%
# Normalize HIFs and define X, y
X = df.iloc[:,:607]
X_normalized = (X-X.mean())/X.std()
X_normalized
# Out:
#      AREA..MM2..OF..EPITHELIAL..IN..TISSUE._FFPE  \
# 0                                      -0.552376
# 1                                      -0.567770
# 2                                       0.115516
# 3                                      -0.897317
# 4                                       1.616579
# ..                                           ...
# 295                                     0.550093
# 296                                     0.418594
# 297                                     0.802766
# 298                                    -0.221942
# 299                                    -0.813305
#
#      AREA..MM2..OF..ESI_0080..IN..TISSUE._FFPE  \
# 0                                    -0.939490
# 1                                    -0.258066
# 2                                    -0.311705
# 3                                    -1.106224
# 4                                     1.768554
# ..                                         ...
# 295                                   0.529432
# 296                                   0.185509
# 297                                   1.024011
# 298                                   0.075497
# 299                                  -0.940509
#
#      AREA..MM2..OF..NECROSIS..IN..TISSUE._FFPE  \
# 0                                     0.586970
# 1                                    -0.066179
# 2                                    -0.632242
# 3                                    -0.818122
# 4                                     0.646039
# ..                                         ...
# 295                                   3.258556
# 296                                  -0.278479
# 297                                   1.278209
# 298                                   1.738920
# 299                                  -0.582689
#
#      AREA..MM2..OF..STROMA..IN..TISSUE._FFPE  \
# 0                                   0.591882
# 1                                   0.235479
# 2                                  -0.554552
# 3                                  -0.886375
# 4                                   0.985479
# ..                                       ...
# 295                                 0.038260
# 296                                -0.444563
# 297                                 0.817827
# 298                                -0.194686
# 299                                -0.107307
#
#      AREA..MM2..OF..TUMOR..IN..TISSUE._FFPE  \
# 0                                  0.087607
# 1                                 -0.147340
# 2                                 -0.292553
# 3                                 -1.034044
# 4                                  1.473692
# ..                                      ...
# 295                                0.312349
# 296                               -0.063862
# 297                                0.940906
# 298                               -0.240132
# 299                               -0.494104
#
#      CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.CANCER.IN.EPITHELIAL_FFPE  \
# 0                                                                   -1.513417
# 1                                                                   -0.466900
# 2                                                                    0.674525
# 3                                                                    0.586245
# 4                                                                    0.353472
# ..                                                                        ...
# 295                                                                  0.002083
# 296                                                                  0.711570
# 297                                                                  0.099733
# 298                                                                 -0.135307
# 299                                                                 -0.278637
#
#      CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.CANCER.IN.ESI_0080_FFPE  \
# 0                                                                 -1.090308
# 1                                                                 -0.066082
# 2                                                                  0.475788
# 3                                                                  0.326138
# 4                                                                 -0.102196
# ..                                                                      ...
# 295                                                                0.074073
# 296                                                                0.808716
# 297                                                               -0.451738
# 298                                                               -0.381229
# 299                                                               -1.013429
#
#      CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.CANCER.IN.STROMA_FFPE  \
# 0                                                               -1.805467
# 1                                                                0.148843
# 2                                                               -0.316039
# 3                                                               -0.985743
# 4                                                                0.452930
# ..                                                                    ...
# 295                                                              0.052567
# 296                                                              0.123747
# 297                                                              0.500865
# 298                                                              0.124218
# 299                                                             -0.975343
#
#      CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.CANCER.IN.TUMOR_FFPE  \
# 0                                                              -2.355995
# 1                                                              -0.845422
# 2                                                              -0.498798
# 3                                                              -0.341998
# 4                                                               0.236481
# ..                                                                   ...
# 295                                                            -0.089513
# 296                                                             0.584774
# 297                                                             0.000924
# 298                                                            -0.042895
# 299                                                            -0.804526
#
#      CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.FIBROBLAST.IN.EPITHELIAL_FFPE  \
# 0                                                                       -0.873144
# 1                                                                       -0.376359
# 2                                                                        0.852959
# 3                                                                        1.238613
# 4                                                                        0.163476
# ..                                                                            ...
# 295                                                                     -1.768699
# 296                                                                      0.870399
# 297                                                                     -0.007891
# 298                                                                     -0.195382
# 299                                                                     -1.036021
#
#      ...  DENSITY..LYMPHOCYTE.CELLS..IN..STROMA._FFPE  \
# 0    ...                                    -0.571889
# 1    ...                                    -1.165326
# 2    ...                                    -0.802562
# 3    ...                                    -1.311080
# 4    ...                                    -0.912635
# ..   ...                                          ...
# 295  ...                                    -0.636563
# 296  ...                                     0.320659
# 297  ...                                    -0.678109
# 298  ...                                    -0.101834
# 299  ...                                    -0.002574
#
#      DENSITY..LYMPHOCYTE.CELLS..IN..TUMOR._FFPE  \
# 0                                     -0.210598
# 1                                     -0.832195
# 2                                     -0.901163
# 3                                     -1.067945
# 4                                     -0.727124
# ..                                          ...
# 295                                   -0.255562
# 296                                   -0.477034
# 297                                   -0.552917
# 298                                   -0.192833
# 299                                    0.351626
#
#      DENSITY..MACROPHAGE.CELLS..IN..EPITHELIAL._FFPE  \
# 0                                          -0.297703
# 1                                          -0.188211
# 2                                          -0.026745
# 3                                           0.394686
# 4                                           1.216292
# ..                                               ...
# 295                                        -0.491581
# 296                                        -0.553537
# 297                                        -0.518669
# 298                                        -0.318385
# 299                                        -0.277848
#
#      DENSITY..MACROPHAGE.CELLS..IN..ESI_0080._FFPE  \
# 0                                         0.113060
# 1                                         0.651824
# 2                                        -0.188191
# 3                                         0.326473
# 4                                         1.199107
# ..                                             ...
# 295                                      -0.845696
# 296                                      -1.129557
# 297                                      -1.023150
# 298                                      -0.487960
# 299                                       0.814513
#
#      DENSITY..MACROPHAGE.CELLS..IN..STROMA._FFPE  \
# 0                                       0.646913
# 1                                       0.918822
# 2                                       0.983434
# 3                                       1.408187
# 4                                       0.287192
# ..                                           ...
# 295                                    -1.102052
# 296                                    -1.449975
# 297                                    -1.494524
# 298                                    -0.642734
# 299                                     0.995256
#
#      DENSITY..MACROPHAGE.CELLS..IN..TUMOR._FFPE  \
# 0                                      0.857673
# 1                                      1.021613
# 2                                      0.169974
# 3                                      1.105176
# 4                                      0.666726
# ..                                          ...
# 295                                   -0.998544
# 296                                   -1.264938
# 297                                   -1.200244
# 298                                   -0.550802
# 299                                    1.162527
#
#      DENSITY..PLASMA.CELLS..IN..EPITHELIAL._FFPE  \
# 0                                      -0.568499
# 1                                      -0.379047
# 2                                       0.219521
# 3                                      -0.061053
# 4                                       0.056943
# ..                                           ...
# 295                                    -0.561606
# 296                                    -0.671080
# 297                                    -0.125522
# 298                                    -0.127310
# 299                                    -0.271548
#
#      DENSITY..PLASMA.CELLS..IN..ESI_0080._FFPE  \
# 0                                     1.973863
# 1                                     0.671252
# 2                                    -0.340917
# 3                                    -1.049089
# 4                                    -0.270715
# ..                                         ...
# 295                                  -1.136437
# 296                                  -0.644884
# 297                                  -0.473873
# 298                                   0.208495
# 299                                   0.211663
#
#      DENSITY..PLASMA.CELLS..IN..STROMA._FFPE  \
# 0                                   1.432806
# 1                                   0.389012
# 2                                  -0.338062
# 3                                  -1.139839
# 4                                  -0.505016
# ..                                       ...
# 295                                -1.166682
# 296                                -0.224721
# 297                                -0.350670
# 298                                 0.205306
# 299                                 0.687951
#
#      DENSITY..PLASMA.CELLS..IN..TUMOR._FFPE
# 0                                  2.040576
# 1                                  0.726561
# 2                                 -0.547773
# 3                                 -1.012474
# 4                                 -0.541377
# ..                                      ...
# 295                               -1.123962
# 296                               -0.634632
# 297                               -0.348732
# 298                                0.133968
# 299                                1.170144
#
# [300 rows x 607 columns]

# %%
y = df.iloc[:,607]
print(np.sum(y))
# Out:
# 99

# %%
# Load in clusters
clusters = pd.read_csv("{0}/data/hif_clusters/LUSC.hif.clusters.csv".format(working_dir))
print("Number of Clusters: {0}".format(len(set(clusters['x']))))
clusters
# Out:
# Number of Clusters: 25
#                                     Unnamed: 0  x
# 0    AREA (MM2) OF [EPITHELIAL] IN [TISSUE]_HE  1
# 1      AREA (MM2) OF [ESI_0080] IN [TISSUE]_HE  1
# 2      AREA (MM2) OF [NECROSIS] IN [TISSUE]_HE  2
# 3        AREA (MM2) OF [STROMA] IN [TISSUE]_HE  3
# 4         AREA (MM2) OF [TUMOR] IN [TISSUE]_HE  1
# ..                                         ... ..
# 602     TOTAL [MACROPHAGE CELLS] IN [TUMOR]_HE  1
# 603    TOTAL [PLASMA CELLS] IN [EPITHELIAL]_HE  1
# 604      TOTAL [PLASMA CELLS] IN [ESI_0080]_HE  3
# 605        TOTAL [PLASMA CELLS] IN [STROMA]_HE  3
# 606         TOTAL [PLASMA CELLS] IN [TUMOR]_HE  3
#
# [607 rows x 2 columns]

# %% [markdown]
# ## Define Nested CV Parameters

# %%
num_outer_loops = 3 # for estimating generalization error
num_inner_loops = 5 # for hyper-parameter tuning
training_aurocs = [0.0, 0.0, 0.0]
generalization_aurocs = [0.0, 0.0, 0.0]
training_auprcs = [0.0, 0.0, 0.0]
generalization_auprcs = [0.0, 0.0, 0.0]

# Define outer loops (A, B, and C)
X_train_AB, X_train_C, y_train_AB, y_train_C = train_test_split(X_normalized, y, test_size=1/3, random_state=seed, stratify=y)
X_train_A, X_train_B, y_train_A, y_train_B = train_test_split(X_train_AB, y_train_AB, test_size=1/2, random_state=seed, stratify=y_train_AB)

# Verify correctness
print(len(X_train_A), len(y_train_A))
print(len(X_train_B), len(y_train_B))
print(len(X_train_C), len(y_train_C))

print(np.sum(y_train_A)/len(y_train_A))
print(np.sum(y_train_B)/len(y_train_B))
print(np.sum(y_train_C)/len(y_train_C))
# Out:
# 100 100
# 100 100
# 100 100
# 0.33
# 0.33
# 0.33

# %% [markdown]
# ### Outer Loop 1

# %%
# Define outer loop train and test
X_train_1 = np.array(X_train_A.append(X_train_B))
y_train_1 = np.array(y_train_A.append(y_train_B))
print(X_train_1.shape, y_train_1.shape)

X_test_1 = np.array(X_train_C)
y_test_1 = np.array(y_train_C)
print(X_test_1.shape, y_test_1.shape)
# Out:
# (200, 607) (200,)
# (100, 607) (100,)

# %%
# Define k-folds object
skf = StratifiedKFold(n_splits=num_inner_loops)
skf.get_n_splits(X_train_1, y_train_1)
# Out:
# 5

# %%
# K-folds: hyper-parameter tuning
num_regs = 30
regs = list(np.logspace(-7, -2, num_regs, base=e))
print(regs)

cv_aucs = [] # based on k-folds CV

for reg in regs:
    print(reg)
    k_folds_count = 1
    
    aucs = [] 
    for train_index, test_index in skf.split(X_train_1, y_train_1):
        print(k_folds_count)

        # Define train / test
        X_train, X_test = X_train_1[train_index], X_train_1[test_index]
        y_train, y_test = y_train_1[train_index], y_train_1[test_index]
        print(np.sum(y_train)/len(y_train), np.sum(y_test)/len(y_test))
        print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
        
        # SGL 
        sgl = LogisticGroupLasso(groups=clusters['x'], group_reg=reg*(1/6), l1_reg=reg*(5/6), n_iter=1000, 
                                 tol=1e-6, old_regularisation=False, warm_start=True, random_state=seed)
        sgl.fit(X_train, y_train)

        # Compute AUC on test set
        y_probs_test = sgl.predict_proba(X_test)[1] # predicted probability y = 1
        fpr, tpr, thresholds = roc_curve(y_test, y_probs_test, pos_label=1)
        roc_auc = auc(fpr, tpr)
        aucs.append(roc_auc)

        k_folds_count += 1
    
    print(aucs)
    cv_aucs.append(np.mean(np.array(aucs)))

# %%
# Plot CV AUCs
print(cv_aucs)
plt.figure(figsize=(12,6))
plt.plot(np.log(regs), cv_aucs)
plt.grid(axis='both')
plt.show()

max_reg = regs[np.argmax(np.array(cv_aucs))]
print(max_reg, np.log(max_reg))
# Out:
# [0.6002442002442003, 0.6013838013838014, 0.6071021571021571, 0.6082417582417583, 0.6093610093610093, 0.6116402116402117, 0.6195156695156696, 0.6217948717948717, 0.6335775335775334, 0.6380341880341881, 0.6560643060643061, 0.6463369963369964, 0.6621082621082621, 0.6847985347985348, 0.6763329263329265, 0.6731583231583231, 0.7032153032153031, 0.7077533577533579, 0.7095848595848595, 0.7159951159951159, 0.7486365486365487, 0.7577330077330078, 0.7594831094831094, 0.76003256003256, 0.756043956043956, 0.7537851037851038, 0.764041514041514, 0.5, 0.5, 0.5]
# 0.08068187071542855 -2.5172413793103443

# %%
# Choose best regularization parameter based on CV plot
optimal_log_reg = -3.6
optimal_reg = np.exp(optimal_log_reg)
print(optimal_log_reg, optimal_reg)

# Fit "optimal model"
optimal_sgl = LogisticGroupLasso(groups=clusters['x'], group_reg=optimal_reg*(1/6), l1_reg=optimal_reg*(5/6), n_iter=1000, 
                         tol=1e-6, old_regularisation=False, warm_start=False, random_state=seed)
optimal_sgl.fit(X_train_1, y_train_1)

# Store optimal model
optimal_sgl_1 = optimal_sgl

# %%
# Plot Train and Test ROCs
y_pred_probs_train = optimal_sgl.predict_proba(X_train_1)[1] # predicted probability y = 1
y_pred_probs_test = optimal_sgl.predict_proba(X_test_1)[1]

# Train
fpr, tpr, thresholds = roc_curve(y_train_1, y_pred_probs_train, pos_label=1)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='blue', lw=1, label='Train ROC Curve (Area = %0.3f)' % roc_auc)
training_aurocs[0] = roc_auc

# Test
fpr, tpr, thresholds = roc_curve(y_test_1, y_pred_probs_test, pos_label=1)
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr, color='red', lw=1, label='Test ROC Curve (Area = %0.3f)' % roc_auc)
generalization_aurocs[0] = roc_auc

# Plot parameters
plt.plot([0, 1], [0, 1], color='black', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
# Plot Train and Test PR Curves

# Train
precision, recall, thresholds = precision_recall_curve(y_train_1, y_pred_probs_train, pos_label=1)
prc_auc = auc(recall, precision)
plt.figure()
plt.plot(recall, precision, color='blue', lw=1, label='Train PR Curve (Area = %0.3f)' % prc_auc)
training_auprcs[0] = prc_auc

# Test
precision, recall, thresholds = precision_recall_curve(y_test_1, y_pred_probs_test, pos_label=1)
prc_auc = auc(recall, precision)
plt.plot(recall, precision, color='red', lw=1, label='Test PR Curve (Area = %0.3f)' % prc_auc)
generalization_auprcs[0] = prc_auc

# Plot parameters
# plt.plot([0, 1], [0, 1], color='black', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower right")
plt.show()

# %%
# Save model coefficients
sparsity_mask = optimal_sgl.sparsity_mask_
print("Number of chosen variables: {0}".format(sparsity_mask.sum()))

betas_1 = optimal_sgl.coef_[:, 1] - optimal_sgl.coef_[:, 0]
betas_1[~sparsity_mask] = 0.0 # if not included in model, set to 0
betas_df = pd.DataFrame({
    "HIF": clusters['Unnamed: 0'],
    "Beta": betas_1, 
    "Cluster": clusters['x'],
    "Included (T/F)": sparsity_mask}
)
betas_df = betas_df[betas_df['Included (T/F)'] == True][['HIF', 'Beta', 'Cluster']]
betas_df.sort_values(by="Beta", ascending=False)
# Out:
# Number of chosen variables: 21
#                                                                                                      HIF  \
# 508                             REGION PROPERTIES: PERIMETER^2 / AREA OF LARGEST REGION OF EPITHELIAL_HE
# 155                 CELL CLUSTERING PROPERTIES: WITHIN CLUSTER DISPERSION MEAN OF FIBROBLAST IN TUMOR_HE
# 95                               CELL CLUSTERING PROPERTIES: CLUSTER SIZE MEAN OF FIBROBLAST IN TUMOR_HE
# 154                CELL CLUSTERING PROPERTIES: WITHIN CLUSTER DISPERSION MEAN OF FIBROBLAST IN STROMA_HE
# 55                             CELL CLUSTERING PROPERTIES: CLUSTER EXTENT MEAN OF FIBROBLAST IN TUMOR_HE
# 114               CELL CLUSTERING PROPERTIES: CLUSTER SIZE STANDARD DEVIATION OF FIBROBLAST IN STROMA_HE
# 174  CELL CLUSTERING PROPERTIES: WITHIN CLUSTER DISPERSION STANDARD DEVIATION OF FIBROBLAST IN STROMA_HE
# 94                              CELL CLUSTERING PROPERTIES: CLUSTER SIZE MEAN OF FIBROBLAST IN STROMA_HE
# 175   CELL CLUSTERING PROPERTIES: WITHIN CLUSTER DISPERSION STANDARD DEVIATION OF FIBROBLAST IN TUMOR_HE
# 115                CELL CLUSTERING PROPERTIES: CLUSTER SIZE STANDARD DEVIATION OF FIBROBLAST IN TUMOR_HE
# 23                                 CELL CLUSTERING PROPERTIES: BALL-HALL INDEX OF MACROPHAGE IN TUMOR_HE
# 19                                 CELL CLUSTERING PROPERTIES: BALL-HALL INDEX OF LYMPHOCYTE IN TUMOR_HE
# 15                                 CELL CLUSTERING PROPERTIES: BALL-HALL INDEX OF FIBROBLAST IN TUMOR_HE
# 476                                         REGION PROPERTIES: LACUNARITY OF LARGEST REGION OF STROMA_HE
# 435                               REGION PROPERTIES: AVERAGE SOLIDITY OF SIGNIFICANT REGIONS OF TUMOR_HE
# 78              CELL CLUSTERING PROPERTIES: CLUSTER EXTENT STANDARD DEVIATION OF LYMPHOCYTE IN STROMA_HE
# 455                                              REGION PROPERTIES: EXTENT OF LARGEST REGION OF TUMOR_HE
# 540               REGION PROPERTIES: STANDARD DEVIATION OF SOLIDITIES OF SIGNIFICANT REGIONS OF TUMOR_HE
# 83               CELL CLUSTERING PROPERTIES: CLUSTER EXTENT STANDARD DEVIATION OF MACROPHAGE IN TUMOR_HE
# 473                                     REGION PROPERTIES: LACUNARITY OF LARGEST REGION OF EPITHELIAL_HE
# 526      REGION PROPERTIES: STANDARD DEVIATION OF ECCENTRICITIES OF SIGNIFICANT REGIONS OF EPITHELIAL_HE
#
#          Beta  Cluster
# 508  0.235103       18
# 155  0.107539        8
# 95   0.096600        8
# 154  0.077487        8
# 55   0.065500        8
# 114  0.059555        8
# 174  0.055962        8
# 94   0.054354        8
# 175  0.051769        8
# 115  0.044701        8
# 23   0.017334        9
# 19   0.010242        9
# 15   0.009741        9
# 476  0.009442       24
# 435  0.005470        9
# 78  -0.000996        9
# 455 -0.001295        9
# 540 -0.004630       24
# 83  -0.004959        9
# 473 -0.010233       18
# 526 -0.065193       18

# %% [markdown]
# ### Outer Loop 2

# %%
# Define outer loop train and test
X_train_2 = np.array(X_train_A.append(X_train_C))
y_train_2 = np.array(y_train_A.append(y_train_C))
print(X_train_2.shape, y_train_2.shape)

X_test_2 = np.array(X_train_B)
y_test_2 = np.array(y_train_B)
print(X_test_2.shape, y_test_2.shape)
# Out:
# (200, 607) (200,)
# (100, 607) (100,)

# %%
# Define k-folds object
skf = StratifiedKFold(n_splits=num_inner_loops)
skf.get_n_splits(X_train_2, y_train_2)
# Out:
# 5

# %%
# K-folds: hyper-parameter tuning
num_regs = 30
regs = list(np.logspace(-6.0, -3.0, num_regs, base=e))
print(regs)

cv_aucs = [] # based on k-folds CV

for reg in regs:
    print(reg)
    k_folds_count = 1
    
    aucs = [] 
    for train_index, test_index in skf.split(X_train_2, y_train_2):
        print(k_folds_count)

        # Define train / test
        X_train, X_test = X_train_2[train_index], X_train_2[test_index]
        y_train, y_test = y_train_2[train_index], y_train_2[test_index]
        print(np.sum(y_train)/len(y_train), np.sum(y_test)/len(y_test))
        print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
        
        # SGL 
        sgl = LogisticGroupLasso(groups=clusters['x'], group_reg=reg*(1/6), l1_reg=reg*(5/6), n_iter=1000, 
                                 tol=1e-6, old_regularisation=False, warm_start=True, random_state=seed)
        sgl.fit(X_train, y_train)

        # Compute AUC on test set
        y_probs_test = sgl.predict_proba(X_test)[1] # predicted probability y = 1
        fpr, tpr, thresholds = roc_curve(y_test, y_probs_test, pos_label=1)
        roc_auc = auc(fpr, tpr)
        aucs.append(roc_auc)

        k_folds_count += 1
    
    print(aucs)
    cv_aucs.append(np.mean(np.array(aucs)))

# %%
# Plot CV AUCs
print(cv_aucs)
plt.figure(figsize=(12,6))
plt.plot(np.log(regs), cv_aucs)
plt.grid(axis='both')
plt.show()

max_reg = regs[np.argmax(np.array(cv_aucs))]
print(max_reg, np.log(max_reg))
# Out:
# [0.6654606498622672, 0.6606367998578242, 0.6655867717188473, 0.675450282870768, 0.6482932969994964, 0.6552173513817718, 0.6609059565771156, 0.6704189745564408, 0.674192796421907, 0.6497370930955836, 0.6418709161458487, 0.6467266076241818, 0.6566097272000236, 0.6524746008708273, 0.6514022985101151, 0.6294057936672492, 0.6542973253161932, 0.7000427712449275, 0.6969045348182814, 0.7008240869642488, 0.6817453570688071, 0.6938215692663132, 0.6759051272177956, 0.6682973845561447, 0.6541494327774651, 0.6750949616421315, 0.6786153549954088, 0.6879549776369183, 0.6213567726074465, 0.6824247504517047]
# 0.01769483024496462 -4.0344827586206895

# %%
# Choose best regularization parameter based on CV plot
optimal_log_reg = -3.6
optimal_reg = np.exp(optimal_log_reg)
print(optimal_log_reg, optimal_reg)

# Fit "optimal model"
optimal_sgl = LogisticGroupLasso(groups=clusters['x'], group_reg=optimal_reg*(1/6), l1_reg=optimal_reg*(5/6), n_iter=1000, 
                         tol=1e-6, old_regularisation=False, warm_start=False, random_state=seed)
optimal_sgl.fit(X_train_2, y_train_2)

# Store optimal model
optimal_sgl_2 = optimal_sgl

# %%
# Plot Train and Test ROCs
y_pred_probs_train = optimal_sgl.predict_proba(X_train_2)[1] # predicted probability y = 1
y_pred_probs_test = optimal_sgl.predict_proba(X_test_2)[1]

# Train
fpr, tpr, thresholds = roc_curve(y_train_2, y_pred_probs_train, pos_label=1)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='blue', lw=1, label='Train ROC Curve (Area = %0.3f)' % roc_auc)
training_aurocs[1] = roc_auc

# Test
fpr, tpr, thresholds = roc_curve(y_test_2, y_pred_probs_test, pos_label=1)
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr, color='red', lw=1, label='Test ROC Curve (Area = %0.3f)' % roc_auc)
generalization_aurocs[1] = roc_auc

# Plot parameters
plt.plot([0, 1], [0, 1], color='black', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
# Plot Train and Test PR Curves

# Train
precision, recall, thresholds = precision_recall_curve(y_train_2, y_pred_probs_train, pos_label=1)
prc_auc = auc(recall, precision)
plt.figure()
plt.plot(recall, precision, color='blue', lw=1, label='Train PR Curve (Area = %0.3f)' % prc_auc)
training_auprcs[1] = prc_auc

# Test
precision, recall, thresholds = precision_recall_curve(y_test_2, y_pred_probs_test, pos_label=1)
prc_auc = auc(recall, precision)
plt.plot(recall, precision, color='red', lw=1, label='Test PR Curve (Area = %0.3f)' % prc_auc)
generalization_auprcs[1] = prc_auc

# Plot parameters
# plt.plot([0, 1], [0, 1], color='black', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower right")
plt.show()

# %%
# Save model coefficients
sparsity_mask = optimal_sgl.sparsity_mask_
print("Number of chosen variables: {0}".format(sparsity_mask.sum()))

betas_2 = optimal_sgl.coef_[:, 1] - optimal_sgl.coef_[:, 0]
betas_2[~sparsity_mask] = 0.0 # if not included in model, set to 0
betas_df = pd.DataFrame({
    "HIF": clusters['Unnamed: 0'],
    "Beta": betas_2, 
    "Cluster": clusters['x'],
    "Included (T/F)": sparsity_mask}
)
betas_df = betas_df[betas_df['Included (T/F)'] == True][['HIF', 'Beta', 'Cluster']]
betas_df.sort_values(by="Beta", ascending=False)
# Out:
# Number of chosen variables: 59
#                                                                                                      HIF  \
# 475                                       REGION PROPERTIES: LACUNARITY OF LARGEST REGION OF NECROSIS_HE
# 423                        REGION PROPERTIES: AVERAGE ECCENTRICITY OF SIGNIFICANT REGIONS OF NECROSIS_HE
# 528        REGION PROPERTIES: STANDARD DEVIATION OF ECCENTRICITIES OF SIGNIFICANT REGIONS OF NECROSIS_HE
# 94                              CELL CLUSTERING PROPERTIES: CLUSTER SIZE MEAN OF FIBROBLAST IN STROMA_HE
# 211                                          COUNT PROP [FIBROBLAST CELLS] IN [[TUMOR] OVER [STROMA]]_HE
# 155                 CELL CLUSTERING PROPERTIES: WITHIN CLUSTER DISPERSION MEAN OF FIBROBLAST IN TUMOR_HE
# 348                                    DENSITY RATIO [FIBROBLAST CELLS] IN [[ESI_0080] OVER [STROMA]]_HE
# 476                                         REGION PROPERTIES: LACUNARITY OF LARGEST REGION OF STROMA_HE
# 382                                       DENSITY RATIO [PLASMA CELLS] IN [[EPITHELIAL] OVER [TUMOR]]_HE
# 254  COUNT PROP [[CANCER CELLS] OVER [[CANCER CELLS] SELECTED BY [LYMPHOCYTE_RADIUS_80]]] IN [STROMA]_HE
# 96                          CELL CLUSTERING PROPERTIES: CLUSTER SIZE MEAN OF LYMPHOCYTE IN EPITHELIAL_HE
# 274  COUNT PROP [[[CANCER CELLS] SELECTED BY [FIBROBLAST_RADIUS_80]] OVER [[CANCER CELLS] SELECTED BY...
# 271   COUNT PROP [[[CANCER CELLS] SELECTED BY [FIBROBLAST_RADIUS_80]] OVER [CANCER CELLS]] IN [TUMOR]_HE
# 238                                          COUNT PROP [PLASMA CELLS] IN [[EPITHELIAL] OVER [TUMOR]]_HE
# 231                                       COUNT PROP [MACROPHAGE CELLS] IN [[STROMA] OVER [ESI_0080]]_HE
# 375                                    DENSITY RATIO [MACROPHAGE CELLS] IN [[STROMA] OVER [ESI_0080]]_HE
# 286  COUNT PROP [[[CANCER CELLS] SELECTED BY [LYMPHOCYTE_RADIUS_80]] OVER [CANCER CELLS]] IN [STROMA]_HE
# 236                                       COUNT PROP [PLASMA CELLS] IN [[EPITHELIAL] OVER [ESI_0080]]_HE
# 367                                       DENSITY RATIO [LYMPHOCYTE CELLS] IN [[TUMOR] OVER [STROMA]]_HE
# 239                                       COUNT PROP [PLASMA CELLS] IN [[ESI_0080] OVER [EPITHELIAL]]_HE
# 273  COUNT PROP [[[CANCER CELLS] SELECTED BY [FIBROBLAST_RADIUS_80]] OVER [[CANCER CELLS] SELECTED BY...
# 174  CELL CLUSTERING PROPERTIES: WITHIN CLUSTER DISPERSION STANDARD DEVIATION OF FIBROBLAST IN STROMA_HE
# 114               CELL CLUSTERING PROPERTIES: CLUSTER SIZE STANDARD DEVIATION OF FIBROBLAST IN STROMA_HE
# 384                                        DENSITY RATIO [PLASMA CELLS] IN [[ESI_0080] OVER [STROMA]]_HE
# 280  COUNT PROP [[[CANCER CELLS] SELECTED BY [FIBROBLAST_RADIUS_80]] OVER [[CANCER CELLS] SELECTED BY...
# 596                                                            TOTAL [LYMPHOCYTE CELLS] IN [ESI_0080]_HE
# 104                             CELL CLUSTERING PROPERTIES: CLUSTER SIZE MEAN OF PLASMA IN EPITHELIAL_HE
# 23                                 CELL CLUSTERING PROPERTIES: BALL-HALL INDEX OF MACROPHAGE IN TUMOR_HE
# 229                                        COUNT PROP [MACROPHAGE CELLS] IN [[ESI_0080] OVER [TUMOR]]_HE
# 278  COUNT PROP [[[CANCER CELLS] SELECTED BY [FIBROBLAST_RADIUS_80]] OVER [[CANCER CELLS] SELECTED BY...
# 341                                       DENSITY RATIO [CANCER CELLS] IN [[TUMOR] OVER [EPITHELIAL]]_HE
# 252  COUNT PROP [[CANCER CELLS] OVER [[CANCER CELLS] SELECTED BY [LYMPHOCYTE_RADIUS_80]]] IN [EPITHEL...
# 522                                         REGION PROPERTIES: SOLIDITY OF LARGEST REGION OF ESI_0080_HE
# 250  COUNT PROP [[CANCER CELLS] OVER [[CANCER CELLS] SELECTED BY [FIBROBLAST_RADIUS_80]]] IN [STROMA]_HE
# 175   CELL CLUSTERING PROPERTIES: WITHIN CLUSTER DISPERSION STANDARD DEVIATION OF FIBROBLAST IN TUMOR_HE
# 116           CELL CLUSTERING PROPERTIES: CLUSTER SIZE STANDARD DEVIATION OF LYMPHOCYTE IN EPITHELIAL_HE
# 12                            CELL CLUSTERING PROPERTIES: BALL-HALL INDEX OF FIBROBLAST IN EPITHELIAL_HE
# 258  COUNT PROP [[CANCER CELLS] OVER [[CANCER CELLS] SELECTED BY [MACROPHAGE_RADIUS_80]]] IN [STROMA]_HE
# 93                            CELL CLUSTERING PROPERTIES: CLUSTER SIZE MEAN OF FIBROBLAST IN ESI_0080_HE
# 498                                      REGION PROPERTIES: NUMBER OF SIGNIFICANT REGIONS OF NECROSIS_HE
# 552                                            REGION PROPERTIES: TOTAL FILLED AREA (MM2) OF ESI_0080_HE
# 228                                       COUNT PROP [MACROPHAGE CELLS] IN [[ESI_0080] OVER [STROMA]]_HE
# 429                                REGION PROPERTIES: AVERAGE EXTENT OF SIGNIFICANT REGIONS OF STROMA_HE
# 376                                       DENSITY RATIO [MACROPHAGE CELLS] IN [[STROMA] OVER [TUMOR]]_HE
# 241                                            COUNT PROP [PLASMA CELLS] IN [[ESI_0080] OVER [TUMOR]]_HE
# 192                                           COUNT PROP [CANCER CELLS] IN [[ESI_0080] OVER [STROMA]]_HE
# 410                                                            DENSITY [MACROPHAGE CELLS] IN [STROMA]_HE
# 417                                       REGION PROPERTIES: AREA (MM2) OF LARGEST REGION OF ESI_0080_HE
# 78              CELL CLUSTERING PROPERTIES: CLUSTER EXTENT STANDARD DEVIATION OF LYMPHOCYTE IN STROMA_HE
# 72          CELL CLUSTERING PROPERTIES: CLUSTER EXTENT STANDARD DEVIATION OF FIBROBLAST IN EPITHELIAL_HE
# 499                                        REGION PROPERTIES: NUMBER OF SIGNIFICANT REGIONS OF STROMA_HE
# 74              CELL CLUSTERING PROPERTIES: CLUSTER EXTENT STANDARD DEVIATION OF FIBROBLAST IN STROMA_HE
# 218                                     COUNT PROP [LYMPHOCYTE CELLS] IN [[STROMA] OVER [EPITHELIAL]]_HE
# 216                                       COUNT PROP [LYMPHOCYTE CELLS] IN [[ESI_0080] OVER [STROMA]]_HE
# 379                                       DENSITY RATIO [MACROPHAGE CELLS] IN [[TUMOR] OVER [STROMA]]_HE
# 318      COUNT PROP [[[CANCER CELLS] SELECTED BY [PLASMA_RADIUS_80]] OVER [CANCER CELLS]] IN [STROMA]_HE
# 83               CELL CLUSTERING PROPERTIES: CLUSTER EXTENT STANDARD DEVIATION OF MACROPHAGE IN TUMOR_HE
# 540               REGION PROPERTIES: STANDARD DEVIATION OF SOLIDITIES OF SIGNIFICANT REGIONS OF TUMOR_HE
# 533               REGION PROPERTIES: STANDARD DEVIATION OF EXTENTS OF SIGNIFICANT REGIONS OF NECROSIS_HE
#
#          Beta  Cluster
# 475  0.910896       21
# 423  0.235397       20
# 528  0.121433       20
# 94   0.062865        8
# 211  0.061168       16
# 155  0.051066        8
# 348  0.026772        4
# 476  0.026437       24
# 382  0.023992       11
# 254  0.022618       17
# 96   0.018821       11
# 274  0.018814       17
# 271  0.018257        8
# 238  0.016018       11
# 231  0.015769        5
# 375  0.015281        4
# 286  0.015036       17
# 236  0.013777       11
# 367  0.012864        4
# 239  0.011171       11
# 273  0.011032       17
# 174  0.010335        8
# 114  0.009851        8
# 384  0.009166        4
# 280  0.008933       11
# 596  0.008772        3
# 104  0.008764       11
# 23   0.008307        9
# 229  0.008274        5
# 278  0.005793       13
# 341  0.005581        4
# 252  0.005257       17
# 522  0.004988        9
# 250  0.004634        8
# 175  0.004539        8
# 116  0.004471       11
# 12   0.004153        8
# 258  0.003391       13
# 93   0.002930        8
# 498  0.001695       21
# 552  0.001081        1
# 228  0.000943        5
# 429 -0.000150        4
# 376 -0.001752        4
# 241 -0.001852        5
# 192 -0.001858        7
# 410 -0.002225       13
# 417 -0.003173        1
# 78  -0.003771        9
# 72  -0.007252        8
# 499 -0.008212       24
# 74  -0.009032        9
# 218 -0.011935       11
# 216 -0.013563        5
# 379 -0.018834        4
# 318 -0.026028       12
# 83  -0.033635        9
# 540 -0.091827       24
# 533 -0.265864       21

# %% [markdown]
# ### Outer Loop 3

# %%
# Define outer loop train and test
X_train_3 = np.array(X_train_B.append(X_train_C))
y_train_3 = np.array(y_train_B.append(y_train_C))
print(X_train_3.shape, y_train_3.shape)

X_test_3 = np.array(X_train_A)
y_test_3 = np.array(y_train_A)
print(X_test_3.shape, y_test_3.shape)
# Out:
# (200, 607) (200,)
# (100, 607) (100,)

# %%
# Define k-folds object
skf = StratifiedKFold(n_splits=num_inner_loops)
skf.get_n_splits(X_train_3, y_train_3)
# Out:
# 5

# %%
# K-folds: hyper-parameter tuning
num_regs = 30
regs = list(np.logspace(-6.0, -3.0, num_regs, base=e))
print(regs)

cv_aucs = [] # based on k-folds CV

for reg in regs:
    print(reg)
    k_folds_count = 1
    
    aucs = [] 
    for train_index, test_index in skf.split(X_train_3, y_train_3):
        print(k_folds_count)

        # Define train / test
        X_train, X_test = X_train_3[train_index], X_train_3[test_index]
        y_train, y_test = y_train_3[train_index], y_train_3[test_index]
        print(np.sum(y_train)/len(y_train), np.sum(y_test)/len(y_test))
        print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
        
        # SGL 
        sgl = LogisticGroupLasso(groups=clusters['x'], group_reg=reg*(1/6), l1_reg=reg*(5/6), n_iter=1000, 
                                 tol=1e-6, old_regularisation=False, warm_start=True, random_state=seed)
        sgl.fit(X_train, y_train)

        # Compute AUC on test set
        y_probs_test = sgl.predict_proba(X_test)[1] # predicted probability y = 1
        fpr, tpr, thresholds = roc_curve(y_test, y_probs_test, pos_label=1)
        roc_auc = auc(fpr, tpr)
        aucs.append(roc_auc)

        k_folds_count += 1
    
    print(aucs)
    cv_aucs.append(np.mean(np.array(aucs)))

# %%
# Plot CV AUCs
print(cv_aucs)
plt.figure(figsize=(12,6))
plt.plot(np.log(regs), cv_aucs)
plt.grid(axis='both')
plt.show()

max_reg = regs[np.argmax(np.array(cv_aucs))]
print(max_reg, np.log(max_reg))
# Out:
# [0.6601139601139601, 0.6634717134717134, 0.6650997150997151, 0.6701465201465202, 0.6723646723646723, 0.6757427757427757, 0.6898656898656899, 0.6806878306878307, 0.6954415954415956, 0.6888074888074888, 0.704985754985755, 0.697883597883598, 0.6989214489214489, 0.7023606023606024, 0.7176027676027676, 0.7076312576312578, 0.7105413105413106, 0.7072853072853074, 0.7032153032153033, 0.6974765974765976, 0.6907203907203907, 0.683943833943834, 0.6828042328042329, 0.7039479039479039, 0.7274318274318274, 0.7241554741554741, 0.7270858770858771, 0.7277370777370777, 0.7249694749694751, 0.7137973137973138]
# 0.04048205248027766 -3.206896551724138

# %%
# Choose best regularization parameter based on CV plot
optimal_log_reg = -3.7
optimal_reg = np.exp(optimal_log_reg)
print(optimal_log_reg, optimal_reg)

# Fit "optimal model"
optimal_sgl = LogisticGroupLasso(groups=clusters['x'], group_reg=optimal_reg*(1/6), l1_reg=optimal_reg*(5/6), n_iter=1000, 
                         tol=1e-6, old_regularisation=False, warm_start=False, random_state=seed)
optimal_sgl.fit(X_train_3, y_train_3)

# Store optimal model
optimal_sgl_3 = optimal_sgl

# %%
# Plot Train and Test ROCs
y_pred_probs_train = optimal_sgl.predict_proba(X_train_3)[1] # predicted probability y = 1
y_pred_probs_test = optimal_sgl.predict_proba(X_test_3)[1]

# Train
fpr, tpr, thresholds = roc_curve(y_train_3, y_pred_probs_train, pos_label=1)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='blue', lw=1, label='Train ROC Curve (Area = %0.3f)' % roc_auc)
training_aurocs[2] = roc_auc

# Test
fpr, tpr, thresholds = roc_curve(y_test_3, y_pred_probs_test, pos_label=1)
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr, color='red', lw=1, label='Test ROC Curve (Area = %0.3f)' % roc_auc)
generalization_aurocs[2] = roc_auc

# Plot parameters
plt.plot([0, 1], [0, 1], color='black', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
# Plot Train and Test PR Curves

# Train
precision, recall, thresholds = precision_recall_curve(y_train_3, y_pred_probs_train, pos_label=1)
prc_auc = auc(recall, precision)
plt.figure()
plt.plot(recall, precision, color='blue', lw=1, label='Train PR Curve (Area = %0.3f)' % prc_auc)
training_auprcs[2] = prc_auc

# Test
precision, recall, thresholds = precision_recall_curve(y_test_3, y_pred_probs_test, pos_label=1)
prc_auc = auc(recall, precision)
plt.plot(recall, precision, color='red', lw=1, label='Test PR Curve (Area = %0.3f)' % prc_auc)
generalization_auprcs[2] = prc_auc

# Plot parameters
# plt.plot([0, 1], [0, 1], color='black', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower right")
plt.show()

# %%
# Save model coefficients
sparsity_mask = optimal_sgl.sparsity_mask_
print("Number of chosen variables: {0}".format(sparsity_mask.sum()))

betas_3 = optimal_sgl.coef_[:, 1] - optimal_sgl.coef_[:, 0]
betas_3[~sparsity_mask] = 0.0 # if not included in model, set to 0
betas_df = pd.DataFrame({
    "HIF": clusters['Unnamed: 0'],
    "Beta": betas_3, 
    "Cluster": clusters['x'],
    "Included (T/F)": sparsity_mask}
)
betas_df = betas_df[betas_df['Included (T/F)'] == True][['HIF', 'Beta', 'Cluster']]
betas_df.sort_values(by="Beta", ascending=False)
# Out:
# Number of chosen variables: 148
#                                                                                                      HIF  \
# 475                                       REGION PROPERTIES: LACUNARITY OF LARGEST REGION OF NECROSIS_HE
# 23                                 CELL CLUSTERING PROPERTIES: BALL-HALL INDEX OF MACROPHAGE IN TUMOR_HE
# 353                                   DENSITY RATIO [FIBROBLAST CELLS] IN [[TUMOR] OVER [EPITHELIAL]]_HE
# 164                CELL CLUSTERING PROPERTIES: WITHIN CLUSTER DISPERSION MEAN OF PLASMA IN EPITHELIAL_HE
# 155                 CELL CLUSTERING PROPERTIES: WITHIN CLUSTER DISPERSION MEAN OF FIBROBLAST IN TUMOR_HE
# ..                                                                                                   ...
# 196                                              COUNT PROP [CANCER CELLS] IN [[STROMA] OVER [TUMOR]]_HE
# 307  COUNT PROP [[[CANCER CELLS] SELECTED BY [MACROPHAGE_RADIUS_80]] OVER [[CANCER CELLS] SELECTED BY...
# 504                                     REGION PROPERTIES: PERIMETER (MM) OF LARGEST REGION OF STROMA_HE
# 83               CELL CLUSTERING PROPERTIES: CLUSTER EXTENT STANDARD DEVIATION OF MACROPHAGE IN TUMOR_HE
# 84              CELL CLUSTERING PROPERTIES: CLUSTER EXTENT STANDARD DEVIATION OF PLASMA IN EPITHELIAL_HE
#
#          Beta  Cluster
# 475  0.508814       21
# 23   0.119695        9
# 353  0.059863       16
# 164  0.044172       11
# 155  0.035111        8
# ..        ...      ...
# 196 -0.046009        7
# 307 -0.048610       13
# 504 -0.053564        3
# 83  -0.214938        9
# 84  -0.692759       14
#
# [148 rows x 3 columns]

# %% [markdown]
# ## Compute Ensemble Model

# %%
betas_df = pd.DataFrame({
    "HIF": clusters['Unnamed: 0'],
    "Beta_1": betas_1, 
    "Beta_2": betas_2,
    "Beta_3": betas_3,
    "Cluster": clusters['x']
    }
)
betas_df['Beta'] = (betas_df['Beta_1'] + betas_df['Beta_2'] + betas_df['Beta_3'])/3.0
betas_df.sort_values(by="Beta", ascending=False)
# Out:
#                                                                                                  HIF  \
# 475                                   REGION PROPERTIES: LACUNARITY OF LARGEST REGION OF NECROSIS_HE
# 423                    REGION PROPERTIES: AVERAGE ECCENTRICITY OF SIGNIFICANT REGIONS OF NECROSIS_HE
# 508                         REGION PROPERTIES: PERIMETER^2 / AREA OF LARGEST REGION OF EPITHELIAL_HE
# 155             CELL CLUSTERING PROPERTIES: WITHIN CLUSTER DISPERSION MEAN OF FIBROBLAST IN TUMOR_HE
# 23                             CELL CLUSTERING PROPERTIES: BALL-HALL INDEX OF MACROPHAGE IN TUMOR_HE
# ..                                                                                               ...
# 526  REGION PROPERTIES: STANDARD DEVIATION OF ECCENTRICITIES OF SIGNIFICANT REGIONS OF EPITHELIAL_HE
# 540           REGION PROPERTIES: STANDARD DEVIATION OF SOLIDITIES OF SIGNIFICANT REGIONS OF TUMOR_HE
# 83           CELL CLUSTERING PROPERTIES: CLUSTER EXTENT STANDARD DEVIATION OF MACROPHAGE IN TUMOR_HE
# 533           REGION PROPERTIES: STANDARD DEVIATION OF EXTENTS OF SIGNIFICANT REGIONS OF NECROSIS_HE
# 84          CELL CLUSTERING PROPERTIES: CLUSTER EXTENT STANDARD DEVIATION OF PLASMA IN EPITHELIAL_HE
#
#        Beta_1    Beta_2    Beta_3  Cluster      Beta
# 475  0.000000  0.910896  0.508814       21  0.473237
# 423  0.000000  0.235397  0.000000       20  0.078466
# 508  0.235103  0.000000  0.000000       18  0.078368
# 155  0.107539  0.051066  0.035111        8  0.064572
# 23   0.017334  0.008307  0.119695        9  0.048445
# ..        ...       ...       ...      ...       ...
# 526 -0.065193  0.000000  0.000000       18 -0.021731
# 540 -0.004630 -0.091827  0.000000       24 -0.032152
# 83  -0.004959 -0.033635 -0.214938        9 -0.084511
# 533  0.000000 -0.265864  0.000000       21 -0.088621
# 84   0.000000  0.000000 -0.692759       14 -0.230920
#
# [607 rows x 6 columns]

# %% [markdown]
# ## Compute Final Train / Test Metrics

# %%
print(training_aurocs)
print(np.mean(training_aurocs), np.std(training_aurocs))
# Out:
# [0.7947761194029851, 0.7836951605608322, 0.7512437810945274]
# 0.7765716870194482 0.01847203338602443

# %%
print(generalization_aurocs)
print(np.mean(generalization_aurocs), np.std(generalization_aurocs))
# Out:
# [0.6942559927634555, 0.7182270465852555, 0.6978742650384442]
# 0.7034524347957184 0.010551140182073036

# %%
print(training_auprcs)
print(np.mean(training_auprcs), np.std(training_auprcs))
# Out:
# [0.659446446609484, 0.6675242143966306, 0.6220573735816011]
# 0.6496760115292385 0.019805798051206733

# %%
print(generalization_auprcs)
print(np.mean(generalization_auprcs), np.std(generalization_auprcs))
# Out:
# [0.5300191883898463, 0.6062481650846794, 0.5405907371941214]
# 0.5589526968895491 0.033720274760424

# %% [markdown]
# ## Evaluate Hold-Out Set

# %%
holdout_df = pd.read_csv("{0}/data/genetic_data/TIGIT/datasets/lusc.tigit.joined.HOLDOUT.csv".format(working_dir))
holdout_df = holdout_df.iloc[:,1:]
holdout_df
# Out:
#     AREA..MM2..OF..EPITHELIAL..IN..TISSUE._FFPE  \
# 0                                     44.614060
# 1                                    141.079780
# 2                                    155.368068
# 3                                    106.002212
# 4                                     49.889124
# ..                                          ...
# 93                                    42.810968
# 94                                    47.872360
# 95                                    20.681632
# 96                                   107.337592
# 97                                     5.812256
#
#     AREA..MM2..OF..ESI_0080..IN..TISSUE._FFPE  \
# 0                                   48.970184
# 1                                  133.991280
# 2                                  141.359540
# 3                                  166.184464
# 4                                   31.114740
# ..                                        ...
# 93                                  71.876072
# 94                                  35.150752
# 95                                  48.952788
# 96                                 179.691200
# 97                                  16.089064
#
#     AREA..MM2..OF..NECROSIS..IN..TISSUE._FFPE  \
# 0                                   52.671736
# 1                                   23.540920
# 2                                   39.170800
# 3                                   44.307036
# 4                                   10.044648
# ..                                        ...
# 93                                  71.635612
# 94                                  10.031736
# 95                                   4.349976
# 96                                  79.234320
# 97                                   2.406924
#
#     AREA..MM2..OF..STROMA..IN..TISSUE._FFPE  \
# 0                                 56.416952
# 1                                102.211936
# 2                                138.627560
# 3                                147.375092
# 4                                 44.979312
# ..                                      ...
# 93                                89.004812
# 94                                22.948752
# 95                                58.916880
# 96                               183.314796
# 97                                25.952164
#
#     AREA..MM2..OF..TUMOR..IN..TISSUE._FFPE  \
# 0                               101.031012
# 1                               243.291716
# 2                               293.995628
# 3                               253.377304
# 4                                94.868436
# ..                                     ...
# 93                              131.815780
# 94                               70.821112
# 95                               79.598512
# 96                              290.652388
# 97                               31.764420
#
#     CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.CANCER.IN.EPITHELIAL_FFPE  \
# 0                                                                6681.995336
# 1                                                                6653.555564
# 2                                                                6641.103506
# 3                                                                5903.440095
# 4                                                                6298.614026
# ..                                                                       ...
# 93                                                               5849.430848
# 94                                                               6923.732594
# 95                                                               6355.898094
# 96                                                               6385.322963
# 97                                                               4930.138750
#
#     CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.CANCER.IN.ESI_0080_FFPE  \
# 0                                                              6068.722504
# 1                                                              6227.367567
# 2                                                              6431.448008
# 3                                                              6007.808063
# 4                                                              5621.425514
# ..                                                                     ...
# 93                                                             5578.271804
# 94                                                             5998.358443
# 95                                                             6468.830562
# 96                                                             6357.834926
# 97                                                             4434.500984
#
#     CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.CANCER.IN.STROMA_FFPE  \
# 0                                                            5635.209993
# 1                                                            5832.030841
# 2                                                            5484.909379
# 3                                                            5381.069213
# 4                                                            5179.342346
# ..                                                                   ...
# 93                                                           4812.196856
# 94                                                           5186.177105
# 95                                                           6701.191267
# 96                                                           5874.068158
# 97                                                           2472.470301
#
#     CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.CANCER.IN.TUMOR_FFPE  \
# 0                                                           6415.732053
# 1                                                           6734.980601
# 2                                                           6555.388437
# 3                                                           6023.511051
# 4                                                           6219.452140
# ..                                                                  ...
# 93                                                          5798.166444
# 94                                                          7016.332174
# 95                                                          6498.534393
# 96                                                          6455.274255
# 97                                                          4887.883312
#
#     CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.FIBROBLAST.IN.EPITHELIAL_FFPE  \
# 0                                                                    5631.244557
# 1                                                                    6289.383036
# 2                                                                    5134.730476
# 3                                                                    5435.350900
# 4                                                                    3581.078568
# ..                                                                           ...
# 93                                                                   3834.319094
# 94                                                                   5264.516818
# 95                                                                   5199.748239
# 96                                                                   5648.279228
# 97                                                                   4380.870442
#
#     ...  DENSITY..LYMPHOCYTE.CELLS..IN..TUMOR._FFPE  \
# 0   ...                                 1802.080335
# 1   ...                                  848.536906
# 2   ...                                 1450.477352
# 3   ...                                 1001.391979
# 4   ...                                  912.516361
# ..  ...                                         ...
# 93  ...                                  936.640515
# 94  ...                                  295.801625
# 95  ...                                 2456.804720
# 96  ...                                 1707.974957
# 97  ...                                  738.027013
#
#     DENSITY..MACROPHAGE.CELLS..IN..EPITHELIAL._FFPE  \
# 0                                         27.771514
# 1                                         77.821216
# 2                                         15.312027
# 3                                        401.925575
# 4                                         77.070906
# ..                                              ...
# 93                                       153.722289
# 94                                       127.798170
# 95                                       510.114482
# 96                                       201.541693
# 97                                       230.031162
#
#     DENSITY..MACROPHAGE.CELLS..IN..ESI_0080._FFPE  \
# 0                                      117.214181
# 1                                      213.051178
# 2                                      126.118124
# 3                                      373.530705
# 4                                      325.794141
# ..                                            ...
# 93                                     459.735752
# 94                                     309.609308
# 95                                     853.822667
# 96                                     410.454157
# 97                                     182.857126
#
#     DENSITY..MACROPHAGE.CELLS..IN..STROMA._FFPE  \
# 0                                    279.543638
# 1                                    485.980424
# 2                                    531.019950
# 3                                    433.960713
# 4                                    726.978661
# ..                                          ...
# 93                                   908.984561
# 94                                   481.159063
# 95                                  1636.780495
# 96                                   869.411545
# 97                                   231.078996
#
#     DENSITY..MACROPHAGE.CELLS..IN..TUMOR._FFPE  \
# 0                                   168.364145
# 1                                   249.297432
# 2                                   258.483436
# 3                                   420.558583
# 4                                   385.207152
# ..                                         ...
# 93                                  663.691403
# 94                                  242.300629
# 95                                 1344.045225
# 96                                  622.767978
# 97                                  230.887263
#
#     DENSITY..PLASMA.CELLS..IN..EPITHELIAL._FFPE  \
# 0                                      7.957133
# 1                                     77.764510
# 2                                     20.506144
# 3                                     57.253522
# 4                                     28.302762
# ..                                          ...
# 93                                    44.661452
# 94                                    18.841770
# 95                                   185.962114
# 96                                    67.730232
# 97                                    74.153650
#
#     DENSITY..PLASMA.CELLS..IN..ESI_0080._FFPE  \
# 0                                  290.830028
# 1                                  468.970817
# 2                                  516.533939
# 3                                  300.334934
# 4                                  202.347826
# ..                                        ...
# 93                                 400.147075
# 94                                 110.381707
# 95                                1067.763495
# 96                                 444.390154
# 97                                  82.416230
#
#     DENSITY..PLASMA.CELLS..IN..STROMA._FFPE  \
# 0                                871.971956
# 1                               1453.978917
# 2                               1832.940001
# 3                                993.037548
# 4                                959.974666
# ..                                      ...
# 93                              1116.310430
# 94                               250.122534
# 95                              1332.894749
# 96                              1118.382174
# 97                                85.773194
#
#     DENSITY..PLASMA.CELLS..IN..TUMOR._FFPE  joined.TIGIT_label
# 0                               490.433571                   0
# 1                               655.940953                   0
# 2                               875.121857                   0
# 3                               601.545591                   0
# 4                               470.029884                   1
# ..                                     ...                 ...
# 93                              768.261584                   0
# 94                               93.785593                   0
# 95                             1034.893718                   1
# 96                              730.377622                   0
# 97                               83.647049                   0
#
# [98 rows x 608 columns]

# %%
# Normalize HIFs and define X, y
X_holdout = holdout_df.iloc[:,:607]
X_normalized_holdout = (X_holdout-X_holdout.mean())/X_holdout.std()
X_normalized_holdout
# Out:
#     AREA..MM2..OF..EPITHELIAL..IN..TISSUE._FFPE  \
# 0                                      0.073592
# 1                                      2.971639
# 2                                      3.400891
# 3                                      1.917830
# 4                                      0.232067
# ..                                          ...
# 93                                     0.019423
# 94                                     0.171479
# 95                                    -0.645392
# 96                                     1.957948
# 97                                    -1.092101
#
#     AREA..MM2..OF..ESI_0080..IN..TISSUE._FFPE  \
# 0                                   -0.042802
# 1                                    2.046526
# 2                                    2.227595
# 3                                    2.837649
# 4                                   -0.481586
# ..                                        ...
# 93                                   0.520093
# 94                                  -0.382404
# 95                                  -0.043229
# 96                                   3.169566
# 97                                  -0.850830
#
#     AREA..MM2..OF..NECROSIS..IN..TISSUE._FFPE  \
# 0                                    1.845840
# 1                                    0.312700
# 2                                    1.135293
# 3                                    1.405610
# 4                                   -0.397602
# ..                                        ...
# 93                                   2.843900
# 94                                  -0.398282
# 95                                  -0.697310
# 96                                   3.243816
# 97                                  -0.799572
#
#     AREA..MM2..OF..STROMA..IN..TISSUE._FFPE  \
# 0                                  0.246177
# 1                                  1.294388
# 2                                  2.127913
# 3                                  2.328137
# 4                                 -0.015622
# ..                                      ...
# 93                                 0.992087
# 94                                -0.519884
# 95                                 0.303398
# 96                                 3.150768
# 97                                -0.451138
#
#     AREA..MM2..OF..TUMOR..IN..TISSUE._FFPE  \
# 0                                 0.194079
# 1                                 2.284979
# 2                                 3.030209
# 3                                 2.433214
# 4                                 0.103504
# ..                                     ...
# 93                                0.646543
# 94                               -0.249936
# 95                               -0.120929
# 96                                2.981071
# 97                               -0.823978
#
#     CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.CANCER.IN.EPITHELIAL_FFPE  \
# 0                                                                   0.431513
# 1                                                                   0.390823
# 2                                                                   0.373008
# 3                                                                  -0.682386
# 4                                                                  -0.117001
# ..                                                                       ...
# 93                                                                 -0.759658
# 94                                                                  0.777372
# 95                                                                 -0.035043
# 96                                                                  0.007056
# 97                                                                 -2.074912
#
#     CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.CANCER.IN.ESI_0080_FFPE  \
# 0                                                                -0.264523
# 1                                                                 0.026964
# 2                                                                 0.401932
# 3                                                                -0.376444
# 4                                                                -1.086365
# ..                                                                     ...
# 93                                                               -1.165654
# 94                                                               -0.393806
# 95                                                                0.470617
# 96                                                                0.266679
# 97                                                               -3.267164
#
#     CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.CANCER.IN.STROMA_FFPE  \
# 0                                                               0.245828
# 1                                                               0.533234
# 2                                                               0.026352
# 3                                                              -0.125280
# 4                                                              -0.419851
# ..                                                                   ...
# 93                                                             -0.955973
# 94                                                             -0.409870
# 95                                                              1.802421
# 96                                                              0.594619
# 97                                                             -4.372546
#
#     CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.CANCER.IN.TUMOR_FFPE  \
# 0                                                             -0.087000
# 1                                                              0.492852
# 2                                                              0.166658
# 3                                                             -0.799392
# 4                                                             -0.443503
# ..                                                                  ...
# 93                                                            -1.208685
# 94                                                             1.003871
# 95                                                             0.063394
# 96                                                            -0.015179
# 97                                                            -2.862034
#
#     CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.FIBROBLAST.IN.EPITHELIAL_FFPE  \
# 0                                                                       0.550957
# 1                                                                       1.374601
# 2                                                                      -0.070417
# 3                                                                       0.305801
# 4                                                                      -2.014773
# ..                                                                           ...
# 93                                                                     -1.697849
# 94                                                                      0.092007
# 95                                                                      0.010951
# 96                                                                      0.572276
# 97                                                                     -1.013854
#
#     ...  DENSITY..LYMPHOCYTE.CELLS..IN..STROMA._FFPE  \
# 0   ...                                     2.070163
# 1   ...                                     0.269106
# 2   ...                                     1.829047
# 3   ...                                    -0.017562
# 4   ...                                     0.197442
# ..  ...                                          ...
# 93  ...                                    -0.259883
# 94  ...                                    -1.063212
# 95  ...                                     1.960462
# 96  ...                                     1.307297
# 97  ...                                    -0.873291
#
#     DENSITY..LYMPHOCYTE.CELLS..IN..TUMOR._FFPE  \
# 0                                     1.557713
# 1                                    -0.067530
# 2                                     0.958432
# 3                                     0.193000
# 4                                     0.041518
# ..                                         ...
# 93                                    0.082636
# 94                                   -1.009626
# 95                                    2.673642
# 96                                    1.397318
# 97                                   -0.255886
#
#     DENSITY..MACROPHAGE.CELLS..IN..EPITHELIAL._FFPE  \
# 0                                         -0.507775
# 1                                         -0.341187
# 2                                         -0.549245
# 3                                          0.737574
# 4                                         -0.343685
# ..                                              ...
# 93                                        -0.088555
# 94                                        -0.174842
# 95                                         1.097674
# 96                                         0.070609
# 97                                         0.165434
#
#     DENSITY..MACROPHAGE.CELLS..IN..ESI_0080._FFPE  \
# 0                                       -1.015373
# 1                                       -0.675170
# 2                                       -0.983766
# 3                                       -0.105499
# 4                                       -0.274955
# ..                                            ...
# 93                                       0.200512
# 94                                      -0.332408
# 95                                       1.599443
# 96                                       0.025572
# 97                                      -0.782353
#
#     DENSITY..MACROPHAGE.CELLS..IN..STROMA._FFPE  \
# 0                                     -1.224906
# 1                                     -0.718101
# 2                                     -0.607529
# 3                                     -0.845810
# 4                                     -0.126447
# ..                                          ...
# 93                                     0.320379
# 94                                    -0.729938
# 95                                     2.107127
# 96                                     0.223227
# 97                                    -1.343887
#
#     DENSITY..MACROPHAGE.CELLS..IN..TUMOR._FFPE  \
# 0                                    -0.945588
# 1                                    -0.694503
# 2                                    -0.666005
# 3                                    -0.163188
# 4                                    -0.272861
# ..                                         ...
# 93                                    0.591098
# 94                                   -0.716210
# 95                                    2.701805
# 96                                    0.464139
# 97                                   -0.751618
#
#     DENSITY..PLASMA.CELLS..IN..EPITHELIAL._FFPE  \
# 0                                     -0.894761
# 1                                      0.337440
# 2                                     -0.673252
# 3                                     -0.024608
# 4                                     -0.535631
# ..                                          ...
# 93                                    -0.246877
# 94                                    -0.702631
# 95                                     2.247283
# 96                                     0.160321
# 97                                     0.273703
#
#     DENSITY..PLASMA.CELLS..IN..ESI_0080._FFPE  \
# 0                                   -0.365753
# 1                                    0.333475
# 2                                    0.520167
# 3                                   -0.328445
# 4                                   -0.713059
# ..                                        ...
# 93                                   0.063332
# 94                                  -1.074039
# 95                                   2.683821
# 96                                   0.236992
# 97                                  -1.183807
#
#     DENSITY..PLASMA.CELLS..IN..STROMA._FFPE  \
# 0                                 -0.013349
# 1                                  1.089577
# 2                                  1.807723
# 3                                  0.216075
# 4                                  0.153420
# ..                                      ...
# 93                                 0.449682
# 94                                -1.191778
# 95                                 0.860118
# 96                                 0.453608
# 97                                -1.503226
#
#     DENSITY..PLASMA.CELLS..IN..TUMOR._FFPE
# 0                                 0.066159
# 1                                 0.576855
# 2                                 1.253168
# 3                                 0.409011
# 4                                 0.003201
# ..                                     ...
# 93                                0.923436
# 94                               -1.157754
# 95                                1.746167
# 96                                0.806540
# 97                               -1.189038
#
# [98 rows x 607 columns]

# %%
y_holdout = holdout_df.iloc[:,607]
print(np.sum(y_holdout))
# Out:
# 30

# %%
X_normalized_holdout = np.array(X_normalized_holdout)
y_pred_probs_1 = optimal_sgl_1.predict_proba(X_normalized_holdout)[1] # predicted probability y = 1
y_pred_probs_2 = optimal_sgl_2.predict_proba(X_normalized_holdout)[1]
y_pred_probs_3 = optimal_sgl_3.predict_proba(X_normalized_holdout)[1]

# %%
# Ensemble (average) predictions
y_pred_probs_ensemble = np.mean(np.array([list(y_pred_probs_1), list(y_pred_probs_2), list(y_pred_probs_3)]), axis=0)
# y_pred_probs_ensemble

# %%
# Hold Out ROC
fpr, tpr, thresholds = roc_curve(y_holdout, y_pred_probs_ensemble, pos_label=1)
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr, color='red', lw=1, label='Hold-Out ROC Curve (Area = %0.3f)' % roc_auc)

# Plot parameters
plt.plot([0, 1], [0, 1], color='black', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
# Generate ROC 95% CI

print("Original ROC area: {:0.3f}".format(roc_auc))

n_bootstraps = 1000
bootstrapped_scores = []

rng = np.random.RandomState(seed)
for i in range(n_bootstraps):
    # bootstrap by sampling with replacement on the prediction indices
    indices = rng.randint(0, len(y_pred_probs_ensemble), len(y_pred_probs_ensemble))
    
    if len(np.unique(y_holdout[indices])) < 2:
        # We need at least one positive and one negative sample for ROC AUC
        # to be defined: reject the sample
        continue

    score = roc_auc_score(y_holdout[indices], y_pred_probs_ensemble[indices])
    bootstrapped_scores.append(score)
    # print("Bootstrap #{} ROC area: {:0.3f}".format(i + 1, score))

plt.hist(bootstrapped_scores, bins=50)
plt.title('Histogram of the bootstrapped ROC AUC scores')
plt.show()

sorted_scores = np.array(bootstrapped_scores)
sorted_scores.sort()

# Computing the lower and upper bound of the 94% confidence interval
confidence_lower = sorted_scores[int(0.025 * len(sorted_scores))]
confidence_upper = sorted_scores[int(0.975 * len(sorted_scores))]
print("Confidence interval for the score: [{:0.3f} - {:0.3}]".format(
    confidence_lower, confidence_upper))
# Out:
# Original ROC area: 0.700
# Confidence interval for the score: [0.587 - 0.807]

# %%
# Hold Out PR Curve
precision, recall, thresholds = precision_recall_curve(y_holdout, y_pred_probs_ensemble, pos_label=1)
prc_auc = auc(recall, precision)
plt.plot(recall, precision, color='red', lw=1, label='Hold-Out PR Curve (Area = %0.3f)' % prc_auc)

# Plot parameters
# plt.plot([0, 1], [0, 1], color='black', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower right")
plt.show()

# %%
# Generate PRC 95% CI
print("Original PRC area: {:0.3f}".format(prc_auc))

n_bootstraps = 1000
bootstrapped_scores = []

rng = np.random.RandomState(seed)
for i in range(n_bootstraps):
    # bootstrap by sampling with replacement on the prediction indices
    indices = rng.randint(0, len(y_pred_probs_ensemble), len(y_pred_probs_ensemble))
    
    if len(np.unique(y_holdout[indices])) < 2:
        # We need at least one positive and one negative sample for ROC AUC
        # to be defined: reject the sample
        continue
    
    precision, recall, thresholds = precision_recall_curve(y_holdout[indices], y_pred_probs_ensemble[indices], pos_label=1)
    score = auc(recall, precision)
    bootstrapped_scores.append(score)
    # print("Bootstrap #{} ROC area: {:0.3f}".format(i + 1, score))

plt.hist(bootstrapped_scores, bins=50)
plt.title('Histogram of the bootstrapped ROC PRC scores')
plt.show()

sorted_scores = np.array(bootstrapped_scores)
sorted_scores.sort()

# Computing the lower and upper bound of the 94% confidence interval
confidence_lower = sorted_scores[int(0.025 * len(sorted_scores))]
confidence_upper = sorted_scores[int(0.975 * len(sorted_scores))]
print("Confidence interval for the score: [{:0.3f} - {:0.3}]".format(
    confidence_lower, confidence_upper))
# Out:
# Original PRC area: 0.510
# Confidence interval for the score: [0.336 - 0.695]
