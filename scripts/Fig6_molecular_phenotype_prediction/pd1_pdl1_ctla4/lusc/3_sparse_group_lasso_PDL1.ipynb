# %%
# Clear workspace
# %reset

# standard packages
from math import e
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pickle as pkl
import os
from sklearn import preprocessing
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import classification_report, roc_curve, auc, roc_auc_score, precision_recall_curve, plot_precision_recall_curve
from scipy.stats import sem
pd.options.display.max_colwidth = 100

# SGL packages
from group_lasso import LogisticGroupLasso
LogisticGroupLasso.LOG_LOSSES = True

# %reload_ext autoreload
# %autoreload 2

working_dir = "~/Desktop/hif2gene"
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
seed = 360
np.random.seed(seed)

# %% [markdown]
# ## Load in HIFs + Clusters

# %%
# Load in HIF dataset with labels
# NAs removed, already converted to patient-level
df = pd.read_csv("{0}/data/genetic_data/PanImmune/datasets/lusc.PDL1.joined.USE.csv".format(working_dir))
df = df.iloc[:,1:]
df
# Out:
#      AREA..MM2..OF..EPITHELIAL..IN..TISSUE._FFPE  \
# 0                                      27.225548
# 1                                      26.648888
# 2                                      52.244148
# 3                                     108.472596
# 4                                      70.275296
# ..                                           ...
# 297                                    52.707784
# 298                                    63.597184
# 299                                    77.987908
# 300                                    39.603288
# 301                                    17.451352
#
#      AREA..MM2..OF..ESI_0080..IN..TISSUE._FFPE  \
# 0                                    20.799096
# 1                                    50.661880
# 2                                    48.311188
# 3                                   139.476556
# 4                                    97.080956
# ..                                         ...
# 297                                  98.824948
# 298                                  70.101124
# 299                                 106.847656
# 300                                  65.279932
# 301                                  20.754456
#
#      AREA..MM2..OF..NECROSIS..IN..TISSUE._FFPE  \
# 0                                    39.167736
# 1                                    21.445668
# 2                                     6.086560
# 3                                    40.770468
# 4                                    39.306184
# ..                                         ...
# 297                                  34.857764
# 298                                  15.685304
# 299                                  57.923272
# 300                                  70.423856
# 301                                   7.431092
#
#      AREA..MM2..OF..STROMA..IN..TISSUE._FFPE  \
# 0                                  85.021760
# 1                                  68.787860
# 2                                  32.802492
# 3                                 102.949824
# 4                                 114.688096
# ..                                       ...
# 297                               189.825556
# 298                                37.812436
# 299                                95.313388
# 300                                49.194160
# 301                                53.174212
#
#      AREA..MM2..OF..TUMOR..IN..TISSUE._FFPE  \
# 0                                112.247308
# 1                                 95.436748
# 2                                 85.046640
# 3                                211.422420
# 4                                184.963392
# ..                                      ...
# 297                              242.533340
# 298                              101.409620
# 299                              173.301296
# 300                               88.797448
# 301                               70.625564
#
#      CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.CANCER.IN.EPITHELIAL_FFPE  \
# 0                                                                 5110.147301
# 1                                                                 5902.693712
# 2                                                                 6767.115806
# 3                                                                 6523.976300
# 4                                                                 6608.847231
# ..                                                                        ...
# 297                                                               5481.887127
# 298                                                               6795.170377
# 299                                                               6331.815097
# 300                                                               6153.814813
# 301                                                               6045.268247
#
#      CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.CANCER.IN.ESI_0080_FFPE  \
# 0                                                               5460.162356
# 1                                                               6204.851490
# 2                                                               6598.832293
# 3                                                               6178.594212
# 4                                                               6825.250651
# ..                                                                      ...
# 297                                                             6206.811690
# 298                                                             6840.896120
# 299                                                             5924.450521
# 300                                                             5975.715902
# 301                                                             5516.059207
#
#      CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.CANCER.IN.STROMA_FFPE  \
# 0                                                             4177.408629
# 1                                                             5660.053414
# 2                                                             5307.369333
# 3                                                             5890.749941
# 4                                                             5889.961751
# ..                                                                    ...
# 297                                                           5773.987957
# 298                                                           5641.014115
# 299                                                           5927.116040
# 300                                                           5641.371296
# 301                                                           4807.185347
#
#      CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.CANCER.IN.TUMOR_FFPE  \
# 0                                                            4758.447487
# 1                                                            5775.615807
# 2                                                            6009.020668
# 3                                                            6504.132661
# 4                                                            6481.346831
# ..                                                                   ...
# 297                                                          6035.985409
# 298                                                          6738.660953
# 299                                                          6345.516412
# 300                                                          6316.010061
# 301                                                          5803.153841
#
#      CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.FIBROBLAST.IN.EPITHELIAL_FFPE  \
# 0                                                                     4499.157584
# 1                                                                     4904.934479
# 2                                                                     5909.048722
# 3                                                                     5345.874892
# 4                                                                     5266.528038
# ..                                                                            ...
# 297                                                                   5217.231719
# 298                                                                   5923.293362
# 299                                                                   5205.901012
# 300                                                                   5052.757209
# 301                                                                   4366.118374
#
#      ...  DENSITY..LYMPHOCYTE.CELLS..IN..TUMOR._FFPE  \
# 0    ...                                  886.586964
# 1    ...                                  510.547572
# 2    ...                                  468.825106
# 3    ...                                  574.111298
# 4    ...                                  724.451463
# ..   ...                                         ...
# 297  ...                                 1314.656368
# 298  ...                                  725.404552
# 299  ...                                  679.498669
# 300  ...                                  897.334347
# 301  ...                                 1226.708788
#
#      DENSITY..MACROPHAGE.CELLS..IN..EPITHELIAL._FFPE  \
# 0                                          98.620604
# 1                                         134.939964
# 2                                         188.499581
# 3                                         600.824562
# 4                                          49.348778
# ..                                               ...
# 297                                        48.171253
# 298                                        13.758471
# 299                                        25.324439
# 300                                        91.760058
# 301                                       105.206748
#
#      DENSITY..MACROPHAGE.CELLS..IN..ESI_0080._FFPE  \
# 0                                       447.423292
# 1                                       619.617748
# 2                                       351.140196
# 3                                       794.534961
# 4                                       395.422558
# ..                                             ...
# 297                                     334.490437
# 298                                      50.270235
# 299                                      84.278873
# 300                                     255.331148
# 301                                     671.614809
#
#      DENSITY..MACROPHAGE.CELLS..IN..STROMA._FFPE  \
# 0                                    1028.560218
# 1                                    1140.259342
# 2                                    1166.801595
# 3                                     880.788295
# 4                                     952.958535
# ..                                           ...
# 297                                   472.354734
# 298                                   167.167225
# 299                                   148.866810
# 300                                   498.778717
# 301                                  1171.658171
#
#      DENSITY..MACROPHAGE.CELLS..IN..TUMOR._FFPE  \
# 0                                    803.003668
# 1                                    859.543119
# 2                                    565.830702
# 3                                    737.149825
# 4                                    609.639555
# ..                                          ...
# 297                                  380.170413
# 298                                   70.959737
# 299                                   93.271086
# 300                                  317.250108
# 301                                  908.141420
#
#      DENSITY..PLASMA.CELLS..IN..EPITHELIAL._FFPE  \
# 0                                      17.153006
# 1                                      33.847566
# 2                                      86.593431
# 3                                      72.267101
# 4                                      22.611075
# ..                                           ...
# 297                                    26.352844
# 298                                     8.113567
# 299                                    56.188198
# 300                                    56.030701
# 301                                    43.320426
#
#      DENSITY..PLASMA.CELLS..IN..ESI_0080._FFPE  \
# 0                                   914.318584
# 1                                   562.138634
# 2                                   288.483901
# 3                                   307.463858
# 4                                   843.028369
# ..                                         ...
# 297                                 291.434507
# 298                                 206.301970
# 299                                 252.537126
# 300                                 437.025578
# 301                                 437.881870
#
#      DENSITY..PLASMA.CELLS..IN..STROMA._FFPE  \
# 0                                1656.599440
# 1                                1058.835091
# 2                                 642.451189
# 3                                 546.839206
# 4                                2217.972125
# ..                                       ...
# 297                               474.862299
# 298                               707.359875
# 299                               635.230803
# 300                               953.629455
# 301                              1230.032332
#
#      DENSITY..PLASMA.CELLS..IN..TUMOR._FFPE  joined.PDL1_data
# 0                               1258.952241                 0
# 1                                772.626913                 1
# 2                                300.987787                 1
# 3                                303.354772                 1
# 4                               1383.863030                 0
# ..                                      ...               ...
# 297                              377.391413                 0
# 298                              268.840372                 0
# 299                              374.653863                 0
# 300                              553.304190                 0
# 301                              936.799599                 1
#
# [302 rows x 608 columns]

# %%
# Normalize HIFs and define X, y
X = df.iloc[:,:607]
X_normalized = (X-X.mean())/X.std()
X_normalized
# Out:
#      AREA..MM2..OF..EPITHELIAL..IN..TISSUE._FFPE  \
# 0                                      -0.556283
# 1                                      -0.571486
# 2                                       0.103347
# 3                                       1.585841
# 4                                       0.578748
# ..                                           ...
# 297                                     0.115571
# 298                                     0.402676
# 299                                     0.782095
# 300                                    -0.229936
# 301                                    -0.813985
#
#      AREA..MM2..OF..ESI_0080..IN..TISSUE._FFPE  \
# 0                                    -0.949580
# 1                                    -0.263648
# 2                                    -0.317642
# 3                                     1.776377
# 4                                     0.802573
# ..                                         ...
# 297                                   0.842632
# 298                                   0.182861
# 299                                   1.026909
# 300                                   0.072121
# 301                                  -0.950605
#
#      AREA..MM2..OF..NECROSIS..IN..TISSUE._FFPE  \
# 0                                     0.597903
# 1                                    -0.061516
# 2                                    -0.633011
# 3                                     0.657539
# 4                                     0.603054
# ..                                         ...
# 297                                   0.437534
# 298                                  -0.275853
# 299                                   1.295776
# 300                                   1.760909
# 301                                  -0.582983
#
#      AREA..MM2..OF..STROMA..IN..TISSUE._FFPE  \
# 0                                   0.620337
# 1                                   0.255454
# 2                                  -0.553377
# 3                                   1.023301
# 4                                   1.287138
# ..                                       ...
# 297                                 2.975977
# 298                                -0.440770
# 299                                 0.851659
# 300                                -0.184947
# 301                                -0.095489
#
#      AREA..MM2..OF..TUMOR..IN..TISSUE._FFPE  \
# 0                                  0.091462
# 1                                 -0.145068
# 2                                 -0.291261
# 3                                  1.486891
# 4                                  1.114603
# ..                                      ...
# 297                                1.924632
# 298                               -0.061028
# 299                                0.950513
# 300                               -0.238485
# 301                               -0.494170
#
#      CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.CANCER.IN.EPITHELIAL_FFPE  \
# 0                                                                   -1.532854
# 1                                                                   -0.490022
# 2                                                                    0.647385
# 3                                                                    0.327462
# 4                                                                    0.439136
# ..                                                                        ...
# 297                                                                 -1.043719
# 298                                                                  0.684300
# 299                                                                  0.074617
# 300                                                                 -0.159596
# 301                                                                 -0.302422
#
#      CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.CANCER.IN.ESI_0080_FFPE  \
# 0                                                                 -1.098407
# 1                                                                 -0.078453
# 2                                                                  0.461158
# 3                                                                 -0.114416
# 4                                                                  0.771269
# ..                                                                      ...
# 297                                                               -0.075768
# 298                                                                0.792698
# 299                                                               -0.462501
# 300                                                               -0.392286
# 301                                                               -1.021849
#
#      CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.CANCER.IN.STROMA_FFPE  \
# 0                                                               -1.816677
# 1                                                                0.131907
# 2                                                               -0.331612
# 3                                                                0.435103
# 4                                                                0.434067
# ..                                                                    ...
# 297                                                              0.281647
# 298                                                              0.106885
# 299                                                              0.482898
# 300                                                              0.107354
# 301                                                             -0.988985
#
#      CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.CANCER.IN.TUMOR_FFPE  \
# 0                                                              -2.366092
# 1                                                              -0.867355
# 2                                                              -0.523447
# 3                                                               0.206071
# 4                                                               0.172498
# ..                                                                   ...
# 297                                                            -0.483716
# 298                                                             0.551635
# 299                                                            -0.027641
# 300                                                            -0.071116
# 301                                                            -0.826780
#
#      CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.FIBROBLAST.IN.EPITHELIAL_FFPE  \
# 0                                                                       -0.885846
# 1                                                                       -0.390341
# 2                                                                        0.835811
# 3                                                                        0.148104
# 4                                                                        0.051211
# ..                                                                            ...
# 297                                                                     -0.008986
# 298                                                                      0.853205
# 299                                                                     -0.022822
# 300                                                                     -0.209830
# 301                                                                     -1.048304
#
#      ...  DENSITY..LYMPHOCYTE.CELLS..IN..STROMA._FFPE  \
# 0    ...                                    -0.599080
# 1    ...                                    -1.187762
# 2    ...                                    -0.827905
# 3    ...                                    -0.937096
# 4    ...                                    -0.646600
# ..   ...                                          ...
# 297  ...                                     0.017756
# 298  ...                                     0.286317
# 299  ...                                    -0.704449
# 300  ...                                    -0.132792
# 301  ...                                    -0.034327
#
#      DENSITY..LYMPHOCYTE.CELLS..IN..TUMOR._FFPE  \
# 0                                     -0.226123
# 1                                     -0.849730
# 2                                     -0.918920
# 3                                     -0.744319
# 4                                     -0.495001
# ..                                          ...
# 297                                    0.483767
# 298                                   -0.493421
# 299                                   -0.569549
# 300                                   -0.208300
# 301                                    0.337919
#
#      DENSITY..MACROPHAGE.CELLS..IN..EPITHELIAL._FFPE  \
# 0                                          -0.300024
# 1                                          -0.190710
# 2                                          -0.029506
# 3                                           1.211512
# 4                                          -0.448323
# ..                                               ...
# 297                                        -0.451867
# 298                                        -0.555443
# 299                                        -0.520631
# 300                                        -0.320673
# 301                                        -0.280201
#
#      DENSITY..MACROPHAGE.CELLS..IN..ESI_0080._FFPE  \
# 0                                         0.108416
# 1                                         0.648256
# 2                                        -0.193437
# 3                                         1.196632
# 4                                        -0.054610
# ..                                             ...
# 297                                      -0.245635
# 298                                      -1.136683
# 299                                      -1.030064
# 300                                      -0.493805
# 301                                       0.811270
#
#      DENSITY..MACROPHAGE.CELLS..IN..STROMA._FFPE  \
# 0                                       0.655204
# 1                                       0.929240
# 2                                       0.994357
# 3                                       0.292669
# 4                                       0.469727
# ..                                           ...
# 297                                    -0.709358
# 298                                    -1.458087
# 299                                    -1.502984
# 300                                    -0.644531
# 301                                     1.006272
#
#      DENSITY..MACROPHAGE.CELLS..IN..TUMOR._FFPE  \
# 0                                      0.872827
# 1                                      1.037833
# 2                                      0.180653
# 3                                      0.680637
# 4                                      0.308506
# ..                                          ...
# 297                                   -0.361184
# 298                                   -1.263594
# 299                                   -1.198480
# 300                                   -0.544812
# 301                                    1.179664
#
#      DENSITY..PLASMA.CELLS..IN..EPITHELIAL._FFPE  \
# 0                                      -0.572615
# 1                                      -0.386526
# 2                                       0.201415
# 3                                       0.041724
# 4                                      -0.511776
# ..                                           ...
# 297                                    -0.470067
# 298                                    -0.673375
# 299                                    -0.137502
# 300                                    -0.139258
# 301                                    -0.280935
#
#      DENSITY..PLASMA.CELLS..IN..ESI_0080._FFPE  \
# 0                                     1.978621
# 1                                     0.664891
# 2                                    -0.355918
# 3                                    -0.285118
# 4                                     1.712688
# ..                                         ...
# 297                                  -0.344912
# 298                                  -0.662480
# 299                                  -0.490010
# 300                                   0.198184
# 301                                   0.201378
#
#      DENSITY..PLASMA.CELLS..IN..STROMA._FFPE  \
# 0                                   1.428148
# 1                                   0.376890
# 2                                  -0.355383
# 3                                  -0.523531
# 4                                   2.415407
# ..                                       ...
# 297                                -0.650114
# 298                                -0.241232
# 299                                -0.368081
# 300                                 0.191870
# 301                                 0.677966
#
#      DENSITY..PLASMA.CELLS..IN..TUMOR._FFPE
# 0                                  2.055382
# 1                                  0.729168
# 2                                 -0.556996
# 3                                 -0.550542
# 4                                  2.396015
# ..                                      ...
# 297                               -0.348643
# 298                               -0.644663
# 299                               -0.356108
# 300                                0.131073
# 301                                1.176869
#
# [302 rows x 607 columns]

# %%
y = df.iloc[:,607]
print(np.sum(y))
# Out:
# 108

# %%
# Load in clusters
clusters = pd.read_csv("{0}/data/hif_clusters/LUSC.hif.clusters.csv".format(working_dir))
print("Number of Clusters: {0}".format(len(set(clusters['x']))))
clusters
# Out:
# Number of Clusters: 25
#                                     Unnamed: 0  x
# 0    AREA (MM2) OF [EPITHELIAL] IN [TISSUE]_HE  1
# 1      AREA (MM2) OF [ESI_0080] IN [TISSUE]_HE  1
# 2      AREA (MM2) OF [NECROSIS] IN [TISSUE]_HE  2
# 3        AREA (MM2) OF [STROMA] IN [TISSUE]_HE  3
# 4         AREA (MM2) OF [TUMOR] IN [TISSUE]_HE  1
# ..                                         ... ..
# 602     TOTAL [MACROPHAGE CELLS] IN [TUMOR]_HE  1
# 603    TOTAL [PLASMA CELLS] IN [EPITHELIAL]_HE  1
# 604      TOTAL [PLASMA CELLS] IN [ESI_0080]_HE  3
# 605        TOTAL [PLASMA CELLS] IN [STROMA]_HE  3
# 606         TOTAL [PLASMA CELLS] IN [TUMOR]_HE  3
#
# [607 rows x 2 columns]

# %% [markdown]
# ## Define Nested CV Parameters

# %%
num_outer_loops = 3 # for estimating generalization error
num_inner_loops = 5 # for hyper-parameter tuning
training_aurocs = [0.0, 0.0, 0.0]
generalization_aurocs = [0.0, 0.0, 0.0]
training_auprcs = [0.0, 0.0, 0.0]
generalization_auprcs = [0.0, 0.0, 0.0]

# Define outer loops (A, B, and C)
X_train_AB, X_train_C, y_train_AB, y_train_C = train_test_split(X_normalized, y, test_size=1/3, random_state=seed, stratify=y)
X_train_A, X_train_B, y_train_A, y_train_B = train_test_split(X_train_AB, y_train_AB, test_size=1/2, random_state=seed, stratify=y_train_AB)

# Verify correctness
print(len(X_train_A), len(y_train_A))
print(len(X_train_B), len(y_train_B))
print(len(X_train_C), len(y_train_C))

print(np.sum(y_train_A)/len(y_train_A))
print(np.sum(y_train_B)/len(y_train_B))
print(np.sum(y_train_C)/len(y_train_C))
# Out:
# 100 100
# 101 101
# 101 101
# 0.36
# 0.3564356435643564
# 0.3564356435643564

# %% [markdown]
# ### Outer Loop 1

# %%
# Define outer loop train and test
X_train_1 = np.array(X_train_A.append(X_train_B))
y_train_1 = np.array(y_train_A.append(y_train_B))
print(X_train_1.shape, y_train_1.shape)

X_test_1 = np.array(X_train_C)
y_test_1 = np.array(y_train_C)
print(X_test_1.shape, y_test_1.shape)
# Out:
# (201, 607) (201,)
# (101, 607) (101,)

# %%
# Define k-folds object
skf = StratifiedKFold(n_splits=num_inner_loops)
skf.get_n_splits(X_train_1, y_train_1)
# Out:
# 5

# %%
# K-folds: hyper-parameter tuning
num_regs = 30
regs = list(np.logspace(-7, -2, num_regs, base=e))
print(regs)

cv_aucs = [] # based on k-folds CV

for reg in regs:
    print(reg)
    k_folds_count = 1
    
    aucs = [] 
    for train_index, test_index in skf.split(X_train_1, y_train_1):
        print(k_folds_count)

        # Define train / test
        X_train, X_test = X_train_1[train_index], X_train_1[test_index]
        y_train, y_test = y_train_1[train_index], y_train_1[test_index]
        print(np.sum(y_train)/len(y_train), np.sum(y_test)/len(y_test))
        print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
        
        # SGL 
        sgl = LogisticGroupLasso(groups=clusters['x'], group_reg=reg*(1/6), l1_reg=reg*(5/6), n_iter=1000, 
                                 tol=1e-6, old_regularisation=False, warm_start=True, random_state=seed)
        sgl.fit(X_train, y_train)

        # Compute AUC on test set
        y_probs_test = sgl.predict_proba(X_test)[1] # predicted probability y = 1
        fpr, tpr, thresholds = roc_curve(y_test, y_probs_test, pos_label=1)
        roc_auc = auc(fpr, tpr)
        aucs.append(roc_auc)

        k_folds_count += 1
    
    print(aucs)
    cv_aucs.append(np.mean(np.array(aucs)))

# %%
# Plot CV AUCs
print(cv_aucs)
plt.figure(figsize=(12,6))
plt.plot(np.log(regs), cv_aucs)
plt.grid(axis='both')
plt.show()

max_reg = regs[np.argmax(np.array(cv_aucs))]
print(max_reg, np.log(max_reg))
# Out:
# [0.5425245421245422, 0.5436395604395605, 0.5463340659340659, 0.5468263736263737, 0.5484542124542124, 0.5506520146520146, 0.5505538461538462, 0.5651413919413919, 0.5683443223443223, 0.5683150183150183, 0.5540498168498169, 0.5836395604395606, 0.5939135531135531, 0.5889362637362636, 0.5705772893772894, 0.5783589743589743, 0.5986461538461538, 0.5978695970695972, 0.6045172161172162, 0.6051003663003662, 0.6073919413919414, 0.600887912087912, 0.5755575091575091, 0.4938461538461539, 0.49333333333333335, 0.5, 0.5, 0.5, 0.5, 0.5]
# 0.02867515708310305 -3.5517241379310343

# %%
# Choose best regularization parameter based on CV plot
optimal_log_reg = -3.75
optimal_reg = np.exp(optimal_log_reg)
print(optimal_log_reg, optimal_reg)

# Fit "optimal model"
optimal_sgl = LogisticGroupLasso(groups=clusters['x'], group_reg=optimal_reg*(1/6), l1_reg=optimal_reg*(5/6), n_iter=1000, 
                         tol=1e-6, old_regularisation=False, warm_start=False, random_state=seed)
optimal_sgl.fit(X_train_1, y_train_1)

# Store optimal model
optimal_sgl_1 = optimal_sgl

# %%
# Plot Train and Test ROCs
y_pred_probs_train = optimal_sgl.predict_proba(X_train_1)[1] # predicted probability y = 1
y_pred_probs_test = optimal_sgl.predict_proba(X_test_1)[1]

# Train
fpr, tpr, thresholds = roc_curve(y_train_1, y_pred_probs_train, pos_label=1)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='blue', lw=1, label='Train ROC Curve (Area = %0.3f)' % roc_auc)
training_aurocs[0] = roc_auc

# Test
fpr, tpr, thresholds = roc_curve(y_test_1, y_pred_probs_test, pos_label=1)
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr, color='red', lw=1, label='Test ROC Curve (Area = %0.3f)' % roc_auc)
generalization_aurocs[0] = roc_auc

# Plot parameters
plt.plot([0, 1], [0, 1], color='black', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
# Plot Train and Test PR Curves

# Train
precision, recall, thresholds = precision_recall_curve(y_train_1, y_pred_probs_train, pos_label=1)
prc_auc = auc(recall, precision)
plt.figure()
plt.plot(recall, precision, color='blue', lw=1, label='Train PR Curve (Area = %0.3f)' % prc_auc)
training_auprcs[0] = prc_auc

# Test
precision, recall, thresholds = precision_recall_curve(y_test_1, y_pred_probs_test, pos_label=1)
prc_auc = auc(recall, precision)
plt.plot(recall, precision, color='red', lw=1, label='Test PR Curve (Area = %0.3f)' % prc_auc)
generalization_auprcs[0] = prc_auc

# Plot parameters
# plt.plot([0, 1], [0, 1], color='black', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower right")
plt.show()

# %%
# Save model coefficients
sparsity_mask = optimal_sgl.sparsity_mask_
print("Number of chosen variables: {0}".format(sparsity_mask.sum()))

betas_1 = optimal_sgl.coef_[:, 1] - optimal_sgl.coef_[:, 0]
betas_1[~sparsity_mask] = 0.0 # if not included in model, set to 0
betas_df = pd.DataFrame({
    "HIF": clusters['Unnamed: 0'],
    "Beta": betas_1, 
    "Cluster": clusters['x'],
    "Included (T/F)": sparsity_mask}
)
betas_df = betas_df[betas_df['Included (T/F)'] == True][['HIF', 'Beta', 'Cluster']]
betas_df.sort_values(by="Beta", ascending=False)
# Out:
# Number of chosen variables: 300
#                                                                                                     HIF  \
# 95                              CELL CLUSTERING PROPERTIES: CLUSTER SIZE MEAN OF FIBROBLAST IN TUMOR_HE
# 155                CELL CLUSTERING PROPERTIES: WITHIN CLUSTER DISPERSION MEAN OF FIBROBLAST IN TUMOR_HE
# 192                                          COUNT PROP [CANCER CELLS] IN [[ESI_0080] OVER [STROMA]]_HE
# 175  CELL CLUSTERING PROPERTIES: WITHIN CLUSTER DISPERSION STANDARD DEVIATION OF FIBROBLAST IN TUMOR_HE
# 154               CELL CLUSTERING PROPERTIES: WITHIN CLUSTER DISPERSION MEAN OF FIBROBLAST IN STROMA_HE
# ..                                                                                                  ...
# 212                                  COUNT PROP [LYMPHOCYTE CELLS] IN [[EPITHELIAL] OVER [ESI_0080]]_HE
# 471                                                      REGION PROPERTIES: LACUNARITY OF EPITHELIAL_HE
# 472                                                        REGION PROPERTIES: LACUNARITY OF ESI_0080_HE
# 81           CELL CLUSTERING PROPERTIES: CLUSTER EXTENT STANDARD DEVIATION OF MACROPHAGE IN ESI_0080_HE
# 198                                           COUNT PROP [CANCER CELLS] IN [[TUMOR] OVER [ESI_0080]]_HE
#
#          Beta  Cluster
# 95   0.164054        8
# 155  0.157537        8
# 192  0.111470        7
# 175  0.074596        8
# 154  0.055075        8
# ..        ...      ...
# 212 -0.048927       11
# 471 -0.082670       23
# 472 -0.099039       23
# 81  -0.145492        6
# 198 -0.494007        6
#
# [300 rows x 3 columns]

# %% [markdown]
# ### Outer Loop 2

# %%
# Define outer loop train and test
X_train_2 = np.array(X_train_A.append(X_train_C))
y_train_2 = np.array(y_train_A.append(y_train_C))
print(X_train_2.shape, y_train_2.shape)

X_test_2 = np.array(X_train_B)
y_test_2 = np.array(y_train_B)
print(X_test_2.shape, y_test_2.shape)
# Out:
# (201, 607) (201,)
# (101, 607) (101,)

# %%
# Define k-folds object
skf = StratifiedKFold(n_splits=num_inner_loops)
skf.get_n_splits(X_train_2, y_train_2)
# Out:
# 5

# %%
# K-folds: hyper-parameter tuning
num_regs = 30
regs = list(np.logspace(-6.0, -3.0, num_regs, base=e))
print(regs)

cv_aucs = [] # based on k-folds CV

for reg in regs:
    print(reg)
    k_folds_count = 1
    
    aucs = [] 
    for train_index, test_index in skf.split(X_train_2, y_train_2):
        print(k_folds_count)

        # Define train / test
        X_train, X_test = X_train_2[train_index], X_train_2[test_index]
        y_train, y_test = y_train_2[train_index], y_train_2[test_index]
        print(np.sum(y_train)/len(y_train), np.sum(y_test)/len(y_test))
        print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
        
        # SGL 
        sgl = LogisticGroupLasso(groups=clusters['x'], group_reg=reg*(1/6), l1_reg=reg*(5/6), n_iter=1000, 
                                 tol=1e-6, old_regularisation=False, warm_start=True, random_state=seed)
        sgl.fit(X_train, y_train)

        # Compute AUC on test set
        y_probs_test = sgl.predict_proba(X_test)[1] # predicted probability y = 1
        fpr, tpr, thresholds = roc_curve(y_test, y_probs_test, pos_label=1)
        roc_auc = auc(fpr, tpr)
        aucs.append(roc_auc)

        k_folds_count += 1
    
    print(aucs)
    cv_aucs.append(np.mean(np.array(aucs)))

# %%
# Plot CV AUCs
print(cv_aucs)
plt.figure(figsize=(12,6))
plt.plot(np.log(regs), cv_aucs)
plt.grid(axis='both')
plt.show()

max_reg = regs[np.argmax(np.array(cv_aucs))]
print(max_reg, np.log(max_reg))
# Out:
# [0.5422534798534798, 0.5375076923076922, 0.5364937728937729, 0.5349509157509157, 0.5317069597069597, 0.5306974358974359, 0.5307018315018315, 0.5320043956043955, 0.5530725274725274, 0.523258608058608, 0.5320776556776556, 0.5222578754578755, 0.5191721611721611, 0.5219882783882783, 0.5259208791208791, 0.5281230769230769, 0.5274886446886446, 0.5328908424908425, 0.5448864468864468, 0.5469421245421244, 0.5486197802197802, 0.5476380952380951, 0.5439487179487179, 0.5500175824175824, 0.5434197802197802, 0.534115750915751, 0.5218666666666666, 0.5120967032967033, 0.5, 0.5]
# 0.0056708639931691346 -5.172413793103448

# %%
# Choose best regularization parameter based on CV plot
optimal_log_reg = -3.75
optimal_reg = np.exp(optimal_log_reg)
print(optimal_log_reg, optimal_reg)

# Fit "optimal model"
optimal_sgl = LogisticGroupLasso(groups=clusters['x'], group_reg=optimal_reg*(1/6), l1_reg=optimal_reg*(5/6), n_iter=1000, 
                         tol=1e-6, old_regularisation=False, warm_start=False, random_state=seed)
optimal_sgl.fit(X_train_2, y_train_2)

# Store optimal model
optimal_sgl_2 = optimal_sgl

# %%
# Plot Train and Test ROCs
y_pred_probs_train = optimal_sgl.predict_proba(X_train_2)[1] # predicted probability y = 1
y_pred_probs_test = optimal_sgl.predict_proba(X_test_2)[1]

# Train
fpr, tpr, thresholds = roc_curve(y_train_2, y_pred_probs_train, pos_label=1)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='blue', lw=1, label='Train ROC Curve (Area = %0.3f)' % roc_auc)
training_aurocs[1] = roc_auc

# Test
fpr, tpr, thresholds = roc_curve(y_test_2, y_pred_probs_test, pos_label=1)
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr, color='red', lw=1, label='Test ROC Curve (Area = %0.3f)' % roc_auc)
generalization_aurocs[1] = roc_auc

# Plot parameters
plt.plot([0, 1], [0, 1], color='black', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
# Plot Train and Test PR Curves

# Train
precision, recall, thresholds = precision_recall_curve(y_train_2, y_pred_probs_train, pos_label=1)
prc_auc = auc(recall, precision)
plt.figure()
plt.plot(recall, precision, color='blue', lw=1, label='Train PR Curve (Area = %0.3f)' % prc_auc)
training_auprcs[1] = prc_auc

# Test
precision, recall, thresholds = precision_recall_curve(y_test_2, y_pred_probs_test, pos_label=1)
prc_auc = auc(recall, precision)
plt.plot(recall, precision, color='red', lw=1, label='Test PR Curve (Area = %0.3f)' % prc_auc)
generalization_auprcs[1] = prc_auc

# Plot parameters
# plt.plot([0, 1], [0, 1], color='black', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower right")
plt.show()

# %%
# Save model coefficients
sparsity_mask = optimal_sgl.sparsity_mask_
print("Number of chosen variables: {0}".format(sparsity_mask.sum()))

betas_2 = optimal_sgl.coef_[:, 1] - optimal_sgl.coef_[:, 0]
betas_2[~sparsity_mask] = 0.0 # if not included in model, set to 0
betas_df = pd.DataFrame({
    "HIF": clusters['Unnamed: 0'],
    "Beta": betas_2, 
    "Cluster": clusters['x'],
    "Included (T/F)": sparsity_mask}
)
betas_df = betas_df[betas_df['Included (T/F)'] == True][['HIF', 'Beta', 'Cluster']]
betas_df.sort_values(by="Beta", ascending=False)
# Out:
# Number of chosen variables: 23
#                                                                                                      HIF  \
# 62                            CELL CLUSTERING PROPERTIES: CLUSTER EXTENT MEAN OF MACROPHAGE IN STROMA_HE
# 122               CELL CLUSTERING PROPERTIES: CLUSTER SIZE STANDARD DEVIATION OF MACROPHAGE IN STROMA_HE
# 182  CELL CLUSTERING PROPERTIES: WITHIN CLUSTER DISPERSION STANDARD DEVIATION OF MACROPHAGE IN STROMA_HE
# 556                                     REGION PROPERTIES: TOTAL MAJOR AXIS LENGTH (MM) OF EPITHELIAL_HE
# 63                             CELL CLUSTERING PROPERTIES: CLUSTER EXTENT MEAN OF MACROPHAGE IN TUMOR_HE
# 411                                                             DENSITY [MACROPHAGE CELLS] IN [TUMOR]_HE
# 305  COUNT PROP [[[CANCER CELLS] SELECTED BY [MACROPHAGE_RADIUS_80]] OVER [[CANCER CELLS] SELECTED BY...
# 409                                                          DENSITY [MACROPHAGE CELLS] IN [ESI_0080]_HE
# 224                                   COUNT PROP [MACROPHAGE CELLS] IN [[EPITHELIAL] OVER [ESI_0080]]_HE
# 273  COUNT PROP [[[CANCER CELLS] SELECTED BY [FIBROBLAST_RADIUS_80]] OVER [[CANCER CELLS] SELECTED BY...
# 321  COUNT PROP [[[CANCER CELLS] SELECTED BY [PLASMA_RADIUS_80]] OVER [[CANCER CELLS] SELECTED BY [FI...
# 313  COUNT PROP [[[CANCER CELLS] SELECTED BY [MACROPHAGE_RADIUS_80]] OVER [[CANCER CELLS] SELECTED BY...
# 135                             CELL CLUSTERING PROPERTIES: NUMBER OF CLUSTERS OF FIBROBLAST IN TUMOR_HE
# 552                                            REGION PROPERTIES: TOTAL FILLED AREA (MM2) OF ESI_0080_HE
# 161              CELL CLUSTERING PROPERTIES: WITHIN CLUSTER DISPERSION MEAN OF MACROPHAGE IN ESI_0080_HE
# 101                           CELL CLUSTERING PROPERTIES: CLUSTER SIZE MEAN OF MACROPHAGE IN ESI_0080_HE
# 181  CELL CLUSTERING PROPERTIES: WITHIN CLUSTER DISPERSION STANDARD DEVIATION OF MACROPHAGE IN ESI_00...
# 559                                         REGION PROPERTIES: TOTAL MAJOR AXIS LENGTH (MM) OF STROMA_HE
# 121             CELL CLUSTERING PROPERTIES: CLUSTER SIZE STANDARD DEVIATION OF MACROPHAGE IN ESI_0080_HE
# 33                      CELL CLUSTERING PROPERTIES: CALINSKI-HARABASZ INDEX OF FIBROBLAST IN ESI_0080_HE
# 293  COUNT PROP [[[CANCER CELLS] SELECTED BY [LYMPHOCYTE_RADIUS_80]] OVER [[CANCER CELLS] SELECTED BY...
# 198                                            COUNT PROP [CANCER CELLS] IN [[TUMOR] OVER [ESI_0080]]_HE
# 309  COUNT PROP [[[CANCER CELLS] SELECTED BY [MACROPHAGE_RADIUS_80]] OVER [[CANCER CELLS] SELECTED BY...
#
#          Beta  Cluster
# 62   0.243164       13
# 122  0.079121       13
# 182  0.036747       13
# 556  0.025498       22
# 63   0.010448       13
# 411  0.007711       13
# 305  0.003961       13
# 409  0.003096       13
# 224 -0.000081       10
# 273 -0.000089       17
# 321 -0.001002       12
# 313 -0.001348       10
# 135 -0.001497        1
# 552 -0.001780        1
# 161 -0.004302       13
# 101 -0.004863       13
# 181 -0.005949       13
# 559 -0.006010       22
# 121 -0.006613       13
# 33  -0.009613        1
# 293 -0.075194       13
# 198 -0.102430        6
# 309 -0.116575       13

# %% [markdown]
# ### Outer Loop 3

# %%
# Define outer loop train and test
X_train_3 = np.array(X_train_B.append(X_train_C))
y_train_3 = np.array(y_train_B.append(y_train_C))
print(X_train_3.shape, y_train_3.shape)

X_test_3 = np.array(X_train_A)
y_test_3 = np.array(y_train_A)
print(X_test_3.shape, y_test_3.shape)
# Out:
# (202, 607) (202,)
# (100, 607) (100,)

# %%
# Define k-folds object
skf = StratifiedKFold(n_splits=num_inner_loops)
skf.get_n_splits(X_train_3, y_train_3)
# Out:
# 5

# %%
# K-folds: hyper-parameter tuning
num_regs = 30
regs = list(np.logspace(-6.0, -3.0, num_regs, base=e))
print(regs)

cv_aucs = [] # based on k-folds CV

for reg in regs:
    print(reg)
    k_folds_count = 1
    
    aucs = [] 
    for train_index, test_index in skf.split(X_train_3, y_train_3):
        print(k_folds_count)

        # Define train / test
        X_train, X_test = X_train_3[train_index], X_train_3[test_index]
        y_train, y_test = y_train_3[train_index], y_train_3[test_index]
        print(np.sum(y_train)/len(y_train), np.sum(y_test)/len(y_test))
        print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
        
        # SGL 
        sgl = LogisticGroupLasso(groups=clusters['x'], group_reg=reg*(1/6), l1_reg=reg*(5/6), n_iter=1000, 
                                 tol=1e-6, old_regularisation=False, warm_start=True, random_state=seed)
        sgl.fit(X_train, y_train)

        # Compute AUC on test set
        y_probs_test = sgl.predict_proba(X_test)[1] # predicted probability y = 1
        fpr, tpr, thresholds = roc_curve(y_test, y_probs_test, pos_label=1)
        roc_auc = auc(fpr, tpr)
        aucs.append(roc_auc)

        k_folds_count += 1
    
    print(aucs)
    cv_aucs.append(np.mean(np.array(aucs)))

# %%
# Plot CV AUCs
print(cv_aucs)
plt.figure(figsize=(12,6))
plt.plot(np.log(regs), cv_aucs)
plt.grid(axis='both')
plt.show()

max_reg = regs[np.argmax(np.array(cv_aucs))]
print(max_reg, np.log(max_reg))
# Out:
# [0.628861970913184, 0.6002464381979207, 0.6284386126003376, 0.6172842925268801, 0.6214943277746512, 0.6273959598353129, 0.6254816208050709, 0.6119074375759012, 0.6248591866354669, 0.6377051923817423, 0.6338829714759634, 0.5868497378632149, 0.6412806788898433, 0.6492841740469772, 0.6387357601966767, 0.6063488936939072, 0.6302116347264596, 0.6533377862030154, 0.6481501732768579, 0.6508866443529517, 0.6621109860489913, 0.6519447587452978, 0.6297309617606114, 0.6364373981813335, 0.6212116051064838, 0.6443538994698024, 0.6504949794141168, 0.6514793993068926, 0.652501229228992, 0.6442629069044163]
# 0.019623362019752715 -3.93103448275862

# %%
# Choose best regularization parameter based on CV plot
optimal_log_reg = -3.75
optimal_reg = np.exp(optimal_log_reg)
print(optimal_log_reg, optimal_reg)

# Fit "optimal model"
optimal_sgl = LogisticGroupLasso(groups=clusters['x'], group_reg=optimal_reg*(1/6), l1_reg=optimal_reg*(5/6), n_iter=1000, 
                         tol=1e-6, old_regularisation=False, warm_start=False, random_state=seed)
optimal_sgl.fit(X_train_3, y_train_3)

# Store optimal model
optimal_sgl_3 = optimal_sgl

# %%
# Plot Train and Test ROCs
y_pred_probs_train = optimal_sgl.predict_proba(X_train_3)[1] # predicted probability y = 1
y_pred_probs_test = optimal_sgl.predict_proba(X_test_3)[1]

# Train
fpr, tpr, thresholds = roc_curve(y_train_3, y_pred_probs_train, pos_label=1)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='blue', lw=1, label='Train ROC Curve (Area = %0.3f)' % roc_auc)
training_aurocs[2] = roc_auc

# Test
fpr, tpr, thresholds = roc_curve(y_test_3, y_pred_probs_test, pos_label=1)
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr, color='red', lw=1, label='Test ROC Curve (Area = %0.3f)' % roc_auc)
generalization_aurocs[2] = roc_auc

# Plot parameters
plt.plot([0, 1], [0, 1], color='black', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
# Plot Train and Test PR Curves

# Train
precision, recall, thresholds = precision_recall_curve(y_train_3, y_pred_probs_train, pos_label=1)
prc_auc = auc(recall, precision)
plt.figure()
plt.plot(recall, precision, color='blue', lw=1, label='Train PR Curve (Area = %0.3f)' % prc_auc)
training_auprcs[2] = prc_auc

# Test
precision, recall, thresholds = precision_recall_curve(y_test_3, y_pred_probs_test, pos_label=1)
prc_auc = auc(recall, precision)
plt.plot(recall, precision, color='red', lw=1, label='Test PR Curve (Area = %0.3f)' % prc_auc)
generalization_auprcs[2] = prc_auc

# Plot parameters
# plt.plot([0, 1], [0, 1], color='black', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower right")
plt.show()

# %%
# Save model coefficients
sparsity_mask = optimal_sgl.sparsity_mask_
print("Number of chosen variables: {0}".format(sparsity_mask.sum()))

betas_3 = optimal_sgl.coef_[:, 1] - optimal_sgl.coef_[:, 0]
betas_3[~sparsity_mask] = 0.0 # if not included in model, set to 0
betas_df = pd.DataFrame({
    "HIF": clusters['Unnamed: 0'],
    "Beta": betas_3, 
    "Cluster": clusters['x'],
    "Included (T/F)": sparsity_mask}
)
betas_df = betas_df[betas_df['Included (T/F)'] == True][['HIF', 'Beta', 'Cluster']]
betas_df.sort_values(by="Beta", ascending=False)
# Out:
# Number of chosen variables: 291
#                                                                                                      HIF  \
# 550                                                    REGION PROPERTIES: TOTAL EULER NUMBER OF TUMOR_HE
# 8                                 CELL CLUSTERING PROPERTIES: BALL-HALL INDEX OF CANCER IN EPITHELIAL_HE
# 176  CELL CLUSTERING PROPERTIES: WITHIN CLUSTER DISPERSION STANDARD DEVIATION OF LYMPHOCYTE IN EPITHE...
# 116           CELL CLUSTERING PROPERTIES: CLUSTER SIZE STANDARD DEVIATION OF LYMPHOCYTE IN EPITHELIAL_HE
# 6                                                     AREA PROP [[ESI_0080] OVER [TUMOR]] IN [TISSUE]_HE
# ..                                                                                                   ...
# 241                                            COUNT PROP [PLASMA CELLS] IN [[ESI_0080] OVER [TUMOR]]_HE
# 300  COUNT PROP [[[CANCER CELLS] SELECTED BY [MACROPHAGE_RADIUS_80]] OVER [CANCER CELLS]] IN [EPITHEL...
# 223                                          COUNT PROP [LYMPHOCYTE CELLS] IN [[TUMOR] OVER [STROMA]]_HE
# 69                CELL CLUSTERING PROPERTIES: CLUSTER EXTENT STANDARD DEVIATION OF CANCER IN ESI_0080_HE
# 212                                   COUNT PROP [LYMPHOCYTE CELLS] IN [[EPITHELIAL] OVER [ESI_0080]]_HE
#
#          Beta  Cluster
# 550  0.246160       25
# 8    0.228866        5
# 176  0.184922       11
# 116  0.160466       11
# 6    0.105026        5
# ..        ...      ...
# 241 -0.024014        5
# 300 -0.058122       10
# 223 -0.138196       11
# 69  -0.227843        5
# 212 -0.266769       11
#
# [291 rows x 3 columns]

# %% [markdown]
# ## Compute Ensemble Model

# %%
betas_df = pd.DataFrame({
    "HIF": clusters['Unnamed: 0'],
    "Beta_1": betas_1, 
    "Beta_2": betas_2,
    "Beta_3": betas_3,
    "Cluster": clusters['x']
    }
)
betas_df['Beta'] = (betas_df['Beta_1'] + betas_df['Beta_2'] + betas_df['Beta_3'])/3.0
betas_df.sort_values(by="Beta", ascending=False)
# Out:
#                                                                                                      HIF  \
# 62                            CELL CLUSTERING PROPERTIES: CLUSTER EXTENT MEAN OF MACROPHAGE IN STROMA_HE
# 550                                                    REGION PROPERTIES: TOTAL EULER NUMBER OF TUMOR_HE
# 8                                 CELL CLUSTERING PROPERTIES: BALL-HALL INDEX OF CANCER IN EPITHELIAL_HE
# 176  CELL CLUSTERING PROPERTIES: WITHIN CLUSTER DISPERSION STANDARD DEVIATION OF LYMPHOCYTE IN EPITHE...
# 95                               CELL CLUSTERING PROPERTIES: CLUSTER SIZE MEAN OF FIBROBLAST IN TUMOR_HE
# ..                                                                                                   ...
# 81            CELL CLUSTERING PROPERTIES: CLUSTER EXTENT STANDARD DEVIATION OF MACROPHAGE IN ESI_0080_HE
# 223                                          COUNT PROP [LYMPHOCYTE CELLS] IN [[TUMOR] OVER [STROMA]]_HE
# 69                CELL CLUSTERING PROPERTIES: CLUSTER EXTENT STANDARD DEVIATION OF CANCER IN ESI_0080_HE
# 212                                   COUNT PROP [LYMPHOCYTE CELLS] IN [[EPITHELIAL] OVER [ESI_0080]]_HE
# 198                                            COUNT PROP [CANCER CELLS] IN [[TUMOR] OVER [ESI_0080]]_HE
#
#        Beta_1    Beta_2    Beta_3  Cluster      Beta
# 62   0.006880  0.243164  0.041219       13  0.097088
# 550  0.000000  0.000000  0.246160       25  0.082053
# 8    0.006676  0.000000  0.228866        5  0.078514
# 176  0.000000  0.000000  0.184922       11  0.061641
# 95   0.164054  0.000000  0.018565        8  0.060873
# ..        ...       ...       ...      ...       ...
# 81  -0.145492  0.000000  0.000000        6 -0.048497
# 223 -0.030263  0.000000 -0.138196       11 -0.056153
# 69  -0.007925  0.000000 -0.227843        5 -0.078589
# 212 -0.048927  0.000000 -0.266769       11 -0.105232
# 198 -0.494007 -0.102430 -0.016446        6 -0.204294
#
# [607 rows x 6 columns]

# %% [markdown]
# ## Compute Final Train / Test Metrics

# %%
print(training_aurocs)
print(np.mean(training_aurocs), np.std(training_aurocs))
# Out:
# [0.6674203273040483, 0.6670973298880275, 0.6162393162393163]
# 0.6502523244771307 0.024051190252901734

# %%
print(generalization_aurocs)
print(np.mean(generalization_aurocs), np.std(generalization_aurocs))
# Out:
# [0.535042735042735, 0.5132478632478632, 0.6644965277777777]
# 0.5709290420227919 0.06675782052574222

# %%
print(training_auprcs)
print(np.mean(training_auprcs), np.std(training_auprcs))
# Out:
# [0.5126876869100305, 0.5465773210292216, 0.49532004787767375]
# 0.518195018605642 0.021284971843019702

# %%
print(generalization_auprcs)
print(np.mean(generalization_auprcs), np.std(generalization_auprcs))
# Out:
# [0.3643719859826726, 0.3669804739221474, 0.4733437331201549]
# 0.4015653976749916 0.050766118174699816

# %% [markdown]
# ## Evaluate Hold-Out Set

# %%
holdout_df = pd.read_csv("{0}/data/genetic_data/PanImmune/datasets/lusc.PDL1.joined.HOLDOUT.csv".format(working_dir))
holdout_df = holdout_df.iloc[:,1:]
holdout_df
# Out:
#     AREA..MM2..OF..EPITHELIAL..IN..TISSUE._FFPE  \
# 0                                     44.614060
# 1                                    141.079780
# 2                                    155.368068
# 3                                    106.002212
# 4                                     49.889124
# ..                                          ...
# 93                                    42.810968
# 94                                    47.872360
# 95                                    20.681632
# 96                                   107.337592
# 97                                     5.812256
#
#     AREA..MM2..OF..ESI_0080..IN..TISSUE._FFPE  \
# 0                                   48.970184
# 1                                  133.991280
# 2                                  141.359540
# 3                                  166.184464
# 4                                   31.114740
# ..                                        ...
# 93                                  71.876072
# 94                                  35.150752
# 95                                  48.952788
# 96                                 179.691200
# 97                                  16.089064
#
#     AREA..MM2..OF..NECROSIS..IN..TISSUE._FFPE  \
# 0                                   52.671736
# 1                                   23.540920
# 2                                   39.170800
# 3                                   44.307036
# 4                                   10.044648
# ..                                        ...
# 93                                  71.635612
# 94                                  10.031736
# 95                                   4.349976
# 96                                  79.234320
# 97                                   2.406924
#
#     AREA..MM2..OF..STROMA..IN..TISSUE._FFPE  \
# 0                                 56.416952
# 1                                102.211936
# 2                                138.627560
# 3                                147.375092
# 4                                 44.979312
# ..                                      ...
# 93                                89.004812
# 94                                22.948752
# 95                                58.916880
# 96                               183.314796
# 97                                25.952164
#
#     AREA..MM2..OF..TUMOR..IN..TISSUE._FFPE  \
# 0                               101.031012
# 1                               243.291716
# 2                               293.995628
# 3                               253.377304
# 4                                94.868436
# ..                                     ...
# 93                              131.815780
# 94                               70.821112
# 95                               79.598512
# 96                              290.652388
# 97                               31.764420
#
#     CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.CANCER.IN.EPITHELIAL_FFPE  \
# 0                                                                6681.995336
# 1                                                                6653.555564
# 2                                                                6641.103506
# 3                                                                5903.440095
# 4                                                                6298.614026
# ..                                                                       ...
# 93                                                               5849.430848
# 94                                                               6923.732594
# 95                                                               6355.898094
# 96                                                               6385.322963
# 97                                                               4930.138750
#
#     CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.CANCER.IN.ESI_0080_FFPE  \
# 0                                                              6068.722504
# 1                                                              6227.367567
# 2                                                              6431.448008
# 3                                                              6007.808063
# 4                                                              5621.425514
# ..                                                                     ...
# 93                                                             5578.271804
# 94                                                             5998.358443
# 95                                                             6468.830562
# 96                                                             6357.834926
# 97                                                             4434.500984
#
#     CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.CANCER.IN.STROMA_FFPE  \
# 0                                                            5635.209993
# 1                                                            5832.030841
# 2                                                            5484.909379
# 3                                                            5381.069213
# 4                                                            5179.342346
# ..                                                                   ...
# 93                                                           4812.196856
# 94                                                           5186.177105
# 95                                                           6701.191267
# 96                                                           5874.068158
# 97                                                           2472.470301
#
#     CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.CANCER.IN.TUMOR_FFPE  \
# 0                                                           6415.732053
# 1                                                           6734.980601
# 2                                                           6555.388437
# 3                                                           6023.511051
# 4                                                           6219.452140
# ..                                                                  ...
# 93                                                          5798.166444
# 94                                                          7016.332174
# 95                                                          6498.534393
# 96                                                          6455.274255
# 97                                                          4887.883312
#
#     CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.FIBROBLAST.IN.EPITHELIAL_FFPE  \
# 0                                                                    5631.244557
# 1                                                                    6289.383036
# 2                                                                    5134.730476
# 3                                                                    5435.350900
# 4                                                                    3581.078568
# ..                                                                           ...
# 93                                                                   3834.319094
# 94                                                                   5264.516818
# 95                                                                   5199.748239
# 96                                                                   5648.279228
# 97                                                                   4380.870442
#
#     ...  DENSITY..LYMPHOCYTE.CELLS..IN..TUMOR._FFPE  \
# 0   ...                                 1802.080335
# 1   ...                                  848.536906
# 2   ...                                 1450.477352
# 3   ...                                 1001.391979
# 4   ...                                  912.516361
# ..  ...                                         ...
# 93  ...                                  936.640515
# 94  ...                                  295.801625
# 95  ...                                 2456.804720
# 96  ...                                 1707.974957
# 97  ...                                  738.027013
#
#     DENSITY..MACROPHAGE.CELLS..IN..EPITHELIAL._FFPE  \
# 0                                         27.771514
# 1                                         77.821216
# 2                                         15.312027
# 3                                        401.925575
# 4                                         77.070906
# ..                                              ...
# 93                                       153.722289
# 94                                       127.798170
# 95                                       510.114482
# 96                                       201.541693
# 97                                       230.031162
#
#     DENSITY..MACROPHAGE.CELLS..IN..ESI_0080._FFPE  \
# 0                                      117.214181
# 1                                      213.051178
# 2                                      126.118124
# 3                                      373.530705
# 4                                      325.794141
# ..                                            ...
# 93                                     459.735752
# 94                                     309.609308
# 95                                     853.822667
# 96                                     410.454157
# 97                                     182.857126
#
#     DENSITY..MACROPHAGE.CELLS..IN..STROMA._FFPE  \
# 0                                    279.543638
# 1                                    485.980424
# 2                                    531.019950
# 3                                    433.960713
# 4                                    726.978661
# ..                                          ...
# 93                                   908.984561
# 94                                   481.159063
# 95                                  1636.780495
# 96                                   869.411545
# 97                                   231.078996
#
#     DENSITY..MACROPHAGE.CELLS..IN..TUMOR._FFPE  \
# 0                                   168.364145
# 1                                   249.297432
# 2                                   258.483436
# 3                                   420.558583
# 4                                   385.207152
# ..                                         ...
# 93                                  663.691403
# 94                                  242.300629
# 95                                 1344.045225
# 96                                  622.767978
# 97                                  230.887263
#
#     DENSITY..PLASMA.CELLS..IN..EPITHELIAL._FFPE  \
# 0                                      7.957133
# 1                                     77.764510
# 2                                     20.506144
# 3                                     57.253522
# 4                                     28.302762
# ..                                          ...
# 93                                    44.661452
# 94                                    18.841770
# 95                                   185.962114
# 96                                    67.730232
# 97                                    74.153650
#
#     DENSITY..PLASMA.CELLS..IN..ESI_0080._FFPE  \
# 0                                  290.830028
# 1                                  468.970817
# 2                                  516.533939
# 3                                  300.334934
# 4                                  202.347826
# ..                                        ...
# 93                                 400.147075
# 94                                 110.381707
# 95                                1067.763495
# 96                                 444.390154
# 97                                  82.416230
#
#     DENSITY..PLASMA.CELLS..IN..STROMA._FFPE  \
# 0                                871.971956
# 1                               1453.978917
# 2                               1832.940001
# 3                                993.037548
# 4                                959.974666
# ..                                      ...
# 93                              1116.310430
# 94                               250.122534
# 95                              1332.894749
# 96                              1118.382174
# 97                                85.773194
#
#     DENSITY..PLASMA.CELLS..IN..TUMOR._FFPE  joined.PDL1_data
# 0                               490.433571                 0
# 1                               655.940953                 0
# 2                               875.121857                 1
# 3                               601.545591                 0
# 4                               470.029884                 0
# ..                                     ...               ...
# 93                              768.261584                 0
# 94                               93.785593                 0
# 95                             1034.893718                 0
# 96                              730.377622                 0
# 97                               83.647049                 1
#
# [98 rows x 608 columns]

# %%
# Normalize HIFs and define X, y
X_holdout = holdout_df.iloc[:,:607]
X_normalized_holdout = (X_holdout-X_holdout.mean())/X_holdout.std()
X_normalized_holdout
# Out:
#     AREA..MM2..OF..EPITHELIAL..IN..TISSUE._FFPE  \
# 0                                      0.073592
# 1                                      2.971639
# 2                                      3.400891
# 3                                      1.917830
# 4                                      0.232067
# ..                                          ...
# 93                                     0.019423
# 94                                     0.171479
# 95                                    -0.645392
# 96                                     1.957948
# 97                                    -1.092101
#
#     AREA..MM2..OF..ESI_0080..IN..TISSUE._FFPE  \
# 0                                   -0.042802
# 1                                    2.046526
# 2                                    2.227595
# 3                                    2.837649
# 4                                   -0.481586
# ..                                        ...
# 93                                   0.520093
# 94                                  -0.382404
# 95                                  -0.043229
# 96                                   3.169566
# 97                                  -0.850830
#
#     AREA..MM2..OF..NECROSIS..IN..TISSUE._FFPE  \
# 0                                    1.845840
# 1                                    0.312700
# 2                                    1.135293
# 3                                    1.405610
# 4                                   -0.397602
# ..                                        ...
# 93                                   2.843900
# 94                                  -0.398282
# 95                                  -0.697310
# 96                                   3.243816
# 97                                  -0.799572
#
#     AREA..MM2..OF..STROMA..IN..TISSUE._FFPE  \
# 0                                  0.246177
# 1                                  1.294388
# 2                                  2.127913
# 3                                  2.328137
# 4                                 -0.015622
# ..                                      ...
# 93                                 0.992087
# 94                                -0.519884
# 95                                 0.303398
# 96                                 3.150768
# 97                                -0.451138
#
#     AREA..MM2..OF..TUMOR..IN..TISSUE._FFPE  \
# 0                                 0.194079
# 1                                 2.284979
# 2                                 3.030209
# 3                                 2.433214
# 4                                 0.103504
# ..                                     ...
# 93                                0.646543
# 94                               -0.249936
# 95                               -0.120929
# 96                                2.981071
# 97                               -0.823978
#
#     CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.CANCER.IN.EPITHELIAL_FFPE  \
# 0                                                                   0.431513
# 1                                                                   0.390823
# 2                                                                   0.373008
# 3                                                                  -0.682386
# 4                                                                  -0.117001
# ..                                                                       ...
# 93                                                                 -0.759658
# 94                                                                  0.777372
# 95                                                                 -0.035043
# 96                                                                  0.007056
# 97                                                                 -2.074912
#
#     CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.CANCER.IN.ESI_0080_FFPE  \
# 0                                                                -0.264523
# 1                                                                 0.026964
# 2                                                                 0.401932
# 3                                                                -0.376444
# 4                                                                -1.086365
# ..                                                                     ...
# 93                                                               -1.165654
# 94                                                               -0.393806
# 95                                                                0.470617
# 96                                                                0.266679
# 97                                                               -3.267164
#
#     CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.CANCER.IN.STROMA_FFPE  \
# 0                                                               0.245828
# 1                                                               0.533234
# 2                                                               0.026352
# 3                                                              -0.125280
# 4                                                              -0.419851
# ..                                                                   ...
# 93                                                             -0.955973
# 94                                                             -0.409870
# 95                                                              1.802421
# 96                                                              0.594619
# 97                                                             -4.372546
#
#     CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.CANCER.IN.TUMOR_FFPE  \
# 0                                                             -0.087000
# 1                                                              0.492852
# 2                                                              0.166658
# 3                                                             -0.799392
# 4                                                             -0.443503
# ..                                                                  ...
# 93                                                            -1.208685
# 94                                                             1.003871
# 95                                                             0.063394
# 96                                                            -0.015179
# 97                                                            -2.862034
#
#     CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.FIBROBLAST.IN.EPITHELIAL_FFPE  \
# 0                                                                       0.550957
# 1                                                                       1.374601
# 2                                                                      -0.070417
# 3                                                                       0.305801
# 4                                                                      -2.014773
# ..                                                                           ...
# 93                                                                     -1.697849
# 94                                                                      0.092007
# 95                                                                      0.010951
# 96                                                                      0.572276
# 97                                                                     -1.013854
#
#     ...  DENSITY..LYMPHOCYTE.CELLS..IN..STROMA._FFPE  \
# 0   ...                                     2.070163
# 1   ...                                     0.269106
# 2   ...                                     1.829047
# 3   ...                                    -0.017562
# 4   ...                                     0.197442
# ..  ...                                          ...
# 93  ...                                    -0.259883
# 94  ...                                    -1.063212
# 95  ...                                     1.960462
# 96  ...                                     1.307297
# 97  ...                                    -0.873291
#
#     DENSITY..LYMPHOCYTE.CELLS..IN..TUMOR._FFPE  \
# 0                                     1.557713
# 1                                    -0.067530
# 2                                     0.958432
# 3                                     0.193000
# 4                                     0.041518
# ..                                         ...
# 93                                    0.082636
# 94                                   -1.009626
# 95                                    2.673642
# 96                                    1.397318
# 97                                   -0.255886
#
#     DENSITY..MACROPHAGE.CELLS..IN..EPITHELIAL._FFPE  \
# 0                                         -0.507775
# 1                                         -0.341187
# 2                                         -0.549245
# 3                                          0.737574
# 4                                         -0.343685
# ..                                              ...
# 93                                        -0.088555
# 94                                        -0.174842
# 95                                         1.097674
# 96                                         0.070609
# 97                                         0.165434
#
#     DENSITY..MACROPHAGE.CELLS..IN..ESI_0080._FFPE  \
# 0                                       -1.015373
# 1                                       -0.675170
# 2                                       -0.983766
# 3                                       -0.105499
# 4                                       -0.274955
# ..                                            ...
# 93                                       0.200512
# 94                                      -0.332408
# 95                                       1.599443
# 96                                       0.025572
# 97                                      -0.782353
#
#     DENSITY..MACROPHAGE.CELLS..IN..STROMA._FFPE  \
# 0                                     -1.224906
# 1                                     -0.718101
# 2                                     -0.607529
# 3                                     -0.845810
# 4                                     -0.126447
# ..                                          ...
# 93                                     0.320379
# 94                                    -0.729938
# 95                                     2.107127
# 96                                     0.223227
# 97                                    -1.343887
#
#     DENSITY..MACROPHAGE.CELLS..IN..TUMOR._FFPE  \
# 0                                    -0.945588
# 1                                    -0.694503
# 2                                    -0.666005
# 3                                    -0.163188
# 4                                    -0.272861
# ..                                         ...
# 93                                    0.591098
# 94                                   -0.716210
# 95                                    2.701805
# 96                                    0.464139
# 97                                   -0.751618
#
#     DENSITY..PLASMA.CELLS..IN..EPITHELIAL._FFPE  \
# 0                                     -0.894761
# 1                                      0.337440
# 2                                     -0.673252
# 3                                     -0.024608
# 4                                     -0.535631
# ..                                          ...
# 93                                    -0.246877
# 94                                    -0.702631
# 95                                     2.247283
# 96                                     0.160321
# 97                                     0.273703
#
#     DENSITY..PLASMA.CELLS..IN..ESI_0080._FFPE  \
# 0                                   -0.365753
# 1                                    0.333475
# 2                                    0.520167
# 3                                   -0.328445
# 4                                   -0.713059
# ..                                        ...
# 93                                   0.063332
# 94                                  -1.074039
# 95                                   2.683821
# 96                                   0.236992
# 97                                  -1.183807
#
#     DENSITY..PLASMA.CELLS..IN..STROMA._FFPE  \
# 0                                 -0.013349
# 1                                  1.089577
# 2                                  1.807723
# 3                                  0.216075
# 4                                  0.153420
# ..                                      ...
# 93                                 0.449682
# 94                                -1.191778
# 95                                 0.860118
# 96                                 0.453608
# 97                                -1.503226
#
#     DENSITY..PLASMA.CELLS..IN..TUMOR._FFPE
# 0                                 0.066159
# 1                                 0.576855
# 2                                 1.253168
# 3                                 0.409011
# 4                                 0.003201
# ..                                     ...
# 93                                0.923436
# 94                               -1.157754
# 95                                1.746167
# 96                                0.806540
# 97                               -1.189038
#
# [98 rows x 607 columns]

# %%
y_holdout = holdout_df.iloc[:,607]
print(np.sum(y_holdout))
# Out:
# 36

# %%
X_normalized_holdout = np.array(X_normalized_holdout)
y_pred_probs_1 = optimal_sgl_1.predict_proba(X_normalized_holdout)[1] # predicted probability y = 1
y_pred_probs_2 = optimal_sgl_2.predict_proba(X_normalized_holdout)[1]
y_pred_probs_3 = optimal_sgl_3.predict_proba(X_normalized_holdout)[1]

# %%
# Ensemble (average) predictions
y_pred_probs_ensemble = np.mean(np.array([list(y_pred_probs_1), list(y_pred_probs_2), list(y_pred_probs_3)]), axis=0)
# y_pred_probs_ensemble

# %%
# Hold Out ROC
fpr, tpr, thresholds = roc_curve(y_holdout, y_pred_probs_ensemble, pos_label=1)
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr, color='red', lw=1, label='Hold-Out ROC Curve (Area = %0.3f)' % roc_auc)

# Plot parameters
plt.plot([0, 1], [0, 1], color='black', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
# Generate ROC 95% CI

print("Original ROC area: {:0.3f}".format(roc_auc))

n_bootstraps = 1000
bootstrapped_scores = []

rng = np.random.RandomState(seed)
for i in range(n_bootstraps):
    # bootstrap by sampling with replacement on the prediction indices
    indices = rng.randint(0, len(y_pred_probs_ensemble), len(y_pred_probs_ensemble))
    
    if len(np.unique(y_holdout[indices])) < 2:
        # We need at least one positive and one negative sample for ROC AUC
        # to be defined: reject the sample
        continue

    score = roc_auc_score(y_holdout[indices], y_pred_probs_ensemble[indices])
    bootstrapped_scores.append(score)
    # print("Bootstrap #{} ROC area: {:0.3f}".format(i + 1, score))

plt.hist(bootstrapped_scores, bins=50)
plt.title('Histogram of the bootstrapped ROC AUC scores')
plt.show()

sorted_scores = np.array(bootstrapped_scores)
sorted_scores.sort()

# Computing the lower and upper bound of the 94% confidence interval
confidence_lower = sorted_scores[int(0.025 * len(sorted_scores))]
confidence_upper = sorted_scores[int(0.975 * len(sorted_scores))]
print("Confidence interval for the score: [{:0.3f} - {:0.3}]".format(
    confidence_lower, confidence_upper))
# Out:
# Original ROC area: 0.513
# Confidence interval for the score: [0.394 - 0.637]

# %%
# Hold Out PR Curve
precision, recall, thresholds = precision_recall_curve(y_holdout, y_pred_probs_ensemble, pos_label=1)
prc_auc = auc(recall, precision)
plt.plot(recall, precision, color='red', lw=1, label='Hold-Out PR Curve (Area = %0.3f)' % prc_auc)

# Plot parameters
# plt.plot([0, 1], [0, 1], color='black', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower right")
plt.show()

# %%
# Generate PRC 95% CI
print("Original PRC area: {:0.3f}".format(prc_auc))

n_bootstraps = 1000
bootstrapped_scores = []

rng = np.random.RandomState(seed)
for i in range(n_bootstraps):
    # bootstrap by sampling with replacement on the prediction indices
    indices = rng.randint(0, len(y_pred_probs_ensemble), len(y_pred_probs_ensemble))
    
    if len(np.unique(y_holdout[indices])) < 2:
        # We need at least one positive and one negative sample for ROC AUC
        # to be defined: reject the sample
        continue
    
    precision, recall, thresholds = precision_recall_curve(y_holdout[indices], y_pred_probs_ensemble[indices], pos_label=1)
    score = auc(recall, precision)
    bootstrapped_scores.append(score)
    # print("Bootstrap #{} ROC area: {:0.3f}".format(i + 1, score))

plt.hist(bootstrapped_scores, bins=50)
plt.title('Histogram of the bootstrapped ROC PRC scores')
plt.show()

sorted_scores = np.array(bootstrapped_scores)
sorted_scores.sort()

# Computing the lower and upper bound of the 94% confidence interval
confidence_lower = sorted_scores[int(0.025 * len(sorted_scores))]
confidence_upper = sorted_scores[int(0.975 * len(sorted_scores))]
print("Confidence interval for the score: [{:0.3f} - {:0.3}]".format(
    confidence_lower, confidence_upper))
# Out:
# Original PRC area: 0.425
# Confidence interval for the score: [0.292 - 0.575]
