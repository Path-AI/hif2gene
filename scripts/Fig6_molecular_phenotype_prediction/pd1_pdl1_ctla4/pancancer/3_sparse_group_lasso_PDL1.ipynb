# %%
# Clear workspace
# %reset

# standard packages
from math import e
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pickle as pkl
import os
from sklearn import preprocessing
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import classification_report, roc_curve, auc, roc_auc_score, precision_recall_curve, plot_precision_recall_curve
from scipy.stats import sem
pd.options.display.max_colwidth = 100

# SGL packages
from group_lasso import LogisticGroupLasso
LogisticGroupLasso.LOG_LOSSES = True

# %reload_ext autoreload
# %autoreload 2

working_dir = "~/Desktop/hif2gene"
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
seed = 360
np.random.seed(seed)

# %% [markdown]
# ## Load in HIFs + Clusters

# %%
# Load in HIF dataset with labels
# NAs removed, already converted to patient-level
df = pd.read_csv("{0}/data/genetic_data/PanImmune/datasets/pancancer.PDL1.joined.USE.csv".format(working_dir))
df = df.iloc[:,1:]
df
# Out:
#       AREA..MM2..OF..EPITHELIAL..IN..TISSUE._HE  \
# 0                                     71.806464
# 1                                     82.396624
# 2                                     26.877520
# 3                                     43.128576
# 4                                      0.685216
# ...                                         ...
# 1616                                  52.707784
# 1617                                  63.597184
# 1618                                  77.987908
# 1619                                  39.603288
# 1620                                  17.451352
#
#       AREA..MM2..OF..ESI_0080..IN..TISSUE._HE  \
# 0                                  129.127076
# 1                                  168.316672
# 2                                   53.040932
# 3                                  111.292004
# 4                                    2.596956
# ...                                       ...
# 1616                                98.824948
# 1617                                70.101124
# 1618                               106.847656
# 1619                                65.279932
# 1620                                20.754456
#
#       AREA..MM2..OF..NECROSIS..IN..TISSUE._HE  \
# 0                                    1.158576
# 1                                    2.677280
# 2                                    3.571664
# 3                                    0.742096
# 4                                    1.605504
# ...                                       ...
# 1616                                34.857764
# 1617                                15.685304
# 1618                                57.923272
# 1619                                70.423856
# 1620                                 7.431092
#
#       AREA..MM2..OF..STROMA..IN..TISSUE._HE  \
# 0                                122.432688
# 1                                145.747888
# 2                                 44.355952
# 3                                 98.095856
# 4                                  8.142384
# ...                                     ...
# 1616                             189.825556
# 1617                              37.812436
# 1618                              95.313388
# 1619                              49.194160
# 1620                              53.174212
#
#       AREA..MM2..OF..TUMOR..IN..TISSUE._HE  \
# 0                               194.239152
# 1                               228.144512
# 2                                71.233472
# 3                               141.224432
# 4                                 8.827600
# ...                                    ...
# 1616                            242.533340
# 1617                            101.409620
# 1618                            173.301296
# 1619                             88.797448
# 1620                             70.625564
#
#       AREA.PROP...EPITHELIAL..OVER..TUMOR...IN..TISSUE._HE  \
# 0                                                 0.369681
# 1                                                 0.361160
# 2                                                 0.377316
# 3                                                 0.305390
# 4                                                 0.077622
# ...                                                    ...
# 1616                                              0.217322
# 1617                                              0.627132
# 1618                                              0.450013
# 1619                                              0.445996
# 1620                                              0.247097
#
#       AREA.PROP...ESI_0080..OVER..TUMOR...IN..TISSUE._HE  \
# 0                                               0.664784
# 1                                               0.737763
# 2                                               0.744607
# 3                                               0.788051
# 4                                               0.294186
# ...                                                  ...
# 1616                                            0.407470
# 1617                                            0.691267
# 1618                                            0.616543
# 1619                                            0.735155
# 1620                                            0.293866
#
#       AREA.PROP...STROMA..OVER..TUMOR...IN..TISSUE._HE  \
# 0                                             0.630319
# 1                                             0.638840
# 2                                             0.622684
# 3                                             0.694610
# 4                                             0.922378
# ...                                                ...
# 1616                                          0.782678
# 1617                                          0.372868
# 1618                                          0.549987
# 1619                                          0.554004
# 1620                                          0.752903
#
#       CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.CANCER.IN.EPITHELIAL_HE  \
# 0                                                                6722.417551
# 1                                                                6594.895183
# 2                                                                5833.355998
# 3                                                                7160.616676
# 4                                                                4479.384456
# ...                                                                      ...
# 1616                                                             5481.887127
# 1617                                                             6795.170377
# 1618                                                             6331.815097
# 1619                                                             6153.814813
# 1620                                                             6045.268247
#
#       CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.CANCER.IN.ESI_0080_HE  \
# 0                                                              6665.889385
# 1                                                              6647.129359
# 2                                                              6531.812070
# 3                                                              7223.818109
# 4                                                              4093.277627
# ...                                                                    ...
# 1616                                                           6206.811690
# 1617                                                           6840.896120
# 1618                                                           5924.450521
# 1619                                                           5975.715902
# 1620                                                           5516.059207
#
#       ...  TOTAL..LYMPHOCYTE.CELLS..IN..TUMOR._HE  \
# 0     ...                                  162597
# 1     ...                                   65822
# 2     ...                                   45076
# 3     ...                                   44382
# 4     ...                                   17273
# ...   ...                                     ...
# 1616  ...                                  318848
# 1617  ...                                   73563
# 1618  ...                                  117758
# 1619  ...                                   79681
# 1620  ...                                   86637
#
#       TOTAL..MACROPHAGE.CELLS..IN..EPITHELIAL._HE  \
# 0                                            4593
# 1                                            3040
# 2                                            1546
# 3                                            1897
# 4                                             452
# ...                                           ...
# 1616                                         2539
# 1617                                          875
# 1618                                         1975
# 1619                                         3634
# 1620                                         1836
#
#       TOTAL..MACROPHAGE.CELLS..IN..ESI_0080._HE  \
# 0                                         24879
# 1                                         14794
# 2                                          7789
# 3                                          5594
# 4                                          1604
# ...                                         ...
# 1616                                      33056
# 1617                                       3524
# 1618                                       9005
# 1619                                      16668
# 1620                                      13939
#
#       TOTAL..MACROPHAGE.CELLS..IN..STROMA._HE  \
# 0                                       38851
# 1                                       24867
# 2                                       12735
# 3                                        9934
# 4                                        4450
# ...                                       ...
# 1616                                    89665
# 1617                                     6321
# 1618                                    14189
# 1619                                    24537
# 1620                                    62302
#
#       TOTAL..MACROPHAGE.CELLS..IN..TUMOR._HE  \
# 0                                      43444
# 1                                      27907
# 2                                      14281
# 3                                      11831
# 4                                       4902
# ...                                      ...
# 1616                                   92204
# 1617                                    7196
# 1618                                   16164
# 1619                                   28171
# 1620                                   64138
#
#       TOTAL..PLASMA.CELLS..IN..EPITHELIAL._HE  \
# 0                                       12789
# 1                                        1328
# 2                                         729
# 3                                        1837
# 4                                         181
# ...                                       ...
# 1616                                     1389
# 1617                                      516
# 1618                                     4382
# 1619                                     2219
# 1620                                      756
#
#       TOTAL..PLASMA.CELLS..IN..ESI_0080._HE  \
# 0                                     27081
# 1                                      3955
# 2                                      2571
# 3                                      2488
# 4                                       289
# ...                                     ...
# 1616                                  28801
# 1617                                  14462
# 1618                                  26983
# 1619                                  28529
# 1620                                   9088
#
#       TOTAL..PLASMA.CELLS..IN..STROMA._HE  TOTAL..PLASMA.CELLS..IN..TUMOR._HE  \
# 0                                   26708                               39497
# 1                                    6120                                7448
# 2                                    4174                                4903
# 3                                    1965                                3802
# 4                                     527                                 708
# ...                                   ...                                 ...
# 1616                                90141                               91530
# 1617                                26747                               27263
# 1618                                60546                               64928
# 1619                                46913                               49132
# 1620                                65406                               66162
#
#       joined.PDL1_data
# 0                    1
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# 1616                 0
# 1617                 0
# 1618                 0
# 1619                 0
# 1620                 1
#
# [1621 rows x 608 columns]

# %%
# Normalize HIFs and define X, y
X = df.iloc[:,:607]
X_normalized = (X-X.mean())/X.std()
X_normalized
# Out:
#       AREA..MM2..OF..EPITHELIAL..IN..TISSUE._HE  \
# 0                                      0.625780
# 1                                      0.890326
# 2                                     -0.496558
# 3                                     -0.090602
# 4                                     -1.150850
# ...                                         ...
# 1616                                   0.148690
# 1617                                   0.420710
# 1618                                   0.780195
# 1619                                  -0.178664
# 1620                                  -0.732026
#
#       AREA..MM2..OF..ESI_0080..IN..TISSUE._HE  \
# 0                                    1.320111
# 1                                    2.099043
# 2                                   -0.192178
# 3                                    0.965621
# 4                                   -1.194802
# ...                                       ...
# 1616                                 0.717826
# 1617                                 0.146911
# 1618                                 0.877285
# 1619                                 0.051085
# 1620                                -0.833904
#
#       AREA..MM2..OF..NECROSIS..IN..TISSUE._HE  \
# 0                                   -0.454536
# 1                                   -0.378713
# 2                                   -0.334060
# 3                                   -0.475329
# 4                                   -0.432223
# ...                                       ...
# 1616                                 1.227934
# 1617                                 0.270728
# 1618                                 2.379506
# 1619                                 3.003612
# 1620                                -0.141373
#
#       AREA..MM2..OF..STROMA..IN..TISSUE._HE  \
# 0                                  1.650450
# 1                                  2.197757
# 2                                 -0.182341
# 3                                  1.079162
# 4                                 -1.032426
# ...                                     ...
# 1616                               3.232446
# 1617                              -0.335945
# 1618                               1.013846
# 1619                              -0.068767
# 1620                               0.024661
#
#       AREA..MM2..OF..TUMOR..IN..TISSUE._HE  \
# 0                                 1.312188
# 1                                 1.778738
# 2                                -0.380414
# 3                                 0.582686
# 4                                -1.239142
# ...                                    ...
# 1616                              1.976733
# 1617                              0.034820
# 1618                              1.024075
# 1619                             -0.138728
# 1620                             -0.388779
#
#       AREA.PROP...EPITHELIAL..OVER..TUMOR...IN..TISSUE._HE  \
# 0                                                -0.561140
# 1                                                -0.609883
# 2                                                -0.517463
# 3                                                -0.928909
# 4                                                -2.231844
# ...                                                    ...
# 1616                                             -1.432699
# 1617                                              0.911593
# 1618                                             -0.101601
# 1619                                             -0.124584
# 1620                                             -1.262373
#
#       AREA.PROP...ESI_0080..OVER..TUMOR...IN..TISSUE._HE  \
# 0                                               0.228032
# 1                                               0.646773
# 2                                               0.686040
# 3                                               0.935311
# 4                                              -1.898384
# ...                                                  ...
# 1616                                           -1.248386
# 1617                                            0.379987
# 1618                                           -0.048766
# 1619                                            0.631810
# 1620                                           -1.900219
#
#       AREA.PROP...STROMA..OVER..TUMOR...IN..TISSUE._HE  \
# 0                                             0.561140
# 1                                             0.609883
# 2                                             0.517463
# 3                                             0.928909
# 4                                             2.231844
# ...                                                ...
# 1616                                          1.432699
# 1617                                         -0.911593
# 1618                                          0.101601
# 1619                                          0.124584
# 1620                                          1.262373
#
#       CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.CANCER.IN.EPITHELIAL_HE  \
# 0                                                                   0.416323
# 1                                                                   0.261875
# 2                                                                  -0.660456
# 3                                                                   0.947043
# 4                                                                  -2.300306
# ...                                                                      ...
# 1616                                                               -1.086134
# 1617                                                                0.504437
# 1618                                                               -0.056752
# 1619                                                               -0.272335
# 1620                                                               -0.403801
#
#       CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.CANCER.IN.ESI_0080_HE  \
# 0                                                                 0.409658
# 1                                                                 0.385380
# 2                                                                 0.236147
# 3                                                                 1.131682
# 4                                                                -2.919595
# ...                                                                    ...
# 1616                                                             -0.184441
# 1617                                                              0.636137
# 1618                                                             -0.549848
# 1619                                                             -0.483505
# 1620                                                             -1.078354
#
#       ...  TOTAL..LYMPHOCYTE.CELLS..IN..STROMA._HE  \
# 0     ...                                 0.657724
# 1     ...                                -0.167697
# 2     ...                                -0.347063
# 3     ...                                -0.408067
# 4     ...                                -0.603285
# ...   ...                                      ...
# 1616  ...                                 2.308081
# 1617  ...                                -0.068714
# 1618  ...                                 0.241515
# 1619  ...                                -0.022396
# 1620  ...                                 0.078247
#
#       TOTAL..LYMPHOCYTE.CELLS..IN..TUMOR._HE  \
# 0                                   0.641397
# 1                                  -0.225805
# 2                                  -0.411710
# 3                                  -0.417929
# 4                                  -0.660853
# ...                                      ...
# 1616                                2.041564
# 1617                               -0.156438
# 1618                                0.239594
# 1619                               -0.101614
# 1620                               -0.039282
#
#       TOTAL..MACROPHAGE.CELLS..IN..EPITHELIAL._HE  \
# 0                                       -0.049494
# 1                                       -0.227107
# 2                                       -0.397972
# 3                                       -0.357829
# 4                                       -0.523090
# ...                                           ...
# 1616                                    -0.284405
# 1617                                    -0.474712
# 1618                                    -0.348908
# 1619                                    -0.159172
# 1620                                    -0.364805
#
#       TOTAL..MACROPHAGE.CELLS..IN..ESI_0080._HE  \
# 0                                      0.703656
# 1                                      0.097471
# 2                                     -0.323583
# 3                                     -0.455519
# 4                                     -0.695349
# ...                                         ...
# 1616                                   1.195156
# 1617                                  -0.579942
# 1618                                  -0.250492
# 1619                                   0.210112
# 1620                                   0.046079
#
#       TOTAL..MACROPHAGE.CELLS..IN..STROMA._HE  \
# 0                                    0.552410
# 1                                    0.082867
# 2                                   -0.324492
# 3                                   -0.418541
# 4                                   -0.602679
# ...                                       ...
# 1616                                 2.258601
# 1617                                -0.539856
# 1618                                -0.275670
# 1619                                 0.071786
# 1620                                 1.339829
#
#       TOTAL..MACROPHAGE.CELLS..IN..TUMOR._HE  \
# 0                                   0.468279
# 1                                   0.014095
# 2                                  -0.384225
# 3                                  -0.455844
# 4                                  -0.658396
# ...                                      ...
# 1616                                1.893650
# 1617                               -0.591336
# 1618                               -0.329180
# 1619                                0.021813
# 1620                                1.073214
#
#       TOTAL..PLASMA.CELLS..IN..EPITHELIAL._HE  \
# 0                                    1.811266
# 1                                   -0.380200
# 2                                   -0.494736
# 3                                   -0.282874
# 4                                   -0.599519
# ...                                       ...
# 1616                                -0.368536
# 1617                                -0.535463
# 1618                                 0.203757
# 1619                                -0.209832
# 1620                                -0.489573
#
#       TOTAL..PLASMA.CELLS..IN..ESI_0080._HE  \
# 0                                  0.511670
# 1                                 -0.440251
# 2                                 -0.497219
# 3                                 -0.500636
# 4                                 -0.591152
# ...                                     ...
# 1616                               0.582470
# 1617                              -0.007758
# 1618                               0.507637
# 1619                               0.571274
# 1620                              -0.228964
#
#       TOTAL..PLASMA.CELLS..IN..STROMA._HE  TOTAL..PLASMA.CELLS..IN..TUMOR._HE
# 0                                0.058301                            0.269384
# 1                               -0.433379                           -0.455277
# 2                               -0.479853                           -0.512822
# 3                               -0.532608                           -0.537716
# 4                               -0.566951                           -0.607675
# ...                                   ...                                 ...
# 1616                             1.573201                            1.445904
# 1617                             0.059233                           -0.007239
# 1618                             0.866417                            0.844406
# 1619                             0.540835                            0.487242
# 1620                             0.982483                            0.872308
#
# [1621 rows x 607 columns]

# %%
y = df.iloc[:,607]
print(np.sum(y))
# Out:
# 755

# %%
# Load in clusters
clusters = pd.read_csv("{0}/data/hif_clusters/pancancer.hif.clusters.csv".format(working_dir))
print("Number of Clusters: {0}".format(len(set(clusters['x']))))
clusters
# Out:
# Number of Clusters: 20
#                                     Unnamed: 0  x
# 0    AREA (MM2) OF [EPITHELIAL] IN [TISSUE]_HE  1
# 1      AREA (MM2) OF [ESI_0080] IN [TISSUE]_HE  1
# 2      AREA (MM2) OF [NECROSIS] IN [TISSUE]_HE  2
# 3        AREA (MM2) OF [STROMA] IN [TISSUE]_HE  3
# 4         AREA (MM2) OF [TUMOR] IN [TISSUE]_HE  1
# ..                                         ... ..
# 602     TOTAL [MACROPHAGE CELLS] IN [TUMOR]_HE  1
# 603    TOTAL [PLASMA CELLS] IN [EPITHELIAL]_HE  1
# 604      TOTAL [PLASMA CELLS] IN [ESI_0080]_HE  9
# 605        TOTAL [PLASMA CELLS] IN [STROMA]_HE  9
# 606         TOTAL [PLASMA CELLS] IN [TUMOR]_HE  9
#
# [607 rows x 2 columns]

# %% [markdown]
# ## Define Nested CV Parameters

# %%
num_outer_loops = 3 # for estimating generalization error
num_inner_loops = 5 # for hyper-parameter tuning
training_aurocs = [0.0, 0.0, 0.0]
generalization_aurocs = [0.0, 0.0, 0.0]
training_auprcs = [0.0, 0.0, 0.0]
generalization_auprcs = [0.0, 0.0, 0.0]

# Define outer loops (A, B, and C)
X_train_AB, X_train_C, y_train_AB, y_train_C = train_test_split(X_normalized, y, test_size=1/3, random_state=seed, stratify=y)
X_train_A, X_train_B, y_train_A, y_train_B = train_test_split(X_train_AB, y_train_AB, test_size=1/2, random_state=seed, stratify=y_train_AB)

# Verify correctness
print(len(X_train_A), len(y_train_A))
print(len(X_train_B), len(y_train_B))
print(len(X_train_C), len(y_train_C))

print(np.sum(y_train_A)/len(y_train_A))
print(np.sum(y_train_B)/len(y_train_B))
print(np.sum(y_train_C)/len(y_train_C))
# Out:
# 540 540
# 540 540
# 541 541
# 0.4666666666666667
# 0.4648148148148148
# 0.4658040665434381

# %% [markdown]
# ### Outer Loop 1

# %%
# Define outer loop train and test
X_train_1 = np.array(X_train_A.append(X_train_B))
y_train_1 = np.array(y_train_A.append(y_train_B))
print(X_train_1.shape, y_train_1.shape)

X_test_1 = np.array(X_train_C)
y_test_1 = np.array(y_train_C)
print(X_test_1.shape, y_test_1.shape)
# Out:
# (1080, 607) (1080,)
# (541, 607) (541,)

# %%
# Define k-folds object
skf = StratifiedKFold(n_splits=num_inner_loops)
skf.get_n_splits(X_train_1, y_train_1)
# Out:
# 5

# %%
# K-folds: hyper-parameter tuning
num_regs = 40
regs = list(np.logspace(-7, -2, num_regs, base=e))
print(regs)

cv_aucs = [] # based on k-folds CV

for reg in regs:
    print(reg)
    k_folds_count = 1
    
    aucs = [] 
    for train_index, test_index in skf.split(X_train_1, y_train_1):
        print(k_folds_count)

        # Define train / test
        X_train, X_test = X_train_1[train_index], X_train_1[test_index]
        y_train, y_test = y_train_1[train_index], y_train_1[test_index]
        print(np.sum(y_train)/len(y_train), np.sum(y_test)/len(y_test))
        print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
        
        # SGL 
        sgl = LogisticGroupLasso(groups=clusters['x'], group_reg=reg*(1/6), l1_reg=reg*(5/6), n_iter=1000, 
                                 tol=1e-6, old_regularisation=False, warm_start=True, random_state=seed)
        sgl.fit(X_train, y_train)

        # Compute AUC on test set
        y_probs_test = sgl.predict_proba(X_test)[1] # predicted probability y = 1
        fpr, tpr, thresholds = roc_curve(y_test, y_probs_test, pos_label=1)
        roc_auc = auc(fpr, tpr)
        aucs.append(roc_auc)

        k_folds_count += 1
    
    print(aucs)
    cv_aucs.append(np.mean(np.array(aucs)))

# %%
# Plot CV AUCs
print(cv_aucs)
plt.figure(figsize=(12,6))
plt.plot(np.log(regs), cv_aucs)
plt.grid(axis='both')
plt.show()

max_reg = regs[np.argmax(np.array(cv_aucs))]
print(max_reg, np.log(max_reg))
# Out:
# [0.6437221080054033, 0.6603169207475471, 0.6566848011637746, 0.6584117223566434, 0.6529943963661735, 0.6551204224620364, 0.6594288746715751, 0.6358040732109193, 0.6481863746344649, 0.658674707200855, 0.6544407425000371, 0.6553868808170173, 0.6529235233868214, 0.6521302640758828, 0.6523191844671723, 0.6495447028960768, 0.6428952306025206, 0.6415148069529591, 0.6368464010568973, 0.6303179524099336, 0.6281292546795909, 0.6264734588151469, 0.6240091439428801, 0.6204255644455, 0.6166519067199074, 0.6136548235783099, 0.6115186292992119, 0.6117950702866388, 0.6138808095952024, 0.6169651238737067, 0.6215282334080486, 0.5839593792212805, 0.5195695221696083, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
# 0.0010366148031826386 -6.871794871794871

# %%
# Choose best regularization parameter based on CV plot
optimal_log_reg = -4.4
optimal_reg = np.exp(optimal_log_reg)
print(optimal_log_reg, optimal_reg)

# Fit "optimal model"
optimal_sgl = LogisticGroupLasso(groups=clusters['x'], group_reg=optimal_reg*(1/6), l1_reg=optimal_reg*(5/6), n_iter=1000, 
                         tol=1e-6, old_regularisation=False, warm_start=False, random_state=seed)
optimal_sgl.fit(X_train_1, y_train_1)

# Store optimal model
optimal_sgl_1 = optimal_sgl

# %%
# Plot Train and Test ROCs
y_pred_probs_train = optimal_sgl.predict_proba(X_train_1)[1] # predicted probability y = 1
y_pred_probs_test = optimal_sgl.predict_proba(X_test_1)[1]

# Train
fpr, tpr, thresholds = roc_curve(y_train_1, y_pred_probs_train, pos_label=1)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='blue', lw=1, label='Train ROC Curve (Area = %0.3f)' % roc_auc)
training_aurocs[0] = roc_auc

# Test
fpr, tpr, thresholds = roc_curve(y_test_1, y_pred_probs_test, pos_label=1)
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr, color='red', lw=1, label='Test ROC Curve (Area = %0.3f)' % roc_auc)
generalization_aurocs[0] = roc_auc

# Plot parameters
plt.plot([0, 1], [0, 1], color='black', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
# Plot Train and Test PR Curves

# Train
precision, recall, thresholds = precision_recall_curve(y_train_1, y_pred_probs_train, pos_label=1)
prc_auc = auc(recall, precision)
plt.figure()
plt.plot(recall, precision, color='blue', lw=1, label='Train PR Curve (Area = %0.3f)' % prc_auc)
training_auprcs[0] = prc_auc

# Test
precision, recall, thresholds = precision_recall_curve(y_test_1, y_pred_probs_test, pos_label=1)
prc_auc = auc(recall, precision)
plt.plot(recall, precision, color='red', lw=1, label='Test PR Curve (Area = %0.3f)' % prc_auc)
generalization_auprcs[0] = prc_auc

# Plot parameters
# plt.plot([0, 1], [0, 1], color='black', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower right")
plt.show()

# %%
# Save model coefficients
sparsity_mask = optimal_sgl.sparsity_mask_
print("Number of chosen variables: {0}".format(sparsity_mask.sum()))

betas_1 = optimal_sgl.coef_[:, 1] - optimal_sgl.coef_[:, 0]
betas_1[~sparsity_mask] = 0.0 # if not included in model, set to 0
betas_df = pd.DataFrame({
    "HIF": clusters['Unnamed: 0'],
    "Beta": betas_1, 
    "Cluster": clusters['x'],
    "Included (T/F)": sparsity_mask}
)
betas_df = betas_df[betas_df['Included (T/F)'] == True][['HIF', 'Beta', 'Cluster']]
betas_df.sort_values(by="Beta", ascending=False)
# Out:
# Number of chosen variables: 234
#                                                                                                      HIF  \
# 117             CELL CLUSTERING PROPERTIES: CLUSTER SIZE STANDARD DEVIATION OF LYMPHOCYTE IN ESI_0080_HE
# 118               CELL CLUSTERING PROPERTIES: CLUSTER SIZE STANDARD DEVIATION OF LYMPHOCYTE IN STROMA_HE
# 57                          CELL CLUSTERING PROPERTIES: CLUSTER EXTENT MEAN OF LYMPHOCYTE IN ESI_0080_HE
# 59                             CELL CLUSTERING PROPERTIES: CLUSTER EXTENT MEAN OF LYMPHOCYTE IN TUMOR_HE
# 286  COUNT PROP [[[CANCER CELLS] SELECTED BY [LYMPHOCYTE_RADIUS_80]] OVER [CANCER CELLS]] IN [STROMA]_HE
# ..                                                                                                   ...
# 258  COUNT PROP [[CANCER CELLS] OVER [[CANCER CELLS] SELECTED BY [MACROPHAGE_RADIUS_80]]] IN [STROMA]_HE
# 259   COUNT PROP [[CANCER CELLS] OVER [[CANCER CELLS] SELECTED BY [MACROPHAGE_RADIUS_80]]] IN [TUMOR]_HE
# 40                    CELL CLUSTERING PROPERTIES: CALINSKI-HARABASZ INDEX OF MACROPHAGE IN EPITHELIAL_HE
# 426                            REGION PROPERTIES: AVERAGE EXTENT OF SIGNIFICANT REGIONS OF EPITHELIAL_HE
# 451                                         REGION PROPERTIES: EXTENT OF LARGEST REGION OF EPITHELIAL_HE
#
#          Beta  Cluster
# 117  0.567154       10
# 118  0.540460       10
# 57   0.538076       10
# 59   0.496314       10
# 286  0.466330       10
# ..        ...      ...
# 258 -0.268947        7
# 259 -0.274447        7
# 40  -0.367477        1
# 426 -0.434664        7
# 451 -0.502165        7
#
# [234 rows x 3 columns]

# %% [markdown]
# ### Outer Loop 2

# %%
# Define outer loop train and test
X_train_2 = np.array(X_train_A.append(X_train_C))
y_train_2 = np.array(y_train_A.append(y_train_C))
print(X_train_2.shape, y_train_2.shape)

X_test_2 = np.array(X_train_B)
y_test_2 = np.array(y_train_B)
print(X_test_2.shape, y_test_2.shape)
# Out:
# (1081, 607) (1081,)
# (540, 607) (540,)

# %%
# Define k-folds object
skf = StratifiedKFold(n_splits=num_inner_loops)
skf.get_n_splits(X_train_2, y_train_2)
# Out:
# 5

# %%
# K-folds: hyper-parameter tuning
num_regs = 30
regs = list(np.logspace(-6.0, -3.0, num_regs, base=e))
print(regs)

cv_aucs = [] # based on k-folds CV

for reg in regs:
    print(reg)
    k_folds_count = 1
    
    aucs = [] 
    for train_index, test_index in skf.split(X_train_2, y_train_2):
        print(k_folds_count)

        # Define train / test
        X_train, X_test = X_train_2[train_index], X_train_2[test_index]
        y_train, y_test = y_train_2[train_index], y_train_2[test_index]
        print(np.sum(y_train)/len(y_train), np.sum(y_test)/len(y_test))
        print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
        
        # SGL 
        sgl = LogisticGroupLasso(groups=clusters['x'], group_reg=reg*(1/6), l1_reg=reg*(5/6), n_iter=1000, 
                                 tol=1e-6, old_regularisation=False, warm_start=True, random_state=seed)
        sgl.fit(X_train, y_train)

        # Compute AUC on test set
        y_probs_test = sgl.predict_proba(X_test)[1] # predicted probability y = 1
        fpr, tpr, thresholds = roc_curve(y_test, y_probs_test, pos_label=1)
        roc_auc = auc(fpr, tpr)
        aucs.append(roc_auc)

        k_folds_count += 1
    
    print(aucs)
    cv_aucs.append(np.mean(np.array(aucs)))

# %%
# Plot CV AUCs
print(cv_aucs)
plt.figure(figsize=(12,6))
plt.plot(np.log(regs), cv_aucs)
plt.grid(axis='both')
plt.show()

max_reg = regs[np.argmax(np.array(cv_aucs))]
print(max_reg, np.log(max_reg))
# Out:
# [0.6654606498622672, 0.6606367998578242, 0.6655867717188473, 0.675450282870768, 0.6482932969994964, 0.6552173513817718, 0.6609059565771156, 0.6704189745564408, 0.674192796421907, 0.6497370930955836, 0.6418709161458487, 0.6467266076241818, 0.6566097272000236, 0.6524746008708273, 0.6514022985101151, 0.6294057936672492, 0.6542973253161932, 0.7000427712449275, 0.6969045348182814, 0.7008240869642488, 0.6817453570688071, 0.6938215692663132, 0.6759051272177956, 0.6682973845561447, 0.6541494327774651, 0.6750949616421315, 0.6786153549954088, 0.6879549776369183, 0.6213567726074465, 0.6824247504517047]
# 0.01769483024496462 -4.0344827586206895

# %%
# Choose best regularization parameter based on CV plot
optimal_log_reg = -4.3
optimal_reg = np.exp(optimal_log_reg)
print(optimal_log_reg, optimal_reg)

# Fit "optimal model"
optimal_sgl = LogisticGroupLasso(groups=clusters['x'], group_reg=optimal_reg*(1/6), l1_reg=optimal_reg*(5/6), n_iter=1000, 
                         tol=1e-6, old_regularisation=False, warm_start=False, random_state=seed)
optimal_sgl.fit(X_train_2, y_train_2)

# Store optimal model
optimal_sgl_2 = optimal_sgl

# %%
# Plot Train and Test ROCs
y_pred_probs_train = optimal_sgl.predict_proba(X_train_2)[1] # predicted probability y = 1
y_pred_probs_test = optimal_sgl.predict_proba(X_test_2)[1]

# Train
fpr, tpr, thresholds = roc_curve(y_train_2, y_pred_probs_train, pos_label=1)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='blue', lw=1, label='Train ROC Curve (Area = %0.3f)' % roc_auc)
training_aurocs[1] = roc_auc

# Test
fpr, tpr, thresholds = roc_curve(y_test_2, y_pred_probs_test, pos_label=1)
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr, color='red', lw=1, label='Test ROC Curve (Area = %0.3f)' % roc_auc)
generalization_aurocs[1] = roc_auc

# Plot parameters
plt.plot([0, 1], [0, 1], color='black', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
# Plot Train and Test PR Curves

# Train
precision, recall, thresholds = precision_recall_curve(y_train_2, y_pred_probs_train, pos_label=1)
prc_auc = auc(recall, precision)
plt.figure()
plt.plot(recall, precision, color='blue', lw=1, label='Train PR Curve (Area = %0.3f)' % prc_auc)
training_auprcs[1] = prc_auc

# Test
precision, recall, thresholds = precision_recall_curve(y_test_2, y_pred_probs_test, pos_label=1)
prc_auc = auc(recall, precision)
plt.plot(recall, precision, color='red', lw=1, label='Test PR Curve (Area = %0.3f)' % prc_auc)
generalization_auprcs[1] = prc_auc

# Plot parameters
# plt.plot([0, 1], [0, 1], color='black', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower right")
plt.show()

# %%
# Save model coefficients
sparsity_mask = optimal_sgl.sparsity_mask_
print("Number of chosen variables: {0}".format(sparsity_mask.sum()))

betas_2 = optimal_sgl.coef_[:, 1] - optimal_sgl.coef_[:, 0]
betas_2[~sparsity_mask] = 0.0 # if not included in model, set to 0
betas_df = pd.DataFrame({
    "HIF": clusters['Unnamed: 0'],
    "Beta": betas_2, 
    "Cluster": clusters['x'],
    "Included (T/F)": sparsity_mask}
)
betas_df = betas_df[betas_df['Included (T/F)'] == True][['HIF', 'Beta', 'Cluster']]
betas_df.sort_values(by="Beta", ascending=False)
# Out:
# Number of chosen variables: 136
#                                                                                                      HIF  \
# 117             CELL CLUSTERING PROPERTIES: CLUSTER SIZE STANDARD DEVIATION OF LYMPHOCYTE IN ESI_0080_HE
# 286  COUNT PROP [[[CANCER CELLS] SELECTED BY [LYMPHOCYTE_RADIUS_80]] OVER [CANCER CELLS]] IN [STROMA]_HE
# 177  CELL CLUSTERING PROPERTIES: WITHIN CLUSTER DISPERSION STANDARD DEVIATION OF LYMPHOCYTE IN ESI_00...
# 59                             CELL CLUSTERING PROPERTIES: CLUSTER EXTENT MEAN OF LYMPHOCYTE IN TUMOR_HE
# 157              CELL CLUSTERING PROPERTIES: WITHIN CLUSTER DISPERSION MEAN OF LYMPHOCYTE IN ESI_0080_HE
# ..                                                                                                   ...
# 254  COUNT PROP [[CANCER CELLS] OVER [[CANCER CELLS] SELECTED BY [LYMPHOCYTE_RADIUS_80]]] IN [STROMA]_HE
# 433                            REGION PROPERTIES: AVERAGE SOLIDITY OF SIGNIFICANT REGIONS OF NECROSIS_HE
# 252  COUNT PROP [[CANCER CELLS] OVER [[CANCER CELLS] SELECTED BY [LYMPHOCYTE_RADIUS_80]]] IN [EPITHEL...
# 428                              REGION PROPERTIES: AVERAGE EXTENT OF SIGNIFICANT REGIONS OF NECROSIS_HE
# 70                  CELL CLUSTERING PROPERTIES: CLUSTER EXTENT STANDARD DEVIATION OF CANCER IN STROMA_HE
#
#          Beta  Cluster
# 117  0.559328       10
# 286  0.464031       10
# 177  0.370915       10
# 59   0.325178       10
# 157  0.316186       10
# ..        ...      ...
# 254 -0.147155       10
# 433 -0.175741        2
# 252 -0.324401       10
# 428 -0.498495        2
# 70  -0.628713        5
#
# [136 rows x 3 columns]

# %% [markdown]
# ### Outer Loop 3

# %%
# Define outer loop train and test
X_train_3 = np.array(X_train_B.append(X_train_C))
y_train_3 = np.array(y_train_B.append(y_train_C))
print(X_train_3.shape, y_train_3.shape)

X_test_3 = np.array(X_train_A)
y_test_3 = np.array(y_train_A)
print(X_test_3.shape, y_test_3.shape)
# Out:
# (1081, 607) (1081,)
# (540, 607) (540,)

# %%
# Define k-folds object
skf = StratifiedKFold(n_splits=num_inner_loops)
skf.get_n_splits(X_train_3, y_train_3)
# Out:
# 5

# %%
# K-folds: hyper-parameter tuning
num_regs = 30
regs = list(np.logspace(-6.0, -3.0, num_regs, base=e))
print(regs)

cv_aucs = [] # based on k-folds CV

for reg in regs:
    print(reg)
    k_folds_count = 1
    
    aucs = [] 
    for train_index, test_index in skf.split(X_train_3, y_train_3):
        print(k_folds_count)

        # Define train / test
        X_train, X_test = X_train_3[train_index], X_train_3[test_index]
        y_train, y_test = y_train_3[train_index], y_train_3[test_index]
        print(np.sum(y_train)/len(y_train), np.sum(y_test)/len(y_test))
        print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
        
        # SGL 
        sgl = LogisticGroupLasso(groups=clusters['x'], group_reg=reg*(1/6), l1_reg=reg*(5/6), n_iter=1000, 
                                 tol=1e-6, old_regularisation=False, warm_start=True, random_state=seed)
        sgl.fit(X_train, y_train)

        # Compute AUC on test set
        y_probs_test = sgl.predict_proba(X_test)[1] # predicted probability y = 1
        fpr, tpr, thresholds = roc_curve(y_test, y_probs_test, pos_label=1)
        roc_auc = auc(fpr, tpr)
        aucs.append(roc_auc)

        k_folds_count += 1
    
    print(aucs)
    cv_aucs.append(np.mean(np.array(aucs)))

# %%
# Plot CV AUCs
print(cv_aucs)
plt.figure(figsize=(12,6))
plt.plot(np.log(regs), cv_aucs)
plt.grid(axis='both')
plt.show()

max_reg = regs[np.argmax(np.array(cv_aucs))]
print(max_reg, np.log(max_reg))
# Out:
# [0.628861970913184, 0.6002464381979207, 0.6284386126003376, 0.6172842925268801, 0.6214943277746512, 0.6273959598353129, 0.6254816208050709, 0.6119074375759012, 0.6248591866354669, 0.6377051923817423, 0.6338829714759634, 0.5868497378632149, 0.6412806788898433, 0.6492841740469772, 0.6387357601966767, 0.6063488936939072, 0.6302116347264596, 0.6533377862030154, 0.6481501732768579, 0.6508866443529517, 0.6621109860489913, 0.6519447587452978, 0.6297309617606114, 0.6364373981813335, 0.6212116051064838, 0.6443538994698024, 0.6504949794141168, 0.6514793993068926, 0.652501229228992, 0.6442629069044163]
# 0.019623362019752715 -3.93103448275862

# %%
# Choose best regularization parameter based on CV plot
optimal_log_reg = -4.3
optimal_reg = np.exp(optimal_log_reg)
print(optimal_log_reg, optimal_reg)

# Fit "optimal model"
optimal_sgl = LogisticGroupLasso(groups=clusters['x'], group_reg=optimal_reg*(1/6), l1_reg=optimal_reg*(5/6), n_iter=1000, 
                         tol=1e-6, old_regularisation=False, warm_start=False, random_state=seed)
optimal_sgl.fit(X_train_3, y_train_3)

# Store optimal model
optimal_sgl_3 = optimal_sgl

# %%
# Plot Train and Test ROCs
y_pred_probs_train = optimal_sgl.predict_proba(X_train_3)[1] # predicted probability y = 1
y_pred_probs_test = optimal_sgl.predict_proba(X_test_3)[1]

# Train
fpr, tpr, thresholds = roc_curve(y_train_3, y_pred_probs_train, pos_label=1)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='blue', lw=1, label='Train ROC Curve (Area = %0.3f)' % roc_auc)
training_aurocs[2] = roc_auc

# Test
fpr, tpr, thresholds = roc_curve(y_test_3, y_pred_probs_test, pos_label=1)
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr, color='red', lw=1, label='Test ROC Curve (Area = %0.3f)' % roc_auc)
generalization_aurocs[2] = roc_auc

# Plot parameters
plt.plot([0, 1], [0, 1], color='black', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
# Plot Train and Test PR Curves

# Train
precision, recall, thresholds = precision_recall_curve(y_train_3, y_pred_probs_train, pos_label=1)
prc_auc = auc(recall, precision)
plt.figure()
plt.plot(recall, precision, color='blue', lw=1, label='Train PR Curve (Area = %0.3f)' % prc_auc)
training_auprcs[2] = prc_auc

# Test
precision, recall, thresholds = precision_recall_curve(y_test_3, y_pred_probs_test, pos_label=1)
prc_auc = auc(recall, precision)
plt.plot(recall, precision, color='red', lw=1, label='Test PR Curve (Area = %0.3f)' % prc_auc)
generalization_auprcs[2] = prc_auc

# Plot parameters
# plt.plot([0, 1], [0, 1], color='black', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower right")
plt.show()

# %%
# Save model coefficients
sparsity_mask = optimal_sgl.sparsity_mask_
print("Number of chosen variables: {0}".format(sparsity_mask.sum()))

betas_3 = optimal_sgl.coef_[:, 1] - optimal_sgl.coef_[:, 0]
betas_3[~sparsity_mask] = 0.0 # if not included in model, set to 0
betas_df = pd.DataFrame({
    "HIF": clusters['Unnamed: 0'],
    "Beta": betas_3, 
    "Cluster": clusters['x'],
    "Included (T/F)": sparsity_mask}
)
betas_df = betas_df[betas_df['Included (T/F)'] == True][['HIF', 'Beta', 'Cluster']]
betas_df.sort_values(by="Beta", ascending=False)
# Out:
# Number of chosen variables: 55
#                                                                                                      HIF  \
# 59                             CELL CLUSTERING PROPERTIES: CLUSTER EXTENT MEAN OF LYMPHOCYTE IN TUMOR_HE
# 284  COUNT PROP [[[CANCER CELLS] SELECTED BY [LYMPHOCYTE_RADIUS_80]] OVER [CANCER CELLS]] IN [EPITHEL...
# 157              CELL CLUSTERING PROPERTIES: WITHIN CLUSTER DISPERSION MEAN OF LYMPHOCYTE IN ESI_0080_HE
# 58                            CELL CLUSTERING PROPERTIES: CLUSTER EXTENT MEAN OF LYMPHOCYTE IN STROMA_HE
# 177  CELL CLUSTERING PROPERTIES: WITHIN CLUSTER DISPERSION STANDARD DEVIATION OF LYMPHOCYTE IN ESI_00...
# 117             CELL CLUSTERING PROPERTIES: CLUSTER SIZE STANDARD DEVIATION OF LYMPHOCYTE IN ESI_0080_HE
# 285  COUNT PROP [[[CANCER CELLS] SELECTED BY [LYMPHOCYTE_RADIUS_80]] OVER [CANCER CELLS]] IN [ESI_008...
# 286  COUNT PROP [[[CANCER CELLS] SELECTED BY [LYMPHOCYTE_RADIUS_80]] OVER [CANCER CELLS]] IN [STROMA]_HE
# 97                            CELL CLUSTERING PROPERTIES: CLUSTER SIZE MEAN OF LYMPHOCYTE IN ESI_0080_HE
# 287   COUNT PROP [[[CANCER CELLS] SELECTED BY [LYMPHOCYTE_RADIUS_80]] OVER [CANCER CELLS]] IN [TUMOR]_HE
# 178  CELL CLUSTERING PROPERTIES: WITHIN CLUSTER DISPERSION STANDARD DEVIATION OF LYMPHOCYTE IN STROMA_HE
# 119                CELL CLUSTERING PROPERTIES: CLUSTER SIZE STANDARD DEVIATION OF LYMPHOCYTE IN TUMOR_HE
# 596                                                            TOTAL [LYMPHOCYTE CELLS] IN [ESI_0080]_HE
# 305  COUNT PROP [[[CANCER CELLS] SELECTED BY [MACROPHAGE_RADIUS_80]] OVER [[CANCER CELLS] SELECTED BY...
# 61                          CELL CLUSTERING PROPERTIES: CLUSTER EXTENT MEAN OF MACROPHAGE IN ESI_0080_HE
# 21                              CELL CLUSTERING PROPERTIES: BALL-HALL INDEX OF MACROPHAGE IN ESI_0080_HE
# 57                          CELL CLUSTERING PROPERTIES: CLUSTER EXTENT MEAN OF LYMPHOCYTE IN ESI_0080_HE
# 87                   CELL CLUSTERING PROPERTIES: CLUSTER EXTENT STANDARD DEVIATION OF PLASMA IN TUMOR_HE
# 86                  CELL CLUSTERING PROPERTIES: CLUSTER EXTENT STANDARD DEVIATION OF PLASMA IN STROMA_HE
# 62                            CELL CLUSTERING PROPERTIES: CLUSTER EXTENT MEAN OF MACROPHAGE IN STROMA_HE
# 307  COUNT PROP [[[CANCER CELLS] SELECTED BY [MACROPHAGE_RADIUS_80]] OVER [[CANCER CELLS] SELECTED BY...
# 302  COUNT PROP [[[CANCER CELLS] SELECTED BY [MACROPHAGE_RADIUS_80]] OVER [CANCER CELLS]] IN [STROMA]_HE
# 292  COUNT PROP [[[CANCER CELLS] SELECTED BY [LYMPHOCYTE_RADIUS_80]] OVER [[CANCER CELLS] SELECTED BY...
# 165                  CELL CLUSTERING PROPERTIES: WITHIN CLUSTER DISPERSION MEAN OF PLASMA IN ESI_0080_HE
# 179   CELL CLUSTERING PROPERTIES: WITHIN CLUSTER DISPERSION STANDARD DEVIATION OF LYMPHOCYTE IN TUMOR_HE
# 306  COUNT PROP [[[CANCER CELLS] SELECTED BY [MACROPHAGE_RADIUS_80]] OVER [[CANCER CELLS] SELECTED BY...
# 405                                                          DENSITY [LYMPHOCYTE CELLS] IN [ESI_0080]_HE
# 583                               TOTAL [CANCER CELLS] IN [STROMA] SELECTED BY [MACROPHAGE_RADIUS_80]_HE
# 323  COUNT PROP [[[CANCER CELLS] SELECTED BY [PLASMA_RADIUS_80]] OVER [[CANCER CELLS] SELECTED BY [FI...
# 432                            REGION PROPERTIES: AVERAGE SOLIDITY OF SIGNIFICANT REGIONS OF ESI_0080_HE
# 22                                CELL CLUSTERING PROPERTIES: BALL-HALL INDEX OF MACROPHAGE IN STROMA_HE
# 26                                    CELL CLUSTERING PROPERTIES: BALL-HALL INDEX OF PLASMA IN STROMA_HE
# 42                        CELL CLUSTERING PROPERTIES: CALINSKI-HARABASZ INDEX OF MACROPHAGE IN STROMA_HE
# 555                                               REGION PROPERTIES: TOTAL FILLED AREA (MM2) OF TUMOR_HE
# 132                        CELL CLUSTERING PROPERTIES: NUMBER OF CLUSTERS OF FIBROBLAST IN EPITHELIAL_HE
# 116           CELL CLUSTERING PROPERTIES: CLUSTER SIZE STANDARD DEVIATION OF LYMPHOCYTE IN EPITHELIAL_HE
# 176  CELL CLUSTERING PROPERTIES: WITHIN CLUSTER DISPERSION STANDARD DEVIATION OF LYMPHOCYTE IN EPITHE...
# 43                         CELL CLUSTERING PROPERTIES: CALINSKI-HARABASZ INDEX OF MACROPHAGE IN TUMOR_HE
# 135                             CELL CLUSTERING PROPERTIES: NUMBER OF CLUSTERS OF FIBROBLAST IN TUMOR_HE
# 13                              CELL CLUSTERING PROPERTIES: BALL-HALL INDEX OF FIBROBLAST IN ESI_0080_HE
# 308  COUNT PROP [[[CANCER CELLS] SELECTED BY [MACROPHAGE_RADIUS_80]] OVER [[CANCER CELLS] SELECTED BY...
# 300  COUNT PROP [[[CANCER CELLS] SELECTED BY [MACROPHAGE_RADIUS_80]] OVER [CANCER CELLS]] IN [EPITHEL...
# 134                            CELL CLUSTERING PROPERTIES: NUMBER OF CLUSTERS OF FIBROBLAST IN STROMA_HE
# 402                                                            DENSITY [FIBROBLAST CELLS] IN [STROMA]_HE
# 29                          CELL CLUSTERING PROPERTIES: CALINSKI-HARABASZ INDEX OF CANCER IN ESI_0080_HE
# 392                            DENSITY RATIO [[LYMPHOCYTE CELLS] OVER [CANCER CELLS]] IN [EPITHELIAL]_HE
# 599                                                          TOTAL [MACROPHAGE CELLS] IN [EPITHELIAL]_HE
# 574                               TOTAL [CANCER CELLS] IN [EPITHELIAL] SELECTED BY [PLASMA_RADIUS_80]_HE
# 571                           TOTAL [CANCER CELLS] IN [EPITHELIAL] SELECTED BY [FIBROBLAST_RADIUS_80]_HE
# 252  COUNT PROP [[CANCER CELLS] OVER [[CANCER CELLS] SELECTED BY [LYMPHOCYTE_RADIUS_80]]] IN [EPITHEL...
# 431                          REGION PROPERTIES: AVERAGE SOLIDITY OF SIGNIFICANT REGIONS OF EPITHELIAL_HE
# 451                                         REGION PROPERTIES: EXTENT OF LARGEST REGION OF EPITHELIAL_HE
# 521                                       REGION PROPERTIES: SOLIDITY OF LARGEST REGION OF EPITHELIAL_HE
# 426                            REGION PROPERTIES: AVERAGE EXTENT OF SIGNIFICANT REGIONS OF EPITHELIAL_HE
# 70                  CELL CLUSTERING PROPERTIES: CLUSTER EXTENT STANDARD DEVIATION OF CANCER IN STROMA_HE
#
#          Beta  Cluster
# 59   0.567394       10
# 284  0.558999       10
# 157  0.484087       10
# 58   0.387696       10
# 177  0.378737       10
# 117  0.368711       10
# 285  0.291722       10
# 286  0.280025       10
# 97   0.265015       10
# 287  0.244496       10
# 178  0.205335       10
# 119  0.164204       10
# 596  0.149498        1
# 305  0.130412        7
# 61   0.119469        7
# 21   0.091139        7
# 57   0.052610       10
# 87   0.048238        9
# 86   0.047551        9
# 62   0.024932        7
# 307  0.023463        7
# 302  0.022351        7
# 292  0.017222        7
# 165  0.006156        9
# 179  0.004943       10
# 306  0.004083        7
# 405  0.003771       10
# 583  0.003667        1
# 323  0.002928        9
# 432  0.002571        5
# 22   0.000810        7
# 26   0.000198        9
# 42  -0.001826        1
# 555 -0.003908        1
# 132 -0.007179        1
# 116 -0.008888       10
# 176 -0.010691       10
# 43  -0.017959        1
# 135 -0.018915        1
# 13  -0.021242        3
# 308 -0.022273        7
# 300 -0.026729        7
# 134 -0.027668        1
# 402 -0.028519       14
# 29  -0.029793        1
# 392 -0.030251       10
# 599 -0.038135        7
# 574 -0.056549        1
# 571 -0.062136        1
# 252 -0.085385       10
# 431 -0.135808        7
# 451 -0.157950        7
# 521 -0.245653        7
# 426 -0.281962        7
# 70  -1.016685        5

# %% [markdown]
# ## Compute Ensemble Model

# %%
betas_df = pd.DataFrame({
    "HIF": clusters['Unnamed: 0'],
    "Beta_1": betas_1, 
    "Beta_2": betas_2,
    "Beta_3": betas_3,
    "Cluster": clusters['x']
    }
)
betas_df['Beta'] = (betas_df['Beta_1'] + betas_df['Beta_2'] + betas_df['Beta_3'])/3.0
betas_df.sort_values(by="Beta", ascending=False)
# Out:
#                                                                                                      HIF  \
# 117             CELL CLUSTERING PROPERTIES: CLUSTER SIZE STANDARD DEVIATION OF LYMPHOCYTE IN ESI_0080_HE
# 59                             CELL CLUSTERING PROPERTIES: CLUSTER EXTENT MEAN OF LYMPHOCYTE IN TUMOR_HE
# 286  COUNT PROP [[[CANCER CELLS] SELECTED BY [LYMPHOCYTE_RADIUS_80]] OVER [CANCER CELLS]] IN [STROMA]_HE
# 177  CELL CLUSTERING PROPERTIES: WITHIN CLUSTER DISPERSION STANDARD DEVIATION OF LYMPHOCYTE IN ESI_00...
# 157              CELL CLUSTERING PROPERTIES: WITHIN CLUSTER DISPERSION MEAN OF LYMPHOCYTE IN ESI_0080_HE
# ..                                                                                                   ...
# 428                              REGION PROPERTIES: AVERAGE EXTENT OF SIGNIFICANT REGIONS OF NECROSIS_HE
# 451                                         REGION PROPERTIES: EXTENT OF LARGEST REGION OF EPITHELIAL_HE
# 252  COUNT PROP [[CANCER CELLS] OVER [[CANCER CELLS] SELECTED BY [LYMPHOCYTE_RADIUS_80]]] IN [EPITHEL...
# 426                            REGION PROPERTIES: AVERAGE EXTENT OF SIGNIFICANT REGIONS OF EPITHELIAL_HE
# 70                  CELL CLUSTERING PROPERTIES: CLUSTER EXTENT STANDARD DEVIATION OF CANCER IN STROMA_HE
#
#        Beta_1    Beta_2    Beta_3  Cluster      Beta
# 117  0.567154  0.559328  0.368711       10  0.498398
# 59   0.496314  0.325178  0.567394       10  0.462962
# 286  0.466330  0.464031  0.280025       10  0.403462
# 177  0.371590  0.370915  0.378737       10  0.373748
# 157  0.264769  0.316186  0.484087       10  0.355014
# ..        ...       ...       ...      ...       ...
# 428 -0.067147 -0.498495  0.000000        2 -0.188547
# 451 -0.502165 -0.000179 -0.157950        7 -0.220098
# 252 -0.255646 -0.324401 -0.085385       10 -0.221811
# 426 -0.434664 -0.081887 -0.281962        7 -0.266171
# 70  -0.253344 -0.628713 -1.016685        5 -0.632914
#
# [607 rows x 6 columns]

# %% [markdown]
# ## Compute Final Train / Test Metrics

# %%
print(training_aurocs)
print(np.mean(training_aurocs), np.std(training_aurocs))
# Out:
# [0.6150480134789185, 0.6997056477125803, 0.6963513039410596]
# 0.6703683217108528 0.03914132754256511

# %%
print(generalization_aurocs)
print(np.mean(generalization_aurocs), np.std(generalization_aurocs))
# Out:
# [0.6342478167737684, 0.6697500654820167, 0.6723434744268078]
# 0.658780452227531 0.017379472454961256

# %%
print(training_auprcs)
print(np.mean(training_auprcs), np.std(training_auprcs))
# Out:
# [0.5919723181173735, 0.6774463838711431, 0.6609054249201414]
# 0.6434413756362193 0.037015300819736474

# %%
print(generalization_auprcs)
print(np.mean(generalization_auprcs), np.std(generalization_auprcs))
# Out:
# [0.5921079418986118, 0.6331763936265982, 0.6633623486752019]
# 0.6295488947334706 0.029202359293222343

# %% [markdown]
# ## Evaluate Hold-Out Set

# %%
holdout_df = pd.read_csv("{0}/data/genetic_data/PanImmune/datasets/pancancer.PDL1.joined.HOLDOUT.csv".format(working_dir))
holdout_df = holdout_df.iloc[:,1:]
holdout_df
# Out:
#      AREA..MM2..OF..EPITHELIAL..IN..TISSUE._HE  \
# 0                                    34.327408
# 1                                    18.961888
# 2                                     2.042160
# 3                                    67.331360
# 4                                    24.716784
# ..                                         ...
# 514                                  42.810968
# 515                                  47.872360
# 516                                  20.681632
# 517                                 107.337592
# 518                                   5.812256
#
#      AREA..MM2..OF..ESI_0080..IN..TISSUE._HE  \
# 0                                  81.342520
# 1                                  32.686732
# 2                                   2.735584
# 3                                  79.770572
# 4                                  34.905768
# ..                                       ...
# 514                                71.876072
# 515                                35.150752
# 516                                48.952788
# 517                               179.691200
# 518                                16.089064
#
#      AREA..MM2..OF..NECROSIS..IN..TISSUE._HE  \
# 0                                   0.551184
# 1                                   6.767424
# 2                                   1.230176
# 3                                   0.214880
# 4                                   7.369856
# ..                                       ...
# 514                                71.635612
# 515                                10.031736
# 516                                 4.349976
# 517                                79.234320
# 518                                 2.406924
#
#      AREA..MM2..OF..STROMA..IN..TISSUE._HE  \
# 0                                62.415296
# 1                                46.949360
# 2                                 7.568592
# 3                                26.367440
# 4                                42.780144
# ..                                     ...
# 514                              89.004812
# 515                              22.948752
# 516                              58.916880
# 517                             183.314796
# 518                              25.952164
#
#      AREA..MM2..OF..TUMOR..IN..TISSUE._HE  \
# 0                               96.742704
# 1                               65.911248
# 2                                9.610752
# 3                               93.698800
# 4                               67.496928
# ..                                    ...
# 514                            131.815780
# 515                             70.821112
# 516                             79.598512
# 517                            290.652388
# 518                             31.764420
#
#      AREA.PROP...EPITHELIAL..OVER..TUMOR...IN..TISSUE._HE  \
# 0                                                0.354832
# 1                                                0.287688
# 2                                                0.212487
# 3                                                0.718594
# 4                                                0.366191
# ..                                                    ...
# 514                                              0.324779
# 515                                              0.675962
# 516                                              0.259824
# 517                                              0.369299
# 518                                              0.182980
#
#      AREA.PROP...ESI_0080..OVER..TUMOR...IN..TISSUE._HE  \
# 0                                              0.840813
# 1                                              0.495920
# 2                                              0.284638
# 3                                              0.851351
# 4                                              0.517146
# ..                                                  ...
# 514                                            0.545277
# 515                                            0.496332
# 516                                            0.614996
# 517                                            0.618234
# 518                                            0.506512
#
#      AREA.PROP...STROMA..OVER..TUMOR...IN..TISSUE._HE  \
# 0                                            0.645168
# 1                                            0.712312
# 2                                            0.787513
# 3                                            0.281406
# 4                                            0.633809
# ..                                                ...
# 514                                          0.675221
# 515                                          0.324038
# 516                                          0.740176
# 517                                          0.630701
# 518                                          0.817020
#
#      CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.CANCER.IN.EPITHELIAL_HE  \
# 0                                                               6633.257717
# 1                                                               5611.085772
# 2                                                               3935.741179
# 3                                                               7514.344122
# 4                                                               5589.983127
# ..                                                                      ...
# 514                                                             5849.430848
# 515                                                             6923.732594
# 516                                                             6355.898094
# 517                                                             6385.322963
# 518                                                             4930.138750
#
#      CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.CANCER.IN.ESI_0080_HE  \
# 0                                                             7130.446085
# 1                                                             6026.546207
# 2                                                             5306.740189
# 3                                                             7332.800369
# 4                                                             6240.323681
# ..                                                                    ...
# 514                                                           5578.271804
# 515                                                           5998.358443
# 516                                                           6468.830562
# 517                                                           6357.834926
# 518                                                           4434.500984
#
#      ...  TOTAL..LYMPHOCYTE.CELLS..IN..TUMOR._HE  \
# 0    ...                                   25000
# 1    ...                                  160321
# 2    ...                                   28523
# 3    ...                                   26272
# 4    ...                                  126871
# ..   ...                                     ...
# 514  ...                                  123464
# 515  ...                                   20949
# 516  ...                                  195558
# 517  ...                                  496427
# 518  ...                                   23443
#
#      TOTAL..MACROPHAGE.CELLS..IN..EPITHELIAL._HE  \
# 0                                           1813
# 1                                           4956
# 2                                            413
# 3                                           3188
# 4                                           3673
# ..                                           ...
# 514                                         6581
# 515                                         6118
# 516                                        10550
# 517                                        21633
# 518                                         1337
#
#      TOTAL..MACROPHAGE.CELLS..IN..ESI_0080._HE  \
# 0                                         4109
# 1                                        12171
# 2                                         1643
# 3                                         4986
# 4                                        12495
# ..                                         ...
# 514                                      33044
# 515                                      10883
# 516                                      41797
# 517                                      73755
# 518                                       2942
#
#      TOTAL..MACROPHAGE.CELLS..IN..STROMA._HE  \
# 0                                       7559
# 1                                      33449
# 2                                       6123
# 3                                       4670
# 4                                      38551
# ..                                       ...
# 514                                    80904
# 515                                    11042
# 516                                    96434
# 517                                   159376
# 518                                     5997
#
#      TOTAL..MACROPHAGE.CELLS..IN..TUMOR._HE  \
# 0                                      9372
# 1                                     38405
# 2                                      6536
# 3                                      7858
# 4                                     42224
# ..                                      ...
# 514                                   87485
# 515                                   17160
# 516                                  106984
# 517                                  181009
# 518                                    7334
#
#      TOTAL..PLASMA.CELLS..IN..EPITHELIAL._HE  \
# 0                                       1564
# 1                                       1385
# 2                                        849
# 3                                       1266
# 4                                       2081
# ..                                       ...
# 514                                     1912
# 515                                      902
# 516                                     3846
# 517                                     7270
# 518                                      431
#
#      TOTAL..PLASMA.CELLS..IN..ESI_0080._HE  \
# 0                                     2336
# 1                                     5787
# 2                                     2863
# 3                                     1532
# 4                                     8924
# ..                                     ...
# 514                                  28761
# 515                                   3880
# 516                                  52270
# 517                                  79853
# 518                                   1326
#
#      TOTAL..PLASMA.CELLS..IN..STROMA._HE  TOTAL..PLASMA.CELLS..IN..TUMOR._HE  \
# 0                                   2231                                3795
# 1                                  12023                               13408
# 2                                   8027                                8876
# 3                                    634                                1900
# 4                                  20944                               23025
# ..                                   ...                                 ...
# 514                                99357                              101269
# 515                                 5740                                6642
# 516                                78530                               82376
# 517                               205016                              212286
# 518                                 2226                                2657
#
#      joined.PDL1_data
# 0                   0
# 1                   1
# 2                   1
# 3                   0
# 4                   1
# ..                ...
# 514                 0
# 515                 0
# 516                 0
# 517                 0
# 518                 1
#
# [519 rows x 608 columns]

# %%
# Normalize HIFs and define X, y
X_holdout = holdout_df.iloc[:,:607]
X_normalized_holdout = (X_holdout-X_holdout.mean())/X_holdout.std()
X_normalized_holdout
# Out:
#      AREA..MM2..OF..EPITHELIAL..IN..TISSUE._HE  \
# 0                                    -0.264150
# 1                                    -0.715446
# 2                                    -1.212389
# 3                                     0.705197
# 4                                    -0.546420
# ..                                         ...
# 514                                  -0.014983
# 515                                   0.133674
# 516                                  -0.664936
# 517                                   1.880206
# 518                                  -1.101659
#
#      AREA..MM2..OF..ESI_0080..IN..TISSUE._HE  \
# 0                                   0.496603
# 1                                  -0.611950
# 2                                  -1.294345
# 3                                   0.460788
# 4                                  -0.561393
# ..                                       ...
# 514                                 0.280923
# 515                                -0.555811
# 516                                -0.241351
# 517                                 2.737337
# 518                                -0.990105
#
#      AREA..MM2..OF..NECROSIS..IN..TISSUE._HE  \
# 0                                  -0.527760
# 1                                  -0.062141
# 2                                  -0.476901
# 3                                  -0.552950
# 4                                  -0.017016
# ..                                       ...
# 514                                 4.796722
# 515                                 0.182368
# 516                                -0.243216
# 517                                 5.365893
# 518                                -0.388758
#
#      AREA..MM2..OF..STROMA..IN..TISSUE._HE  \
# 0                                 0.404003
# 1                                -0.022081
# 2                                -1.107016
# 3                                -0.589110
# 4                                -0.136942
# ..                                     ...
# 514                               1.136541
# 515                              -0.683295
# 516                               0.307622
# 517                               3.734768
# 518                              -0.600551
#
#      AREA..MM2..OF..TUMOR..IN..TISSUE._HE  \
# 0                                0.091180
# 1                               -0.404560
# 2                               -1.309818
# 3                                0.042237
# 4                               -0.379064
# ..                                    ...
# 514                              0.655122
# 515                             -0.325614
# 516                             -0.184482
# 517                              3.209063
# 518                             -0.953609
#
#      AREA.PROP...EPITHELIAL..OVER..TUMOR...IN..TISSUE._HE  \
# 0                                               -0.750348
# 1                                               -1.173195
# 2                                               -1.646784
# 3                                                1.540488
# 4                                               -0.678812
# ..                                                    ...
# 514                                             -0.939612
# 515                                              1.272008
# 516                                             -1.348671
# 517                                             -0.659241
# 518                                             -1.832608
#
#      AREA.PROP...ESI_0080..OVER..TUMOR...IN..TISSUE._HE  \
# 0                                              1.328443
# 1                                             -1.034066
# 2                                             -2.481348
# 3                                              1.400629
# 4                                             -0.888671
# ..                                                  ...
# 514                                           -0.695976
# 515                                           -1.031249
# 516                                           -0.218398
# 517                                           -0.196219
# 518                                           -0.961513
#
#      AREA.PROP...STROMA..OVER..TUMOR...IN..TISSUE._HE  \
# 0                                            0.750348
# 1                                            1.173195
# 2                                            1.646784
# 3                                           -1.540488
# 4                                            0.678812
# ..                                                ...
# 514                                          0.939612
# 515                                         -1.272008
# 516                                          1.348671
# 517                                          0.659241
# 518                                          1.832608
#
#      CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.CANCER.IN.EPITHELIAL_HE  \
# 0                                                                  0.460257
# 1                                                                 -1.020111
# 2                                                                 -3.446439
# 3                                                                  1.736296
# 4                                                                 -1.050673
# ..                                                                      ...
# 514                                                               -0.674926
# 515                                                                0.880939
# 516                                                                0.058569
# 517                                                                0.101183
# 518                                                               -2.006296
#
#      CELL.CLUSTERING.PROPERTIES..BALL.HALL.INDEX.OF.CANCER.IN.ESI_0080_HE  \
# 0                                                                1.211129
# 1                                                               -0.661388
# 2                                                               -1.882376
# 3                                                                1.554377
# 4                                                               -0.298763
# ..                                                                    ...
# 514                                                             -1.421784
# 515                                                             -0.709202
# 516                                                              0.088848
# 517                                                             -0.099432
# 518                                                             -3.361933
#
#      ...  TOTAL..LYMPHOCYTE.CELLS..IN..STROMA._HE  \
# 0    ...                                -0.552670
# 1    ...                                 1.081526
# 2    ...                                -0.484143
# 3    ...                                -0.677123
# 4    ...                                 0.642227
# ..   ...                                      ...
# 514  ...                                 0.594345
# 515  ...                                -0.634772
# 516  ...                                 1.399180
# 517  ...                                 4.907412
# 518  ...                                -0.562439
#
#      TOTAL..LYMPHOCYTE.CELLS..IN..TUMOR._HE  \
# 0                                 -0.575289
# 1                                  0.885769
# 2                                 -0.537252
# 3                                 -0.561556
# 4                                  0.524610
# ..                                      ...
# 514                                0.487824
# 515                               -0.619028
# 516                                1.266222
# 517                                4.514698
# 518                               -0.592100
#
#      TOTAL..MACROPHAGE.CELLS..IN..EPITHELIAL._HE  \
# 0                                      -0.443024
# 1                                       0.158537
# 2                                      -0.710979
# 3                                      -0.179853
# 4                                      -0.087025
# ..                                           ...
# 514                                     0.469557
# 515                                     0.380940
# 516                                     1.229211
# 517                                     3.350462
# 518                                    -0.534128
#
#      TOTAL..MACROPHAGE.CELLS..IN..ESI_0080._HE  \
# 0                                    -0.539589
# 1                                     0.081646
# 2                                    -0.729612
# 3                                    -0.472009
# 4                                     0.106613
# ..                                         ...
# 514                                   1.690061
# 515                                  -0.017603
# 516                                   2.364543
# 517                                   4.827137
# 518                                  -0.629514
#
#      TOTAL..MACROPHAGE.CELLS..IN..STROMA._HE  \
# 0                                  -0.433317
# 1                                   0.573655
# 2                                  -0.489169
# 3                                  -0.545683
# 4                                   0.772094
# ..                                       ...
# 514                                 2.419383
# 515                                -0.297848
# 516                                 3.023411
# 517                                 5.471494
# 518                                -0.494070
#
#      TOTAL..MACROPHAGE.CELLS..IN..TUMOR._HE  \
# 0                                 -0.473025
# 1                                  0.547617
# 2                                 -0.572723
# 3                                 -0.526249
# 4                                  0.681872
# ..                                      ...
# 514                                2.273002
# 515                               -0.199241
# 516                                2.958481
# 517                                5.560796
# 518                               -0.544670
#
#      TOTAL..PLASMA.CELLS..IN..EPITHELIAL._HE  \
# 0                                  -0.335674
# 1                                  -0.380017
# 2                                  -0.512800
# 3                                  -0.409497
# 4                                  -0.207598
# ..                                       ...
# 514                                -0.249464
# 515                                -0.499670
# 516                                 0.229644
# 517                                 1.077868
# 518                                -0.616351
#
#      TOTAL..PLASMA.CELLS..IN..ESI_0080._HE  \
# 0                                -0.545109
# 1                                -0.344137
# 2                                -0.514419
# 3                                -0.591930
# 4                                -0.161452
# ..                                     ...
# 514                               0.993770
# 515                              -0.455193
# 516                               2.362833
# 517                               3.969148
# 518                              -0.603927
#
#      TOTAL..PLASMA.CELLS..IN..STROMA._HE  TOTAL..PLASMA.CELLS..IN..TUMOR._HE
# 0                              -0.478115                           -0.497430
# 1                              -0.202419                           -0.236648
# 2                              -0.314927                           -0.359592
# 3                              -0.523079                           -0.548837
# 4                               0.048754                            0.024242
# ..                                   ...                                 ...
# 514                             2.256490                            2.146844
# 515                            -0.379318                           -0.420196
# 516                             1.670101                            1.634315
# 517                             5.231344                            5.158513
# 518                            -0.478256                           -0.528301
#
# [519 rows x 607 columns]

# %%
y_holdout = holdout_df.iloc[:,607]
print(np.sum(y_holdout))
# Out:
# 255

# %%
X_normalized_holdout = np.array(X_normalized_holdout)
y_pred_probs_1 = optimal_sgl_1.predict_proba(X_normalized_holdout)[1] # predicted probability y = 1
y_pred_probs_2 = optimal_sgl_2.predict_proba(X_normalized_holdout)[1]
y_pred_probs_3 = optimal_sgl_3.predict_proba(X_normalized_holdout)[1]

# %%
# Ensemble (average) predictions
y_pred_probs_ensemble = np.mean(np.array([list(y_pred_probs_1), list(y_pred_probs_2), list(y_pred_probs_3)]), axis=0)
# y_pred_probs_ensemble

# %%
# Hold Out ROC
fpr, tpr, thresholds = roc_curve(y_holdout, y_pred_probs_ensemble, pos_label=1)
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr, color='red', lw=1, label='Hold-Out ROC Curve (Area = %0.3f)' % roc_auc)

# Plot parameters
plt.plot([0, 1], [0, 1], color='black', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
# Generate ROC 95% CI

print("Original ROC area: {:0.3f}".format(roc_auc))

n_bootstraps = 1000
bootstrapped_scores = []

rng = np.random.RandomState(seed)
for i in range(n_bootstraps):
    # bootstrap by sampling with replacement on the prediction indices
    indices = rng.randint(0, len(y_pred_probs_ensemble), len(y_pred_probs_ensemble))
    
    if len(np.unique(y_holdout[indices])) < 2:
        # We need at least one positive and one negative sample for ROC AUC
        # to be defined: reject the sample
        continue

    score = roc_auc_score(y_holdout[indices], y_pred_probs_ensemble[indices])
    bootstrapped_scores.append(score)
    # print("Bootstrap #{} ROC area: {:0.3f}".format(i + 1, score))

plt.hist(bootstrapped_scores, bins=50)
plt.title('Histogram of the bootstrapped ROC AUC scores')
plt.show()

sorted_scores = np.array(bootstrapped_scores)
sorted_scores.sort()

# Computing the lower and upper bound of the 94% confidence interval
confidence_lower = sorted_scores[int(0.025 * len(sorted_scores))]
confidence_upper = sorted_scores[int(0.975 * len(sorted_scores))]
print("Confidence interval for the score: [{:0.3f} - {:0.3}]".format(
    confidence_lower, confidence_upper))
# Out:
# Original ROC area: 0.626
# Confidence interval for the score: [0.574 - 0.674]

# %%
# Hold Out PR Curve
precision, recall, thresholds = precision_recall_curve(y_holdout, y_pred_probs_ensemble, pos_label=1)
prc_auc = auc(recall, precision)
plt.plot(recall, precision, color='red', lw=1, label='Hold-Out PR Curve (Area = %0.3f)' % prc_auc)

# Plot parameters
# plt.plot([0, 1], [0, 1], color='black', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower right")
plt.show()

# %%
# Generate PRC 95% CI
print("Original PRC area: {:0.3f}".format(prc_auc))

n_bootstraps = 1000
bootstrapped_scores = []

rng = np.random.RandomState(seed)
for i in range(n_bootstraps):
    # bootstrap by sampling with replacement on the prediction indices
    indices = rng.randint(0, len(y_pred_probs_ensemble), len(y_pred_probs_ensemble))
    
    if len(np.unique(y_holdout[indices])) < 2:
        # We need at least one positive and one negative sample for ROC AUC
        # to be defined: reject the sample
        continue
    
    precision, recall, thresholds = precision_recall_curve(y_holdout[indices], y_pred_probs_ensemble[indices], pos_label=1)
    score = auc(recall, precision)
    bootstrapped_scores.append(score)
    # print("Bootstrap #{} ROC area: {:0.3f}".format(i + 1, score))

plt.hist(bootstrapped_scores, bins=50)
plt.title('Histogram of the bootstrapped ROC PRC scores')
plt.show()

sorted_scores = np.array(bootstrapped_scores)
sorted_scores.sort()

# Computing the lower and upper bound of the 94% confidence interval
confidence_lower = sorted_scores[int(0.025 * len(sorted_scores))]
confidence_upper = sorted_scores[int(0.975 * len(sorted_scores))]
print("Confidence interval for the score: [{:0.3f} - {:0.3}]".format(
    confidence_lower, confidence_upper))
# Out:
# Original PRC area: 0.639
# Confidence interval for the score: [0.574 - 0.707]
